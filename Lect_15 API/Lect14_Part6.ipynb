# %% [markdown]
# # Python для анализа данных
#
# ## Работа с форматами XML и JSON

# %% [markdown]
# # XML

# %% [markdown]
# До этого мы с вами собирали данные вручную, обращаясь к html страницам, размеченным для отображения в браузере. Но данные также можно собирать и через API -  — application program interface. Обычный интерфейс — это способ взаимодействия человека с программой, а API — одной программы с другой. Например, вашего скрипта на Python с удалённым веб-сервером.
#
# Для хранения веб-страниц, которые читают люди, используется язык HTML. Для хранения произвольных структурированных данных, которыми обмениваются между собой программы, используются другие языки — в частности, язык XML, похожий на HTML. Вернее было бы сказать, что XML это метаязык, то есть способ описания языков. В отличие от HTML, набор тегов в XML-документе может быть произвольным (и определяется разработчиком конкретного диалекта XML). Например, если бы мы хотели описать в виде XML некоторую студенческую группу, это могло бы выглядеть так:
#
# ```xml
# <group>
#     <number>134</number>
#     <student>
#         <firstname>Виталий</firstname>
#         <lastname>Иванов</lastname>
#     </student>
#     <student>
#         <firstname>Мария</firstname>
#         <lastname>Петрова</lastname>
#     </student>
# </group>
# ```

# %% [markdown]
# Для обработки XML-файлов можно использовать тот же пакет *Beautiful Soup*, который мы уже использовали для работы с HTML. Единственное различие — нужно указать дополнительный параметр `feautres="xml"` при вызове функции `BeautifulSoup` — чтобы он не искал в документе HTML-теги.

# %%
group = """<group>
<number>134</number>
<student>
<firstname>Виталий</firstname>
<lastname>Иванов</lastname>
</student>
<student>
<firstname>Мария</firstname>
<lastname>Петрова</lastname>
</student>
</group>"""

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in /Users/kasyanenko/opt/anaconda3/lib/python3.9/site-packages (4.6.3)

# %%
from bs4 import BeautifulSoup

obj = BeautifulSoup(group, features="lxml")
print(obj.prettify())
# Out:
# <html>
#  <body>
#   <group>
#    <number>
#     134
#    </number>
#    <student>
#     <firstname>
#      Виталий
#     </firstname>
#     <lastname>
#      Иванов
#     </lastname>
#    </student>
#    <student>
#     <firstname>
#      Мария
#     </firstname>
#     <lastname>
#      Петрова
#     </lastname>
#    </student>
#   </group>
#  </body>
# </html>

# %% [markdown]
# Номер группы можно найти, например, вот так - для каждого объекта через точку указываем его атрибут, в который надо спуститься.

# %%
obj.group.number.text # последний атрибут текст, точно также как делали в html
# Out:
# '134'

# %% [markdown]
# Но это работает только тогда, когда тэг уникальный. В других случаях, парсер всегда будет попадать в первый child-тэг, который он встретил по пути вниз.

# %%
obj.group.student.lastname.text # до Петровой так не добраться
# Out:
# 'Иванов'

# %% [markdown]
# Перечислить всех студентов можно с помощью цикла (похожая структура у нас была и в обработке html).

# %%
for student in obj.group.find_all('student'):
    print(student.lastname.text, student.firstname.text)
# Out:
# Иванов Виталий
# Петрова Мария

# %% [markdown]
# По сути, главное отличие xml от html, что работать вы будете не со стандартизированными структурами. Поэтому перед работой придется поиграть в детективов - запросить данные и внимательно изучить расположение узлов, чтобы понять, какие тэги вас интересуют.
#
# XML легко представить в виде дерева, где есть главный узел (parent) и его "дети".
#
# ![](https://www.py4e.com/images/xml-tree.svg)
# *Источник: Python for Everybody, C.Severance*

# %% [markdown]
# Кроме BS парсить xml можно и с помощью других библиотек. Например, ElementTree.

# %%
import xml.etree.ElementTree as ET

# %%
tree = ET.fromstring(group)
list(tree) # посмотрим, что внутри
# Out:
# [<Element 'number' at 0x7fc8c81bd630>,
#  <Element 'student' at 0x7fc8c81bd5e0>,
#  <Element 'student' at 0x7fc8c81bd450>]

# %% [markdown]
# Cинтаксис очень похож на BS. Добрались до первой фамилии.

# %%
tree.find('student').find('lastname').text
# Out:
# 'Иванов'

# %%
for element in tree.findall('student'):
    print(element)
    print(element.find('lastname').text)
# Out:
# <Element 'student' at 0x7fc8c81bd5e0>
# Иванов
# <Element 'student' at 0x7fc8c81bd450>
# Петрова

# %% [markdown]
# Можно немного упростить код, включив дочерний тэг в findall.

# %%
for element in tree.findall('student/lastname'):
    print(element.text)
# Out:
# Иванов
# Петрова

# %% [markdown]
# # Задача
# По ссылке данные в формате xml.
# http://py4e-data.dr-chuck.net/comments_42.xml
#
# Посчитайте все комментарии в этом документе (поля count).

# %%
import requests
data = requests.get('http://py4e-data.dr-chuck.net/comments_42.xml').text

tree = ET.fromstring(data)

total = 0
for element in tree.findall('comments/comment/count'):
#     print(type(element.text))
    total += int(element.text)
    
print(total)
# Out:
# 2553

# %% [markdown]
# # JSON
#
# Другой популярный формат, в котором клиент может отдать вам данные - json. JSON расшифровывается как JavaScript Object Notation и изначально возник как подмножество языка JavaScript (пусть вас не вводит в заблуждение название, этот язык ничего не имеет общего с Java), используемое для описания объектов, но впоследствии стал использоваться и в других языках программирования, включая Python. Различные API могут поддерживать либо XML, либо JSON, либо и то, и другое, так что нам полезно научиться работать с обоими типами данных (например, wiki api могла бы выгрузить нам данные и в формате json при соответствующем запросе).

# %% [markdown]
# JSON очень похож на описание объекта в Python и смысл квадратных и фигурных скобок такой же. Правда, есть и отличия: например, в Python одинарные и двойные кавычки ничем не отличаются, а в JSON можно использовать только двойные. Мы видим, что полученный нами JSON представляет собой словарь, значения которого — строки или числа, а также списки или словари, значения которых в свою очередь также могут быть строками, числами, списками, словарями и т.д. То есть получается такая довольно сложная структура данных.
#
# В данный момент тот факт, что перед нами сложная структура данных, видим только мы — с точки зрения Python, j.text это просто такая строка. Однако в модуле requests есть метод, позволяющий сразу выдать питоновский объект (словарь или список), если результат запроса возвращён в формате JSON. Так что нам не придётся использовать никакие дополнительные библиотеки.

# %% [markdown]
# Преимущества JSON в том, что мы получаем готовый объект Python и нет необходимости использовать какие-то дополнительные библиотеки для того, чтобы с ним работать. Недостатком является то же самое: зачастую поиск информации в XML-файле может проводиться более эффективно, чем в JSON.

# %% [markdown]
# ## JSON (парсинг VK)
#
# Как уже говорилось выше, не все API открытые. Так, чтобы достать информацию из vk вам придется сгенерировать токен с помощью вашего аккаунта. API VK отдает данные в json. Структура тут будет посложнее, чем то, что мы уже видели, поэтому давайте еще потренируемся.

# %% [markdown]
# Теперь научимся еще и загружать JSON файл с диска. Для этого нам понадобится модуль json.

# %%
import json

with open('vk.json',  'r', encoding='Utf-8') as json_data:
    res_loaded = json.load(json_data) # считываем данные с помощью функции .load()

# %% [markdown]
# Здесь у нас выгрузка постов со стены группы ВШЭ.

# %%
res_loaded.keys()
# Out:
# dict_keys(['count', 'items'])

# %%
type(res_loaded['items'])
# Out:
# list

# %%
res_loaded['items'][0]
# Out:
# {'id': 32494,
#  'from_id': -132,
#  'owner_id': -132,
#  'date': 1541422799,
#  'marked_as_ads': 0,
#  'post_type': 'post',
#  'text': '',
#  'attachments': [{'type': 'link',
#    'link': {'url': 'http://family.hse.ru/event/view/2271',
#     'title': 'День карьеры факультета бизнеса и менеджмента',
#     'caption': 'family.hse.ru',
#     'description': '',
#     'photo': {'id': 456239093,
#      'album_id': -2,
#      'owner_id': 100,
#      'photo_75': 'https://pp.userapi.com/c850336/v850336548/628ea/TwPjzdADVZ4.jpg',
#      'photo_130': 'https://pp.userapi.com/c850336/v850336548/628eb/gMSUSljxiC8.jpg',
#      'photo_604': 'https://pp.userapi.com/c850336/v850336548/628ec/kIMEO_f_3JQ.jpg',
#      'width': 150,
#      'height': 80,
#      'text': '',
#      'date': 1541422799}}}],
#  'post_source': {'type': 'vk'},
#  'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#  'likes': {'count': 6, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#  'reposts': {'count': 2, 'user_reposted': 0},
#  'views': {'count': 2832}}

# %%
res_loaded['items'][1]
# Out:
# {'id': 32493,
#  'from_id': -132,
#  'owner_id': -132,
#  'date': 1541076555,
#  'marked_as_ads': 0,
#  'post_type': 'post',
#  'text': 'На Шаболовке 7 ноября в 18:30 ауд 5215 состоится встреча с представителем оргкомитета симпозиума, Lars John. Авторы лучших эссе получат возможность участвовать в симпозиуме в Швейцарии, а автор cамого лучшего эссе получит значительный денежный приз. Приглашаем всех студентов магистратуры, студентов 4 курса и аспирантов принять участие в этой встрече. \n \nTo all grad/postgrad and 4th year undergraduate students: compete until 1 Feb 2019 and qualify as a Leader of Tomorrow for the #49sgs (8–10 May 2019) in Switzerland, all expenses paid. Create an impact and win CHF 20,000. Leaders who have attended in the past include Niall Ferguson, Jack Ma, Christine Lagarde, Paul Polman, Anders Fogh Rasmussen, Ratan Tata, Muhammad Yunus, and many more. Register now at www.symp.sg/apply',
#  'post_source': {'type': 'vk'},
#  'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#  'likes': {'count': 2, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#  'reposts': {'count': 1, 'user_reposted': 0},
#  'views': {'count': 3943}}

# %%
res_loaded.keys()
# Out:
# dict_keys(['count', 'items'])

# %% [markdown]
# Ключами являются `count` и `items`. Нужные нам объекты (текст постов, id автора, дата и время публикации и проч.) находятся в `items`.

# %%
res_loaded['items'][50] # первый элемент items - первый пост со всей информацией о нем
# Out:
# {'id': 32099,
#  'from_id': -132,
#  'owner_id': -132,
#  'date': 1531760787,
#  'marked_as_ads': 0,
#  'post_type': 'post',
#  'text': '',
#  'copy_history': [{'id': 1050401,
#    'owner_id': -79138567,
#    'from_id': -79138567,
#    'date': 1531760410,
#    'post_type': 'post',
#    'text': 'В России есть проблемы с образованием, но часть из них можно решить с помощью грамотного менеджмента.\n\nМагистерская программа НИУ ВШЭ «Экономика и управление образованием» сделает из вас крутого специалиста. Вы научитесь руководить большими образовательными организациями и открывать собственные: школы, курсы, университеты и так далее. \n\nЗадавайте в Прямой линии свои вопросы о поступлении, будущей профессии и образовательном менеджменте:\n\nhttps://thequestion.ru/interview/5663/magistratura-niu-vshe-ekonomika-i-upravlenie-obrazovaniem#',
#    'attachments': [{'type': 'doc',
#      'doc': {'id': 469433958,
#       'owner_id': 27546726,
#       'title': 'school3.gif',
#       'size': 378724,
#       'ext': 'gif',
#       'url': 'https://vk.com/doc27546726_469433958?hash=ec0701bbf9cd8d84af&dl=GE3DOOJUGU3TA:1541538437:8a3c81805509fa7a05&api=1&no_preview=1',
#       'date': 1531742997,
#       'type': 3,
#       'preview': {'photo': {'sizes': [{'src': 'https://pp.userapi.com/c848028/u244342990/d18/-3/m_fab5b0b7f9.jpg',
#           'width': 130,
#           'height': 56,
#           'type': 'm'},
#          {'src': 'https://pp.userapi.com/c848028/u244342990/d18/-3/s_fab5b0b7f9.jpg',
#           'width': 100,
#           'height': 43,
#           'type': 's'},
#          {'src': 'https://pp.userapi.com/c848028/u244342990/d18/-3/x_fab5b0b7f9.jpg',
#           'width': 604,
#           'height': 256,
#           'type': 'x'},
#          {'src': 'https://pp.userapi.com/c848028/u244342990/d18/-3/o_fab5b0b7f9.jpg',
#           'width': 493,
#           'height': 209,
#           'type': 'o'}]},
#        'video': {'src': 'https://vk.com/doc27546726_469433958?hash=ec0701bbf9cd8d84af&dl=GE3DOOJUGU3TA:1541538437:8a3c81805509fa7a05&api=1&mp4=1',
#         'width': 492,
#         'height': 208,
#         'file_size': 25082}},
#       'access_key': 'e902820a909048fd1b'}},
#     {'type': 'link',
#      'link': {'url': 'https://thequestion.ru/interview/5663/magistratura-niu-vshe-ekonomika-i-upravlenie-obrazovaniem#',
#       'title': 'Задать вопрос Магистратура НИУ ВШЭ: экономика и управление образованием — TheQuestion',
#       'caption': 'thequestion.ru',
#       'description': ''}}],
#    'post_source': {'type': 'vk'}}],
#  'post_source': {'type': 'vk'},
#  'comments': {'count': 1, 'can_post': 1, 'groups_can_post': True},
#  'likes': {'count': 7, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#  'reposts': {'count': 0, 'user_reposted': 0},
#  'views': {'count': 7310}}

# %% [markdown]
# Помимо текста поста можно найти много всего интересного. Например, тип поста (`post_type`), дата (`date`), id поста (`id`), лайки (`likes`, которые включают информацию о том, могут ли пользователи лайкать пост и публиковать его, а также собственно число лайков), репосты (`reposts`, которые включают число репостов), число просмотров (`views`), комментарии (`comments`, которые включают информацию о том, могут ли пользователи комментировать пост, и число комментариев), и так далее.
#
# Давайте остановимся на тексте поста, id автора, id поста и дате публикации. Чтобы извлечь соответствующую информацию, сохраним `items` и извлечем из них нужные поля:

# %%
items = res_loaded['items']
full_list = []

for item in items:
    l = [item['from_id'], item['id'], item['text'], item['date']] # нужные поля
    full_list.append(l) # добавляем в список списков full_list
# несколько элементов списка
full_list[0:4]
# Out:
# [[-132, 32494, '', 1541422799],
#  [-132,
#   32493,
#   'На Шаболовке 7 ноября в 18:30 ауд 5215 состоится встреча с представителем оргкомитета симпозиума, Lars John. Авторы лучших эссе получат возможность участвовать в симпозиуме в Швейцарии, а автор cамого лучшего эссе получит значительный денежный приз. Приглашаем всех студентов магистратуры, студентов 4 курса и аспирантов принять участие в этой встрече. \n \nTo all grad/postgrad and 4th year undergraduate students: compete until 1 Feb 2019 and qualify as a Leader of Tomorrow for the #49sgs (8–10 May 2019) in Switzerland, all expenses paid. Create an impact and win CHF 20,000. Leaders who have attended in the past include Niall Ferguson, Jack Ma, Christine Lagarde, Paul Polman, Anders Fogh Rasmussen, Ratan Tata, Muhammad Yunus, and many more. Register now at www.symp.sg/apply',
#   1541076555],
#  [-132, 32492, '', 1540743239],
#  [-132, 32491, '', 1540551399]]

# %% [markdown]
# Видно, что в двух первых постах текста не обнаружено, там только картинки, ссылки и репосты.
#
# Из этого списка списков можно легко сделать датафрейм `pandas`.

# %% [markdown]
# Но если у ссылок, репостов и картинок нет текста, то наш DataFrame будет выглядет неполноценно. Поэтому добавим условие, что если текст отсутсвует, вставим в DataFrame строку с этой отметкой.

# %%
# опять выберем только нужные поля
full_list = []

for item in items:
    if item['text'] == "":
        l = [item['from_id'], item['id'], "Картинка, ссылка или репост", item['date']]
    else:
        l = [item['from_id'], item['id'], item['text'], item['date']]
    full_list.append(l)

# %%
full_list
# Out:
# [[-132, 32494, 'Картинка, ссылка или репост', 1541422799],
#  [-132,
#   32493,
#   'На Шаболовке 7 ноября в 18:30 ауд 5215 состоится встреча с представителем оргкомитета симпозиума, Lars John. Авторы лучших эссе получат возможность участвовать в симпозиуме в Швейцарии, а автор cамого лучшего эссе получит значительный денежный приз. Приглашаем всех студентов магистратуры, студентов 4 курса и аспирантов принять участие в этой встрече. \n \nTo all grad/postgrad and 4th year undergraduate students: compete until 1 Feb 2019 and qualify as a Leader of Tomorrow for the #49sgs (8–10 May 2019) in Switzerland, all expenses paid. Create an impact and win CHF 20,000. Leaders who have attended in the past include Niall Ferguson, Jack Ma, Christine Lagarde, Paul Polman, Anders Fogh Rasmussen, Ratan Tata, Muhammad Yunus, and many more. Register now at www.symp.sg/apply',
#   1541076555],
#  [-132, 32492, 'Картинка, ссылка или репост', 1540743239],
#  [-132, 32491, 'Картинка, ссылка или репост', 1540551399],
#  [-132, 32488, 'Картинка, ссылка или репост', 1540302306],
#  [-132,
#   32486,
#   '26-28 октября в Москве пройдет крупнейший в России международный хакатон Hack.Moscow \n \nНа 36 часов новая площадка 1С в Москве примет 450 участников из 47 стран. На протяжении Hack.Moscow участникам будут предложены 8 треков с заданиями по различным тематикам, образовательные лекции и воркшопы. \n \nХакатон – это событие для комьюнити разработчиков, насыщенное интеллектом, технологиями и атмосферой запуска проектов, где команды за короткий промежуток времени соревнуются в создании IT-продуктов. \n \nСобытие организовано крупнейшим комьюнити участников хакатонов Russian Hackers совместно с международной лигой MLH. Среди треков на хакатоне: AI, Big Data, Blockchain, CTF, Entertainment, Digitalization, E-commerce, Fintech. Партнеры мероприятия: .etc, IBM, Nvidia, Avast, Here, НИУ ВШЭ, Иннополис. \n \nЧто ждет участников: \n \n— кейсы от крупных компаний: 1C, МТС, Росбанк, Сибур, WorldQuant, Bankex, Cleverbots \n \n— атмосфера международного хакатона и команды со всего мира \n \n— призовой фонд и море стикеров и мерча \n \n— 32 GPU Nvidia Tesla v100 для любителей нейросетей от Reg.ru \n \n— менторы и серьезные спикеры \n \nРегистрация открыта до 22 октября. Приглашаются разработчики, дизайнеры, data scientists, продукты и проджекты. На хакатон можно зарегистрироваться как самостоятельно, так и командой. \n \nБольше информации на сайте',
#   1539863523],
#  [-132, 32485, 'Картинка, ссылка или репост', 1539781575],
#  [-132, 32484, 'Картинка, ссылка или репост', 1539718883],
#  [-132, 32481, 'Картинка, ссылка или репост', 1539088885],
#  [-132,
#   32480,
#   'Будущим магистрам! Новая программа Факультета бизнеса и менеджмента "HR-аналитика". Прием на программу начинается в 2019 году по конкурсу портфолио. https://management.hse.ru/news/225469321.html?_r=206801539081229.7121&__t=4005952&__r=OK',
#   1539088745],
#  [-132,
#   32478,
#   'Будущим магистрам! Новая программа факультета бизнеса и менеджмента (реализует Школа логистики) https://logistics.hse.ru/news/225353561.html',
#   1539016393],
#  [-132,
#   32476,
#   'До окончания регистрации в Осеннюю школу бизнес-проектов осталось 5 дней! \nРегистрация школьников 9-11 классов на Осеннюю школу бизнес-проектов (учебный центр "Вороново"). Школу проводит Факультет бизнеса и менеджмента НИУ ВШЭ совместно с Дирекцией по профориентации и по работе с талантливой молодежью. Регистрация https://shkolnikam.hse.ru/projectsc',
#   1538752645],
#  [-132, 32475, 'Картинка, ссылка или репост', 1538640660],
#  [-132,
#   32474,
#   'Продолжается регистрация школьников 9-11 классов на Осеннюю школу бизнес-проектов (учебный центр "Вороново"). Школу проводит Факультет бизнеса и менеджмента НИУ ВШЭ совместно с Дирекцией по профориентации и по работе с талантливой молодежью. Регистрация https://shkolnikam.hse.ru/projectsc',
#   1538513448],
#  [-132,
#   32472,
#   'Для абитуриентов Школа логистики факультета бизнеса и менеджмента готовит цикл семинаров в декабре. Приглашают всех желающих https://logistics.hse.ru/announcements/224770564.html',
#   1538477565],
#  [-132, 32471, 'Картинка, ссылка или репост', 1538044277],
#  [-132,
#   32470,
#   'Приглашаем 29 октября - 4 ноября школьников 9-11 классов на Осеннюю школу бизнес-проектов в учебный центр "Вороново". Школу проводит Факультет бизнеса и менеджмента НИУ ВШЭ совместно с Дирекцией по профориентации и по работе с талантливой молодежью. Регистрация https://shkolnikam.hse.ru/projectsc',
#   1537815734],
#  [-132,
#   32469,
#   'Привет! Ты начинающий дизайнер, программист или, может быть, хочешь сделать свой стартап? Тогда приглашаем тебя на презентацию Russian Hackers, где мы расскажем о хакатонах — месте, в котором ты сможешь развить все нужные навыки, найти знакомых для реализации своих идей и просто весело, но с пользой провести время. \n \nЖдем тебя в Таблице (Новослободская ул., 16) 26 сентября. Не забудь зарегистрироваться! \n\nСсылка: https://russian-hacker.timepad.ru/event/800309/',
#   1537779781],
#  [-132, 32467, 'Картинка, ссылка или репост', 1537450286],
#  [-132, 32465, 'Картинка, ссылка или репост', 1537357519],
#  [-132, 32464, 'Картинка, ссылка или репост', 1537356318],
#  [-132,
#   32462,
#   'Иванова Валерия Станиславовна, документы найдены, контакт https://m.vk.com/smotra.drift',
#   1537168381],
#  [-132,
#   32459,
#   'Факультет бизнеса и менеджмента совместно с Дирекцией по профориентации и работе с талантливой молодежью НИУ ВШЭ открывает регистрация старшеклассников для участия в Осенней Школе Бизнес-Проектов (ОШБП-2018). Школа пройдет с 29.10. по 4.11 в учебном центре "Вороново". https://shkolnikam.hse.ru/projectsc',
#   1536952253],
#  [-132, 32458, 'Картинка, ссылка или репост', 1536776359],
#  [-132, 32457, 'Картинка, ссылка или репост', 1536747843],
#  [-132,
#   32448,
#   'С началом нового учебного года коллектив университета поздравил Министр науки и высшего образования https://www.hse.ru/news/edu/222831157.html',
#   1535952929],
#  [-132,
#   32447,
#   'В НИУ ВШЭ открывается новый факультет подготовки урбанистов https://www.hse.ru/news/edu/222771701.html',
#   1535952608],
#  [-132,
#   32444,
#   'Начинаем учебу вместе [club167415981|HSE WELCOME PARTY 2018]! \n \nОтпразднуй долгожданное поступление в Вышку и новый учебный год на грандиозной общеуниверситетской вечеринке! Создатели [club164898180|Выпускного НИУ ВШЭ 2018] и [club150271576|HSE Welcome Party 2017], [club76064811|NoSilence] по традиции радуют вышкинцев поводом потусить. \n \nТебя ждет яркая программа, громкие танцевальные хиты, крутые сюрпризы и, конечно, потрясающий хэдлайнер – музыкальная группа [club9304590|Brevis Brass]. Звучит заманчиво? Тогда присоединяйся! \n \n8 сентября. Клуб [club31338548|PRAVDA]. \n \nУспей купить билет онлайн. Вся подробная информация в [club167415981|группе мероприятия Вконтакте].',
#   1535657976],
#  [-132,
#   32443,
#   'Приглашаем на День Вышки по традиции в сентябре в Парк им.Горького!\n Подробнее о программе праздника https://www.hse.ru/day2018/',
#   1535657872],
#  [-132, 32437, 'Картинка, ссылка или репост', 1534807953],
#  [-132, 32433, 'Картинка, ссылка или репост', 1534409167],
#  [-132,
#   32431,
#   'Вышка побила все рекорды по набору в бакалавриат. Поздравляем первокурсников, которые сделали правильный выбор и влились в ряды нашего студенчества. Удачи и незабываемых лет в Вышке! https://www.hse.ru/news/admission/222366438.html',
#   1534187126],
#  [-132, 32429, 'Картинка, ссылка или репост', 1533892715],
#  [-132, 32427, 'Картинка, ссылка или репост', 1533832438],
#  [-132, 32426, 'Картинка, ссылка или репост', 1533754950],
#  [-132, 32425, 'Картинка, ссылка или репост', 1533754924],
#  [-132, 32422, 'Картинка, ссылка или репост', 1533665811],
#  [-132, 32416, 'Картинка, ссылка или репост', 1533504609],
#  [-132, 32415, 'Картинка, ссылка или репост', 1533504583],
#  [-132, 32369, 'Картинка, ссылка или репост', 1533031913],
#  [-132,
#   32282,
#   'Уважаемые абитуриенты! Порядок приема предполагает издание двух приказов о зачислении. Рекомендация бывалых: поторопитесь принести оригиналы раньше, чтобы попасть в первый приказ (80% контрольных цифр приема). При определении проходного балла есть риски "перебрать" бюджет. Не все абитуриенты относятся ответственно к проводимому вузом мониторингу, многие не приняли решение о приоритетной программе и вузе до последнего или не выходят на связь. В случае, если проходной балл будет ниже реального, сверхплановые абитуриенты будут приняты на обучение по контракту со скидкой 100%. Потребуется заключение договора с вузом. Прием подлинников 7 дней в неделю по расписанию.https://ba.hse.ru/graf2018',
#   1532836790],
#  [-132, 32263, 'Картинка, ссылка или репост', 1532805701],
#  [-132,
#   32158,
#   'Идет заседание приемной комиссии НИУ ВШЭ. Определяем параметры зеленой и желтой волны для бакалавриата',
#   1532780290],
#  [-132,
#   32155,
#   'Магистратура "Менеджмент в ритейле". Что вам об этом известно?\nЧто нужно делать сейчас, чтобы обеспечить себе богатое будущее? \nИзвестнейшее агентство финансовой информации Bloomberg любит считать деньги в карманах сверхбогатых. Многие годы богатейшими людьми были IT-предприниматели, однако в последнее время они отступили с золотого пьедестала! Так кто теперь самый богатый человек на планете? Это владелец онлайн ритейлера Amazon Джефф Безос, с оценкой состояния в 150 миллиардов долларов он серьёзно вырвался вперёд, так у следующего вторым Билла Гейтса сейчас менее 100 миллиардов. При этом если взглянуть на Топ-20 самых богатых людей планеты, обнаружится 8 миллиардеров, построивших свои бизнес-империи в ритейле. Среди них Бернар Арно (№4, Louis Vuitton Moët Hennessy), Амансио Ортего (№5, Zara, Inditex), Франсуаза Бетенкур Майерс (№11, L\'Oreal), Джек Ма (№14, Alibaba), Джим, Роб и Алиса Волтон (№16-18, Walmart). \nПолучается, что ритейл в современном мире постмодерна не только даёт работу миллионам россиян, но и куёт миллиардеров. Учитывая этот тренд факультет бизнеса и менеджмента открыл магистерскую программу "Менеджмент в ритейле" ( https://www.hse.ru/ma/retail/ ). Подать документы на которую можно до 15 августа! \nУспей освоить денежную профессию!',
#   1532766560],
#  [-132,
#   32113,
#   'Уважаемые абитуриенты! Мы получаем много вопросов по порядку зачисления в наш университет. Сейчас приемная кампания вступает в финальную стадию, напряжение растет. Мы прекрасно это понимаем. Поэтому кратко отвечаем на вопросы, несмотря на ночь\nИтак, \n-если вам позвонили с какой-либо программы любого вуза и сказали, что вы прошли по конкурсу - это предположение, но не факт (кроме вузов с ДВИ). 27 появятся ранжированные списки, и 28 вечером - проходные баллы (после заседания приемной комиссии). Мониторинг абитуриентов дает вузам некоторые ориентиры для подведения итогов, но не является точным источником данных о предпочтениях абитуриентов;\n- наличие подлинника на программе не означает, что вас обязательно зачислят на бюджетное место, ровно как и не означает, что с копией вы не можете на него претендовать; все участники конкурса равны в правах\n- в НИУ ВШЭ нет никаких первых и вторых списков абитуриентов, а есть зеленая волна (гарантия поступления) и желтая (прогнозный лист ожидания, не дающий гарантий).\n- если вы попадаете в приказ с подлинником в любом вузе, а позже прошли по конкурсу в приоритетный вуз, вам обязаны вернуть подлинник по заявлению в течение суток;\n- первый приказ (зачисление 80% на программы) издается 3 августа, второй - 8 августа. Теоретически вы можете гулять с подлинником до 6 числа. Однако, повышается риск не попасть на бюджетное место. Если в зоне проходного балла будет перебор подлинников, то наш вуз зачислит вас на коммерческое обучение со скидкой 100%. Настоятельно советуем принести подлинник до 1 августа на выбранную программу, чтобы попасть на бюджетное место, а не коммерческое.\nВсем удачи!',
#   1532642656],
#  [-132,
#   32111,
#   'Совмещение работы и учебы в магистратуре — вопрос, который волнует многих абитуриентов. Стоит ли оставаться в вузе еще на два года? А не будет ли это мешать моей работе? \n \nОтвечает руководитель магистерской программы «Прикладная статистика и сетевой анализ»:\n\nhttps://thequestion.ru/questions/416150/naskolko-realno-sovmeshat-rabotu-s-obucheniem?utm_campaign=editorial&utm_source=vk&utm_medium=social',
#   1532597211],
#  [-132, 32110, 'Картинка, ссылка или репост', 1532366305],
#  [-132,
#   32109,
#   'Абитуриентам медиакома https://www.youtube.com/watch?v=RdJ0dl0rKFc&feature=youtu.be',
#   1532287305],
#  [-132,
#   32107,
#   'Сейчас в Вышке идет набор абитуриентов на магистерскую программу двойных дипломов Варшавского, Кельнского университетов «Культурная и интеллектуальная история: между Востоком и Западом». \nТам, \n1) Каждый студент может получить 2 диплома (помимо Вышки, Кельнский и Варшавский университеты; в 2019 году бельгийский Лувен); \n \n2) Выпускной работой по итогом программы может стать не диссертация, но научно-популярный фильм или серьезная выставка; \n \n3) Поступление на немецкий трек возможно при знании английского (C1), а не немецкого; \n \n4) Индивидуальный план обучения с первого дня (70% дисциплин по выбору); \n \n5) Портфолио можно обсудить очно-заочно, оно может быть подано онлайн (до 31 июля). Собеседование может быть проведено онлайн; \n \nОписание вашего будущего проекта в рамках этой программы для подачи документов может не быть слишком подробным, главное, обозначить личные предпосылки: где и чему вы учились, какова реальная база знаний о предмете, которым собираетесь заниматься, какой цели хотите добиться при написании магистерской диссертации. \n \nПодробнее на официальной страничке https://www.facebook.com/culteastwesthse/ \n \nсайте https://www.hse.ru/ma/inhist/',
#   1532111243],
#  [-132, 32106, 'Картинка, ссылка или репост', 1531991571],
#  [-132, 32099, 'Картинка, ссылка или репост', 1531760787],
#  [-132,
#   32098,
#   'Вниманию абитуриентов бакалавриата! Мы начинаем мониторинг абитуриентов. Что это означает? Вам могут позвонить и попросить выделить приоритетный для поступления вуз и приоритетную программу (если Вышка приоритет изначально). Это информационный обзвон, но именно он является ориентиром для университета при подведении итогов и определении параметров "зеленой волны", гарантирующей поступление на бюджетные места. Чем точнее вы сформулируете свою траекторию поступления, тем точнее мы определим проходной балл. Дорогие абитуриенты, мы рассчитываем на сотрудничество с вами! Подробнее о нашей уникальной "зеленой волне" в репортаже https://www.hse.ru/news/admission/221487317.html',
#   1531756022],
#  [-132, 32096, 'Картинка, ссылка или репост', 1531498280],
#  [-132, 32080, 'Картинка, ссылка или репост', 1530637905],
#  [-132,
#   32079,
#   'Бакалавриат. "Цифровые инновации в управлении предприятием" Встреча с академическим руководителем новой программы двух дипломов, которую открывает НИУ ВШЭ совместно с Лондонским университетом. Приглашаем 4 июля на экспертную сессию https://www.hse.ru/ba/digital/news/220942802.html',
#   1530558343],
#  [-132, 32078, 'Картинка, ссылка или репост', 1530551271],
#  [-132,
#   32074,
#   'Магистерская программа «Управление в социальной сфере» готовит управленческие кадры и аналитиков по вопросам социальной политики и социально-экономического развития. Каждый студент может выбрать аналитический или управленческий трек. Выпускники смогут изучать значимые общественные процессы, выявлять негативные факторы, а также предлагать меры их предотвращения, смягчения и преодоления. В Прямой линии академический руководитель программы ответит на вопросы о поступлении, содержании программы и карьерных перспективах.\n\nhttps://thequestion.ru/interview/5663/magistratura-niu-vshe-upravlenie-v-socialnoi-sfere#/',
#   1530180715],
#  [-132, 32073, 'Картинка, ссылка или репост', 1530069620],
#  [-132,
#   32072,
#   'Новая англоязычная программа двойных дипломов, (открыта совместно с Лондонским университетом) приглашает абитуриентов. Направление "Бизнес-информатика". https://www.hse.ru/ba/digital/',
#   1530036059],
#  [-132,
#   32071,
#   'Многогранная Вышка занимается и исследованиями в области спорта. К Чемпионату мира по футболу',
#   1529990821],
#  [-132, 32070, 'Картинка, ссылка или репост', 1529960004],
#  [-132,
#   32069,
#   'Вчера в "Крокус-Сити" холле отгремел выпускной Лицея НИУ ВШЭ. 8 профилей, 701 выпускник, из которых 121 медалист. Мы ждем выпускников в Большой Вышке! https://www.youtube.com/watch?time_continue=8&v=fHCt_wXXYyE',
#   1529923013],
#  [-132,
#   32068,
#   'Консультации сотрудников и студентов факультетов проводятся по графику в вестибюле по адресу Мясницкая 9-11 график работы консультантов https://ba.hse.ru/dod_summer',
#   1529921237],
#  [-132, 32067, 'Картинка, ссылка или репост', 1529907232],
#  [-132,
#   32066,
#   'Академические руководители программ бакалавриата встречаются с абитуриентами в период подачи документов. Приглашаем выпускников, родителей. Расписание https://ba.hse.ru/meet2018',
#   1529907221],
#  [-132,
#   32065,
#   'Приглашаем в магистратуру направления "Менеджмент"! День открытых дверей',
#   1529831748],
#  [-132,
#   32064,
#   'Памятка абитуриенту бакалавриата и магистратуры НИУ ВШЭ https://www.hse.ru/news/admission/220450757.html',
#   1529611517],
#  [-132,
#   32063,
#   'В 2018 году в Вышке открывают новую образовательную программу двух дипломов с Лондонским университетом - Цифровые инновации в управлении предприятием! \n \nЕсли коротко, то после обучения на этой программе, у тебя появятся отличные перспективы войти в число digerati — высококвалифицированных специалистов, активно применяющих в своей деятельности весь спектр цифровых технологий. «Полученные студентами навыки очень пригодятся на должностях, которые в ближайшие десять лет будут одними из самых востребованных на рынке труда», - говорит руководитель программы Сергей Ефремов. \n \nПеред тобой откроются новые возможности не только в российских, но и зарубежных IT-компаниях, аналитических и интернет-компаниях, различных инновационных и венчурных фондах. Ты сможешь выступать в роли консультанта по последним технологиям и инновационным решениям в сфере IT, разрабатывать рекомендации по архитектуре цифровых продуктов и услуг, контролировать ход технологических проектов по внедрению инноваций и многое-многое другое. \n \nЕсли такая перспектива кажется тебе интересной, welcome :) Новости и информация о программе публикуются в группе: https://vk.com/hse_ba_digital',
#   1529581970],
#  [-132,
#   32062,
#   'Встречу с абитуриентами и родителями абитуриентов бакалавриата проводит академический руководитель образовательной программы "Маркетинг и рыночная аналитика" В.Ребязина. Мы ждем вас 2 июля в 11-00 на Мясницкой 9-11',
#   1529574271],
#  [-132,
#   32061,
#   'Встречу с абитуриентами и родителями абитуриентов бакалавриата проводит академический руководитель образовательной программы "Управление бизнесом" М.Дворяшина. Мы ждем вас 28 июня в 11-00 на Мясницкой 9-11',
#   1529574186],
#  [-132,
#   32060,
#   'IV Международная конференция завершилась на Факультете бизнеса и менеджментаhttps://bi.hse.ru/news/220417442.html',
#   1529573485],
#  [-132,
#   32059,
#   'Школа логистики приглашает абитуриентов бакалавриата и магистратуры https://logistics.hse.ru/announcements/220022865.html',
#   1529573055],
#  [-132,
#   32058,
#   'Абитуриентам магистратуры направления "Бизнес-информатика".\nПрограмма консультаций по подготовке к экзамену на магистерскую программу по направлению - бизнес-информатика: \n29 июня с 12.00, аудитория 534, Кирпичная, 33 -профессор Грекул В.И., преподаватель Горбунов А.А., старший преподаватель Тарасов П.А. \n1. Теоретические основы информационных технологий \n2. Основные этапы создания информационных систем. \n3. Базы данных \n4. Совершенствование бизнес-процессов \n17 июля с 19.00, аудитория 534 -доцент Моргунов А.Ф. Архитектура информационных систем. \n31 июля с 18.00, аудитория 534 -доцент Ямпольский С.М., доцент Романов Д.А., профессор Кирсанов А.П., профессор Грекул В.И. \n1. Теоретические основы информационных технологий \n2. Основные этапы создания информационных систем. \n3. Базы данных \n4. Совершенствование бизнес-процессов',
#   1529572620],
#  [-132,
#   32057,
#   'Абитуриентам бакалавриата! Направление "Бизнес-информатика" 4 июля (11:00 -13:00) – Встречи руководителей образовательных программ с поступающими в 2018, ул. Мясницкая, д 9-.11 \nШколу Бизнес-информатики представляют: \nСамодуров Владимир Алексеевич, к.ф.-м.н., заместитель руководителя по работе с абитуриентами и выпускниками Школы бизнес-информатики Факультета бизнеса и менеджмента; \nДмитриев Андрей Викторович, профессор, д.ф.-м.н., академический руководитель образовательной программы: Бизнес-информатика \nЕфремов Сергей Геннадьевич, доцент, к.т.н., руководитель образовательной программы: Цифровые инновации в управлении предприятием (программа двух дипломов НИУ ВШЭ и Лондонского университета) \nОпределенов Владимир Викторович, заведующий кафедрой ИТ в сфере культуры ФБиМ ШБИ НИУ ВШЭ (bi.hse.ru/cultureit/), заместитель директора ГМИИ им. А.С. Пушкина по ИТ (www.arts-museum.ru)',
#   1529572480],
#  [-132, 32056, 'Картинка, ссылка или репост', 1529448595],
#  [-132, 32055, 'Картинка, ссылка или репост', 1529343837],
#  [-132,
#   32054,
#   'Выпускники- 2018! Вас приглашает Факультет бизнеса и менеджмента на День открытых дверей Школы логистики https://logistics.hse.ru/announcements/220022865.html',
#   1529303635],
#  [-132, 32053, 'Картинка, ссылка или репост', 1527716601],
#  [-132, 32052, 'Картинка, ссылка или репост', 1527716594],
#  [-132,
#   32051,
#   'Компания КРОК приглашает:\nПривет! Этим летом тебя ждёт IT-жара! \nУспей подать заявку в «Летние школы» КРОК, чтобы не пропустить полезный нетворкинг, получить новые знания и опыт работы с одной из крупнейших IT-компаний в России. \nНаправления подготовки: \n• разработка программного обеспечения с 9 по 20 июля \n• телекоммуникации с 2 по 13 июля \n• построение IT-инфраструктуры современных компаний с 16 по 27 июля \n• разработка многомерного хранилища данных с 15 по 29 июля, с 6 по 20 августа \nКто может принять участие? Студенты 2-6 курсов технических вузов. \nСрок обучения: 2-3 недели (в июле – августе). \nГде? В офисе КРОК в Москве (м. Площадь Ильича/ Римская, ул. Волочаевская, д. 5, корп. 1) \nПрием заявок: до 20 июня 2018 г. \nВажно! Участие бесплатное. \nУзнать более детальную информацию о программе и зарегистрироваться ты можешь по ссылке. http://www.croc.ru/vacancy/students/detail/79855/\nДо встречи!',
#   1527538730],
#  [-132,
#   32050,
#   'Сбываются мечты Е.Г.Ясина. Вышка выращивает не только профессоров и миллионеров, но и министров. Второй министр (первый - выпускник ЭФ Орешкин возглавил Минфин) в правительстве РФ из НИУ ВШЭ. На этот раз - выпускник факультета бизнеса и менеджмента. Пожелаем Константину Носкову успехов! https://bm.hse.ru/news/219436492.html',
#   1527080728],
#  [-132, 32049, 'Картинка, ссылка или репост', 1527078739],
#  [-132, 32048, 'Картинка, ссылка или репост', 1527078368],
#  [-132,
#   32047,
#   'Павел Алферов, Дмитрий Маев, Valery Anshin, Николай Филинов и Jesus Martinez-Almela в Higher School of Economics. \nКонференция по управлению проектами в НИУ ВШЭ. У микрофона заведующий кафедрой управления проектами Школы бизнеса и делового администрирования Факультета бизнеса и менеджмента',
#   1527078310],
#  [-132, 32046, 'Картинка, ссылка или репост', 1526849884],
#  [-132, 32045, 'Картинка, ссылка или репост', 1525030127],
#  [-132,
#   32044,
#   'Вакансия для студентов Вышки от коллег из ADIDAS https://vacancy.adidas.ru/ru/retail/response',
#   1524946182],
#  [-132, 32043, 'Картинка, ссылка или репост', 1524895899],
#  [-132,
#   32042,
#   '1С приглашает на хакатон http://student.1c.ru/msk/',
#   1524895678],
#  [-132,
#   32041,
#   'Они сделали это! Первый международный хакатон в России под эгидой MLH успешно провели студенты НИУ ВШЭ (образовательная прогамма "Бизнес-информатика" Факультета бизнеса и менеджмента") https://bm.hse.ru/news/218706777.html',
#   1524895128],
#  [-132, 32039, 'Картинка, ссылка или репост', 1524425196],
#  [-132, 32038, 'Картинка, ссылка или репост', 1524137966],
#  [-132,
#   32037,
#   'Хочешь получить востребованную высокооплачиваемую специальность? Посети вебинар магистерской программы "Маркетинг", который пройдет 19 апреля в 18:30! Узнай подробности о поступлении, обучении и успехах выпускников от преподавателей и студентов программы. Регистрируйся и приходи! https://events.webinar.ru/2972343/1014021',
#   1524137943],
#  [-132,
#   32036,
#   '21 апреля состоится первый экологический бизнес-форум «Eco+номика: инновации в использовании ресурсов и новый стиль жизни» в НИУ ВШЭ! \n\nСтать участником просто – регистрируйтесь по ссылке: https://greenhse.timepad.ru/event/689540 \n\nВремя, проведенное на форуме, вы точно потратите не зря, потому что вас ждут: \n1. Гостевые лекции на тему проблем экологии в России и путей их решения от ИКЕА, KPMG, UPM, GreenPeace и других \n2. Круглый стол "Сжигать нельзя перерабатывать: как создать в России эффективный способ переработки отходов?" \n3. Игровой практикум "Используй разумно" и воркшоп по эко-брендингу \n4. Презентации лучших экологических практик стартапов и студенческих организаций \n5. Возможность попасть на стажировку в ведущие компании \n\nСледите за новостями в группе форума https://vk.com/economicaforum и участвуйте в конкурсе: https://vk.com/economicaforum?w=wall-163781621_11 \n\nДобавляйте в свой календарь: \n🌱21 апреля \n🌱Ул. Шаболовка, д. 26 \n🌱Приходить можно в любое время с 11 до 17:30. \n\nРегистрируйтесь по ссылке: https://greenhse.timepad.ru/event/689540 \nПриходите на форум Eco+номика!',
#   1523905424],
#  [-132,
#   32035,
#   'Пользователь https://vk.com/eugene753 нашел стденческий билет Великой (МИРЭК, скорее всего). Найдите девушку, коллеги!',
#   1523905292],
#  [-132,
#   32034,
#   'Приглашаем на вебинар абитуриентов магистратуры https://www.hse.ru/webinar/announcements/215213845.html',
#   1523905024],
#  [-132,
#   32033,
#   'Студенты факультета бизнеса и менеджмента организовали 1-Й Медунаодный хакатон под эгидой MLH. Первый 12-часовой хакатон успешно проведен в декабре. Теперь - международный формат, 36 часов невероятного напряжения сил, интеллекта, море драйва, интересные задания от ведущих компаний, крутые спикеры, призы от спонсоров! Регистрация https://bi.hse.ru/announcements/218106089.html',
#   1523904989],
#  [-132, 32032, 'Картинка, ссылка или репост', 1523779453],
#  [-132, 32031, 'Картинка, ссылка или репост', 1523696547],
#  [-132, 32030, 'Картинка, ссылка или репост', 1523696439]]

# %% [markdown]
# Оставлось превратить обновленный список `items` (список списков) в датафрейм. Импортируем `pandas`.

# %%
import pandas as pd

# %% [markdown]
# Создадим датафрейм:

# %%
df = pd.DataFrame(full_list, columns = ['From_id', 'Id', 'Text', 'Date_Unix'])
df.head(10)
# Out:
#    From_id     Id                                               Text  \
# 0     -132  32494                        Картинка, ссылка или репост
# 1     -132  32493  На Шаболовке 7 ноября в 18:30 ауд 5215 состоит...
# 2     -132  32492                        Картинка, ссылка или репост
# 3     -132  32491                        Картинка, ссылка или репост
# 4     -132  32488                        Картинка, ссылка или репост
# 5     -132  32486  26-28 октября в Москве пройдет крупнейший в Ро...
# 6     -132  32485                        Картинка, ссылка или репост
# 7     -132  32484                        Картинка, ссылка или репост
# 8     -132  32481                        Картинка, ссылка или репост
# 9     -132  32480  Будущим магистрам! Новая программа Факультета ...
#
#     Date_Unix
# 0  1541422799
# 1  1541076555
# 2  1540743239
# 3  1540551399
# 4  1540302306
# 5  1539863523
# 6  1539781575
# 7  1539718883
# 8  1539088885
# 9  1539088745

# %% [markdown]
# С датой все интереснее. То, что указано в столбце `date`, это дата в виде UNIX-времени (POSIX-времени). Это число секунд, прошедших с 1 января 1970 года. Несмотря на то, что такой формат даты-времени кажется необычным, он довольно широко распространен в разных системах и приложениях. Этот факт, конечно, радует, но хочется получить дату в более человеческом формате. Давайте напишем функцию для перевода UNIX-времени в формат год-месяц-день-часы-минуты-секунды. Для этого нам понадобится модуль datetime.

# %%
from datetime import datetime

# %%
def date_norm(date):
    
    """Получает на вход строку данных времени в формате POSIX. 
    Возвращает кортеж (ГГГГ-ММ-ДД, ЧЧ:ММ:СС)"""
    
    d = datetime.fromtimestamp(date) # timestamp - UNIX-время в виде строки
    str_d = d.strftime("%Y-%m-%d %H:%M:%S") # %Y-%m-%d %H:%M:%S - год-месяц-день, часы:минуты:секунды
    date_norm, time_norm = str_d.split() # разобьем результат на части, отделим дату от времени
    return date_norm, time_norm

# %%
datetime.fromtimestamp(1539088745).strftime("%Y-%m-%d %H:%M:%S")
# Out:
# '2018-10-09 15:39:05'

# %%
# ?date_norm

# %% [markdown]
# Применим нашу функцию к элементам столбца date и создадим новый ‒ `date_norm`.

# %%
df['Date_Norm'] = df.Date_Unix.apply(date_norm)

# %%
df.head()
# Out:
#    From_id     Id                                               Text  \
# 0     -132  32494                        Картинка, ссылка или репост
# 1     -132  32493  На Шаболовке 7 ноября в 18:30 ауд 5215 состоит...
# 2     -132  32492                        Картинка, ссылка или репост
# 3     -132  32491                        Картинка, ссылка или репост
# 4     -132  32488                        Картинка, ссылка или репост
#
#     Date_Unix               Date_Norm
# 0  1541422799  (2018-11-05, 15:59:59)
# 1  1541076555  (2018-11-01, 15:49:15)
# 2  1540743239  (2018-10-28, 19:13:59)
# 3  1540551399  (2018-10-26, 13:56:39)
# 4  1540302306  (2018-10-23, 16:45:06)

# %% [markdown]
# Можно было, конечно, не разбивать на части дату и время, сохранять одной строкой. А можно написать функции, которые будут отделять дату от времени ‒ извлекать их из кортежа в date_norm.

# %%
df['Date'] = df.Date_Norm.apply(lambda x: x[0])
df['Time'] = df.Date_Norm.apply(lambda x: x[1])
df.head()
# Out:
#    From_id     Id                                               Text  \
# 0     -132  32494                        Картинка, ссылка или репост
# 1     -132  32493  На Шаболовке 7 ноября в 18:30 ауд 5215 состоит...
# 2     -132  32492                        Картинка, ссылка или репост
# 3     -132  32491                        Картинка, ссылка или репост
# 4     -132  32488                        Картинка, ссылка или репост
#
#     Date_Unix               Date_Norm        Date      Time
# 0  1541422799  (2018-11-05, 15:59:59)  2018-11-05  15:59:59
# 1  1541076555  (2018-11-01, 15:49:15)  2018-11-01  15:49:15
# 2  1540743239  (2018-10-28, 19:13:59)  2018-10-28  19:13:59
# 3  1540551399  (2018-10-26, 13:56:39)  2018-10-26  13:56:39
# 4  1540302306  (2018-10-23, 16:45:06)  2018-10-23  16:45:06

# %%
del df['Date_Norm']

# %%
df.head()
# Out:
#    From_id     Id                                               Text  \
# 0     -132  32494                        Картинка, ссылка или репост
# 1     -132  32493  На Шаболовке 7 ноября в 18:30 ауд 5215 состоит...
# 2     -132  32492                        Картинка, ссылка или репост
# 3     -132  32491                        Картинка, ссылка или репост
# 4     -132  32488                        Картинка, ссылка или репост
#
#     Date_Unix        Date      Time
# 0  1541422799  2018-11-05  15:59:59
# 1  1541076555  2018-11-01  15:49:15
# 2  1540743239  2018-10-28  19:13:59
# 3  1540551399  2018-10-26  13:56:39
# 4  1540302306  2018-10-23  16:45:06

# %%
df[df['Text'] != 'Картинка, ссылка или репост']
# Out:
#     From_id     Id                                               Text  \
# 1      -132  32493  На Шаболовке 7 ноября в 18:30 ауд 5215 состоит...
# 5      -132  32486  26-28 октября в Москве пройдет крупнейший в Ро...
# 9      -132  32480  Будущим магистрам! Новая программа Факультета ...
# 10     -132  32478  Будущим магистрам! Новая программа факультета ...
# 11     -132  32476  До окончания регистрации в Осеннюю школу бизне...
# 13     -132  32474  Продолжается регистрация школьников 9-11 класс...
# 14     -132  32472  Для абитуриентов Школа логистики факультета би...
# 16     -132  32470  Приглашаем 29 октября - 4 ноября школьников 9-...
# 17     -132  32469  Привет! Ты начинающий дизайнер, программист ил...
# 21     -132  32462  Иванова Валерия Станиславовна, документы найде...
# 22     -132  32459  Факультет бизнеса и менеджмента совместно с Ди...
# 25     -132  32448  С началом нового учебного года коллектив униве...
# 26     -132  32447  В НИУ ВШЭ открывается новый факультет подготов...
# 27     -132  32444  Начинаем учебу вместе [club167415981|HSE WELCO...
# 28     -132  32443  Приглашаем на День Вышки по традиции в сентябр...
# 31     -132  32431  Вышка побила все рекорды по набору в бакалаври...
# 40     -132  32282  Уважаемые абитуриенты! Порядок приема предпола...
# 42     -132  32158  Идет заседание приемной комиссии НИУ ВШЭ. Опре...
# 43     -132  32155  Магистратура "Менеджмент в ритейле". Что вам о...
# 44     -132  32113  Уважаемые абитуриенты! Мы получаем много вопро...
# 45     -132  32111  Совмещение работы и учебы в магистратуре — воп...
# 47     -132  32109  Абитуриентам медиакома https://www.youtube.com...
# 48     -132  32107  Сейчас в Вышке идет набор абитуриентов на маги...
# 51     -132  32098  Вниманию абитуриентов бакалавриата! Мы начинае...
# 54     -132  32079  Бакалавриат. "Цифровые инновации в управлении ...
# 56     -132  32074  Магистерская программа «Управление в социально...
# 58     -132  32072  Новая англоязычная программа двойных дипломов,...
# 59     -132  32071  Многогранная Вышка занимается и исследованиями...
# 61     -132  32069  Вчера в "Крокус-Сити" холле отгремел выпускной...
# 62     -132  32068  Консультации сотрудников и студентов факультет...
# 64     -132  32066  Академические руководители программ бакалавриа...
# 65     -132  32065  Приглашаем в магистратуру направления "Менеджм...
# 66     -132  32064  Памятка абитуриенту бакалавриата и магистратур...
# 67     -132  32063  В 2018 году в Вышке открывают новую образовате...
# 68     -132  32062  Встречу с абитуриентами и родителями абитуриен...
# 69     -132  32061  Встречу с абитуриентами и родителями абитуриен...
# 70     -132  32060  IV Международная конференция завершилась на Фа...
# 71     -132  32059  Школа логистики приглашает абитуриентов бакала...
# 72     -132  32058  Абитуриентам магистратуры направления "Бизнес-...
# 73     -132  32057  Абитуриентам бакалавриата! Направление "Бизнес...
# 76     -132  32054  Выпускники- 2018! Вас приглашает Факультет биз...
# 79     -132  32051  Компания КРОК приглашает:\nПривет! Этим летом ...
# 80     -132  32050  Сбываются мечты Е.Г.Ясина. Вышка выращивает не...
# 83     -132  32047  Павел Алферов, Дмитрий Маев, Valery Anshin, Ни...
# 86     -132  32044  Вакансия для студентов Вышки от коллег из ADID...
# 88     -132  32042  1С приглашает на хакатон http://student.1c.ru/...
# 89     -132  32041  Они сделали это! Первый международный хакатон ...
# 92     -132  32037  Хочешь получить востребованную высокооплачивае...
# 93     -132  32036  21 апреля состоится первый экологический бизне...
# 94     -132  32035  Пользователь https://vk.com/eugene753 нашел ст...
# 95     -132  32034  Приглашаем на вебинар абитуриентов магистратур...
# 96     -132  32033  Студенты факультета бизнеса и менеджмента орга...
#
#      Date_Unix        Date      Time
# 1   1541076555  2018-11-01  15:49:15
# 5   1539863523  2018-10-18  14:52:03
# 9   1539088745  2018-10-09  15:39:05
# 10  1539016393  2018-10-08  19:33:13
# 11  1538752645  2018-10-05  18:17:25
# 13  1538513448  2018-10-02  23:50:48
# 14  1538477565  2018-10-02  13:52:45
# 16  1537815734  2018-09-24  22:02:14
# 17  1537779781  2018-09-24  12:03:01
# 21  1537168381  2018-09-17  10:13:01
# 22  1536952253  2018-09-14  22:10:53
# 25  1535952929  2018-09-03  08:35:29
# 26  1535952608  2018-09-03  08:30:08
# 27  1535657976  2018-08-30  22:39:36
# 28  1535657872  2018-08-30  22:37:52
# 31  1534187126  2018-08-13  22:05:26
# 40  1532836790  2018-07-29  06:59:50
# 42  1532780290  2018-07-28  15:18:10
# 43  1532766560  2018-07-28  11:29:20
# 44  1532642656  2018-07-27  01:04:16
# 45  1532597211  2018-07-26  12:26:51
# 47  1532287305  2018-07-22  22:21:45
# 48  1532111243  2018-07-20  21:27:23
# 51  1531756022  2018-07-16  18:47:02
# 54  1530558343  2018-07-02  22:05:43
# 56  1530180715  2018-06-28  13:11:55
# 58  1530036059  2018-06-26  21:00:59
# 59  1529990821  2018-06-26  08:27:01
# 61  1529923013  2018-06-25  13:36:53
# 62  1529921237  2018-06-25  13:07:17
# 64  1529907221  2018-06-25  09:13:41
# 65  1529831748  2018-06-24  12:15:48
# 66  1529611517  2018-06-21  23:05:17
# 67  1529581970  2018-06-21  14:52:50
# 68  1529574271  2018-06-21  12:44:31
# 69  1529574186  2018-06-21  12:43:06
# 70  1529573485  2018-06-21  12:31:25
# 71  1529573055  2018-06-21  12:24:15
# 72  1529572620  2018-06-21  12:17:00
# 73  1529572480  2018-06-21  12:14:40
# 76  1529303635  2018-06-18  09:33:55
# 79  1527538730  2018-05-28  23:18:50
# 80  1527080728  2018-05-23  16:05:28
# 83  1527078310  2018-05-23  15:25:10
# 86  1524946182  2018-04-28  23:09:42
# 88  1524895678  2018-04-28  09:07:58
# 89  1524895128  2018-04-28  08:58:48
# 92  1524137943  2018-04-19  14:39:03
# 93  1523905424  2018-04-16  22:03:44
# 94  1523905292  2018-04-16  22:01:32
# 95  1523905024  2018-04-16  21:57:04
# 96  1523904989  2018-04-16  21:56:29

# %% [markdown]
# Всё! Материалы о разных методах и функциях для `vk.api` можно найти в [официальной документации](https://dev.vk.com/reference).
