# %% [markdown]
# # Один из возможных алгоритмов скрейпинга
#
# * указать в коде адрес интересующего сайта: откуда вы хотите скачать данные?
# для этого используется библиотека requests
#
# * сохранить веб-страницу (html-код страницы)
#
# * выбрать данные, которые нужно собрать (используется BeautifulSoup)
#
# * записать данные в csv-файл.
#
# Если нужно соскрейпить несколько страниц - повторяем процесс для каждой из них.

# %% [markdown]
# **Наша задача:** выгрузить недавние новости в датафрейм `pandas`, чтобы потом сохранить все в csv-файл.
#
# Сначала сгрузим весь html-код страницы и сохраним его в отдельную переменную. Для этого нам понадобится библиотека `requests`. Документация: https://requests.readthedocs.io/en/latest/
#
# Импортируем её:

# %%
import requests

# %% [markdown]
# Сохраним ссылку на главную страницу сайта в переменную `url` для удобства и выгрузим страницу. (Разумеется, это будет работать при подключении к интернету. Если соединение будет отключено, Python выдаст `NewConnectionError`).

# %%
url = 'https://nplus1.ru/' # сохраняем
page = requests.get(url) # загружаем страницу по ссылке

# %% [markdown]
# Если мы просто посмотрим на объект, мы ничего особенного не увидим:

# %%
page  # response 200 - страница загружена
# Out:
# <Response [200]>

# %% [markdown]
# **BeautifulSoup** - python-библиотека для синтаксического разбора файлов HTML/XML. В веб-разработке «суп из тегов» (tag soup) - это слово для синтаксически или структурно некорректного HTML, написанного для веб-страницы.
#
# Документация: https://www.crummy.com/software/BeautifulSoup/bs4/doc/
#
# Импортируем функцию `BeautifulSoup` из библиотеки `bs4` (от *beautifulsoup4*) и заберём со страницы `page` код html в виде текста.
#
# Сохраним в переменную 'soup' весь HTML-код страницы. HTML-код - это "дерево тегов", формирующее контент страницы.

# %%
# !pip install bs4

# %%
from bs4 import BeautifulSoup 
# название - отсылка к песне про суп из Алисы в стране чудес https://aliceinwonderland.fandom.com/wiki/Turtle_Soup

# %%
soup = BeautifulSoup(page.text, 'html')

# %% [markdown]
# Если выведем `soup` на экран, мы увидим то же самое, что в режиме разработчика или в режиме происмотра исходного кода (`view-source` через *Ctrl+U* в Google Chrome).

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="ru" prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>N + 1 — главное издание о науке, технике и технологиях</title>
# <link as="font" crossorigin="" href="https://staticn1.nplus1.ru/fonts/AeonikPro/AeonikPro-Regular.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://staticn1.nplus1.ru/fonts/Spectral/Spectral-Regular.woff" rel="preload" type="font/woff2"/>
# <link href="/front-build/css/main.css?id=c066269c9e31b8c5719ba747306ba601" rel="stylesheet"/>
# <link href="/front-build/css/app.css?id=ab07a66910bee48e90bcb5a042d79cad" rel="stylesheet"/>
# <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/site.webmanifest" rel="manifest"/>
# <link color="#f26e40" href="/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="#f26e40" name="msapplication-TileColor"/>
# <meta content="#ffffff" name="theme-color"/>
# <link href="https://nplus1.ru" rel="canonical"/>
# <meta content="8c90b02c84ac3b72" name="yandex-verification"/>
# <meta content="b419949322895fc9106e24ed01be58ac" name="pmail-verification"/>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#
#     })(window,document,'script','dataLayer','GTM-PJWMQBQ');</script>
# <!-- End Google Tag Manager -->
# <meta content="N + 1 - это научно-популярное издание, которое познакомит вас с природными явлениями, открытиями и технологиями, расскажет
#  просто о сложном и поможет узнать что-то новое для себя" name="description"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:site_name"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:title"/>
# <meta content="https://nplus1.ru/images-new/share_snippet.png" property="og:image"/>
# <meta content="https://nplus1.ru" property="og:url"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:description"/>
# <meta content="" property="og:type"/>
# <script type="application/ld+json">
# {
# 	"@context": "http://schema.org",
# 	"@type": "WebSite",
# 	"url": "https://nplus1.ru/",
# 	"name": "N + 1 — главное издание о науке, технике и технологиях",
# 	"description": "N + 1 — главное издание о науке, технике и технологиях",
# 	"image": "https://staticn1.nplus1.ru/image-new/share_snippet.png",
# 	"publisher": {
# 	"@type": "Organization",
# 		"name": "N+1",
# 		"logo": {
# 			"@type":"ImageObject",
# 			"url": "https://staticn1.nplus1.ru/image-new/logo-alt.png"
# 		},
# 		"sameAs": [
# 			"https://www.facebook.com/nplusone",
# 			"https://twitter.com/nplusodin",
# 			"https://vk.com/nplusone",
# 			"https://ok.ru/nplus1",
# 			"https://soundcloud.com/nplus_1",
# 			"https://t.me/nplusone"
# 		]
# 	},
# 	"potentialAction":{
# 		"@type":"SearchAction",
# 		"target":"https://nplus1.ru/search/{search_term_string}",
# 		"query-input":"required name=search_term_string"
# 	}
# }
#
#   </script>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@nplusodin" name="twitter:site"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" name="twitter:title"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" name="twitter:description"/>
# <meta content="https://nplus1.ru/images-new/share_snippet.png" name="twitter:image"/>
# <link href="https://nplus1.ru/rss" rel="alternate" title="RSS" type="application/rss+xml"/>
# </head>
# <body class="antialiased">
# <!-- Top.Mail.Ru counter -->
# <script type="text/javascript">
#
# var tmr = window.tmr || (window._tmr = []);
#
# _tmr.push({id: "3377932", type: "pageView", start: (new Date()).getTime()});
#
# (function (d, w, id) {
#
#   if (d.getElementById(id)) return;
#
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
#
# })(document, window, "tmr-code");
#
# </script>
# <noscript><div><img alt="Top.Mail.Ru" src="https://top-fwz1.mail.ru/counter?id=3377932;js=na" style="position:absolute;left:-9999px;"/></div></noscript>
# <!-- /Top.Mail.Ru counter -->
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PJWMQBQ" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div class="font-aeonik text-main-black flex flex-col min-h-screen pt-15 bg-light-gray" id="appfront">
# <header class="bg-light-gray fixed h-15 left-0 top-0 w-full z-50" data-ref-header="" ref="headerRef">
# <div class="border-b border-main-gray h-full">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto flex justify-between items-center h-full" data-ref-header-container="" ref="headerContainerRef">
# <button aria-label="Go" class="w-7.5 h-7.5" data-ref-header-menu-btn="" id="topMenuBtn" ref="headerMenuBtnRef">
# <template v-if="isOpenDesktopMenu || isOpenMobileMenu">
# <svg class="w-full h-full">
# <use xlink:href="#n1_cross_menu"></use>
# </svg>
# </template>
# <template v-else="">
# <svg class="w-full h-full">
# <use xlink:href="#n1_burger"></use>
# </svg>
# </template>
# </button>
# <div>
# <img alt="as" height="23" loading="lazy" src="https://staticn1.nplus1.ru/image-new/logo.svg" width="57"/>
# </div>
# <a class="w-7.5 h-7.5" href="/search">
# <svg class="w-full h-full">
# <use xlink:href="#n1_pupa"></use>
# </svg>
# </a>
# </div>
# </div>
# <nav :style="stylesNavDesktop" class="relative bg-light-gray max-h-0 n1_top_nav overflow-hidden" id="navMenu" v-if="isOpenDesktopMenu">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
# <div class="py-12 mb-12 border-b border-gray-2 text-18 grid grid-cols-flow lg:grid-cols-12 gap-x-5 md:gap-x-9">
# <!--
#         <a @click.native="menuClose"
#            class="col-span-3 flex gap-x-2 lg:gap-x-5 items-center hover:text-main transition-colors duration-75"
#            href="/lk">
#           <svg class="h-10 lg:h-12 w-10 lg:w-12 shrink-0">
#             <use xlink:href="#n1_person"></use>
#           </svg>
#           <span>Личный кабинет</span>
#         </a>
#         -->
# <a class="col-span-3 lg:col-span-2 col-start-7 lg:col-start-9 flex items-center hover:text-main transition-colors duration-75" href="https://offline.nplus1.ru/">N + offline</a>
# <a class="col-span-3 lg:col-span-2 col-start-10 lg:col-start-11 flex items-center hover:text-main transition-colors duration-75" href="https://nplus.pro/">N + production</a>
# </div>
# <div class="grid grid-cols-12 gap-x-5 gap-y-5 md:gap-y-9 pb-6">
# <div class="col-span-6 md:col-span-3 text-20 lg:text-26 xl:text-34 font-spectral flex flex-col gap-y-3">
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">
#                 О нас
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#                 Сложность
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#                 Рекламодателям
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">
#                 Авторам
#               </a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">Игры</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">Физика</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">Зоология</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">Астрономия</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">Генетика</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">Математика</a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">Космонавтика</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">Археология</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">Нейронауки</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">На мышах</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">Звук</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">Красота</a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">Научные закрытия</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">Когда рассеется дым</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">Книжная полка</a>
# </div>
# </div>
# <div class="py-12 mt-auto border-t border-gray-2 text-18 grid grid-cols-12 gap-x-5 md:gap-x-9">
# <ul class="flex gap-2.5">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <nav :style="stylesNavMobile" class="relative bg-white max-h-0 n1_top_nav overflow-hidden" id="mobNavMenu" v-if="isOpenMobileMenu">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
# <div class="text-30 font-spectral flex flex-col gap-y-5 mb-10 mt-10">
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">О нас</a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">Сложность</a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">Рекламодателям</a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/news/2015/09/21/editor-thy-name" target="_blank">Вакансии</a>
# </div>
# <div class="text-28 text-main flex flex-col gap-y-2.5 mb-10">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">Игры
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">Физика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">Зоология
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">Астрономия
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">Генетика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">Математика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">Космонавтика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">Археология
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">Нейронауки
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">На мышах
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">Звук
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">Красота
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">Научные закрытия
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">Когда рассеется дым
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">Книжная полка
#           </a>
# </div>
# <div class="max-w-full flex py-5 border-t border-gray-2">
# <div class="flex gap-x-5 overflow-x-auto">
# <a class="hover:text-main whitespace-nowrap" href="https://offline.nplus1.ru/">N + offline</a>
# <a class="hover:text-main whitespace-nowrap" href="https://nplus.pro/">N + production</a>
# </div>
# </div>
# <div class="pt-5 pb-10 border-t border-gray-2 text-18">
# <ul class="flex gap-2.5">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# </header>
# <section class="mb-10">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto mx-auto">
# <div class="grid grid-cols-2 col-span-2 gap-0.5 n1_m_full n1_fs_main">
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
# <div class="flex flex-wrap gap-2 text-tags">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=870">Химия</a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=879">Материалы</a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/5">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">5.7</span>
# </a>
# </div>
# </div>
# <a class="" href="https://nplus1.ru/material/2023/10/05/qdots-nobel-2023">
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="hidden sm:block max-height-[333px]">
# <div class="-inset-0.5 absolute group">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/841331/25287473fb54662b69f5ff25ecb2daf1.jpg">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/841332/0e9e68ba948158bfb16f691a03bb0e0c.jpg">
# <img alt="Шрёдингер в телевизоре" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="block sm:hidden">
# <div class="-inset-0.5 absolute max-height-[333px]">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/841331/25287473fb54662b69f5ff25ecb2daf1.jpg">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/841332/0e9e68ba948158bfb16f691a03bb0e0c.jpg">
# <img alt="Шрёдингер в телевизоре" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
# <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">Шрёдингер в телевизоре</h3>
# <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#                     Как нобелевские лауреаты по химии материализовали квантовые точки
#                   </div>
# </div>
# </div>
# </a>
# </div>
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
# <div class="flex flex-wrap gap-2 text-tags">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=812">Партнерский материал</a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=872">Экология и климат</a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">2.8</span>
# </a>
# </div>
# </div>
# <a class="" href="https://nplus1.ru/material/2023/10/04/esg-test">
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="hidden sm:block max-height-[333px]">
# <div class="-inset-0.5 absolute group">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/837648/c882a47f573b0288271136029cfcb50d.png">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/837649/b075d68873a88d96da461834ca7e1f34.png">
# <img alt="Отвечаешь головой" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="block sm:hidden">
# <div class="-inset-0.5 absolute max-height-[333px]">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/837648/c882a47f573b0288271136029cfcb50d.png">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/837649/b075d68873a88d96da461834ca7e1f34.png">
# <img alt="Отвечаешь головой" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
# <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">Отвечаешь головой</h3>
# <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#                     Попробуйте справиться с реальными ESG-кейсами
#                   </div>
# </div>
# </div>
# </a>
# </div>
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
# <div class="flex flex-wrap gap-2 text-tags">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=869">Физика</a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/4">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">4.9</span>
# </a>
# </div>
# </div>
# <a class="" href="https://nplus1.ru/material/2023/10/03/nobel-pulses-2023">
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="hidden sm:block max-height-[333px]">
# <div class="-inset-0.5 absolute group">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/840797/00500a7d2ace93ac616788441a953e0f.jpg">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/840798/85fcc9f518e4ab5371f56aec8401a3db.jpg">
# <img alt="Импульс укорачивать" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="block sm:hidden">
# <div class="-inset-0.5 absolute max-height-[333px]">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/840797/00500a7d2ace93ac616788441a953e0f.jpg">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/840798/85fcc9f518e4ab5371f56aec8401a3db.jpg">
# <img alt="Импульс укорачивать" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
# <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">Импульс укорачивать</h3>
# <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#                     Почему нобелевские лауреаты по физике стремились к аттосекундам
#                   </div>
# </div>
# </div>
# </a>
# </div>
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
# <div class="flex flex-wrap gap-2 text-tags">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=870">Химия</a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/4">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">4.9</span>
# </a>
# </div>
# </div>
# <a class="" href="https://nplus1.ru/news/2023/10/04/chem-nobel-2023">
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="hidden sm:block max-height-[333px]">
# <div class="-inset-0.5 absolute group">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/838978/b6a57b60221a4de185ef25eab71044d4.jpg">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/838979/01a0b40604715ad17efdec71160f58aa.jpg">
# <img alt="Нобелевскую премию по химии присудили за квантовые точки" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="block sm:hidden">
# <div class="-inset-0.5 absolute max-height-[333px]">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/838978/b6a57b60221a4de185ef25eab71044d4.jpg">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/838979/01a0b40604715ad17efdec71160f58aa.jpg">
# <img alt="Нобелевскую премию по химии присудили за квантовые точки" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
# <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">Нобелевскую премию по химии присудили за квантовые точки</h3>
# <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#                     Ее получат Мунги Бавенди, Луис Брюс и Алексей Екимов
#                   </div>
# </div>
# </div>
# </a>
# </div>
# </div>
# </div>
# </section>
# <section class="mb-0 sm:mb-5">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 sm:grid-cols-12 gap-x-5 md:gap-x-9 relative">
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <div class="inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full">
# <span class="overflow-hidden text-ellipsis whitespace-nowrap">00:00</span>
# </div>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/05">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">05.10.23</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
# <p class="truncate">Медицина</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.6</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/05/manganese-accumulation-in-the-brain">
# <div>Врачи описали хроническое отравление марганцем из-за сварочных работ</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">04.10.23</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=884">
# <p class="truncate">Геология</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/5">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">5.6</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/sulfur-of-deccan-traps">
# <div>Извержения Деканских траппов принесли динозаврам серию вулканических зим перед ударом астероида</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">04.10.23</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
# <p class="truncate">Медицина</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.6</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/heartbreaking">
# <div>Злоупотребление каннабисом связали с повышенным риском болезней сердца и сосудов</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">04.10.23</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=871">
# <p class="truncate">Космонавтика</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.9</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/osiris-rex-deploy-capsule">
# <div>NASA показало полет возвращаемой капсулы станции OSIRIS-REx к Земле</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">04.10.23</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
# <p class="truncate">Медицина</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.3</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/vehicle-crash-adhd">
# <div>Пожилые водители с СДВГ отличились повышенным риском ДТП</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">04.10.23</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=874">
# <p class="truncate">Зоология</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.5</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/same-sex-behaviour-mammals">
# <div>Однополое сексуальное поведение млекопитающих связали с развитием социальности</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">04.10.23</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=880">
# <p class="truncate">Астрономия</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/4">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">4.9</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/frb-gw-or-no">
# <div>Астрономы не нашли связи между быстрыми радиовсплесками и гравитационными всплесками</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">04.10.23</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=877">
# <p class="truncate">Антропология</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">3.1</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/ak-alakha">
# <div>Знатному пазырыкцу поставили диффузный идиопатический скелетный гиперостоз</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">04.10.23</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
# <p class="truncate">Медицина</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.3</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/second-vaccine-for-malaria">
# <div>ВОЗ одобрила вторую противомалярийную вакцину для широкого применения</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">04.10.23</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=870">
# <p class="truncate">Химия</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/4">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">4.9</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/chem-nobel-2023">
# <div>Нобелевскую премию по химии присудили за квантовые точки</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">04.10.23</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=877">
# <p class="truncate">Антропология</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.9</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/neolithic-jericho">
# <div>Среди 44 жителей Иерихона эпохи докерамического неолита нашли двух неместных</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">04.10.23</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=887">
# <p class="truncate">Транспорт</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.7</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/we-drive-solar-sharing-batteries">
# <div>Каршеринговые электромобили в Нидерландах поделятся энергией с городской электросетью</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="mb-0 sm:mb-10">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 sm:grid-cols-12 gap-x-5 md:gap-x-9">
# <div class="col-span-6">
# <div class="flex flex-col gap-x-9 border-t border-gray-2 pt-5 pb-10 sm:pb-5">
# <a class="shrink-0 h-60 lg:h-72 xl:h-88 relative group" href="https://nplus1.ru/blog/2023/10/04/visual-glue">
# <picture>
# <source media="(max-width: 768px)" srcset="https://minio.nplus1.ru/app-images/840625/651c1185e9422_cover_mobile.jpg">
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/840624/651c118586bac_cover_tablet.jpg">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/840623/651c11852292a_cover.jpg">
# <img alt="«Визуальный клей»" class="w-full h-full object-cover" loading="lazy" src="https://minio.nplus1.ru/app-images/840623/651c11852292a_cover.jpg"/>
# </source></source></source></picture>
# </a>
# <div class="flex flex-col">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags xl:pr-9">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/blog/2023/10/04">
# <span class="group-hover:text-main transition-colors duration-75">04.10.23</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=882">
# <span class="group-hover:text-main transition-colors duration-75">Психология</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">1.1</span>
# </a>
# </div>
# <a class="group" href="https://nplus1.ru/blog/2023/10/04/visual-glue">
# <h3 class="text-34 sm:text-22 lg:text-32 mb-1 transition-colors duration-75 group-hover:text-main">
#                 «Визуальный клей»</h3>
# ...
# <a class="underline transition-colors duration-75 hover:text-main inline-block col-span-6 sm:col-span-5 mb-5 font-spectral italic" href="/personal-data-policy">Политика
#           обработки
#           персональных данных пользователей сайта
#         </a>
# </div>
# <div class="order-3 sm:col-span-9 lg:col-span-5 sm:order-3 lg:order-6 mt-auto col-span-6 mb-10 lg:mb-0">
# <ul class="flex gap-3 text-gray-2">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </footer>
# </div>
# <svg class="stroke-current" fill="none" height="16" id="n1_star" style="display:block;width:0;height:0" viewbox="3 3 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M11 5V17"></path>
# <path d="M6.75781 6.75781L15.2431 15.2431"></path>
# <path d="M17 11L5 11"></path>
# <path d="M15.2422 6.75781L6.75691 15.2431"></path>
# </svg>
# <svg class="stroke-current" fill="none" id="n1_person" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <circle cx="25" cy="25" r="24.5"></circle>
# <path d="M30.1897 30.3212C28.9483 29.9852 27.5345 29.7164 27.5345 28.5067C27.5345 27.8347 27.5 27.0618 28.2931 26.625C31.0172 25.0457 32.5 22.3911 32.1552 18.2581C31.8103 14.0578 29.2586 11 24.9828 11C20.7069 11 18.1552 14.0578 17.8103 18.2581C17.4655 22.3911 18.9138 25.0457 21.6724 26.625C22.4655 27.0618 22.431 27.8347 22.431 28.5067C22.431 29.7164 21.0172 29.9516 19.8103 30.3212C17.3966 30.9933 12.5 31.9005 12.5 36C16.431 36 33.569 36 37.5 36C37.4655 31.9005 32.6034 30.9933 30.1897 30.3212Z" stroke-miterlimit="10"></path>
# </svg>
# <svg fill="none" id="n1_tg" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M16.3181 21.32H19.4961V30H20.7141V21.32H23.8921V20.2H16.3181V21.32ZM28.6969 30.084C30.3769 30.084 31.4269 29.286 31.8749 28.572L31.9589 30H33.0089V24.694H28.8789V25.814H31.8189V26.15C31.8189 27.886 30.5169 28.964 28.7109 28.964C26.6809 28.964 25.3369 27.368 25.3369 25.1C25.3369 22.832 26.6809 21.236 28.7389 21.236C30.2229 21.236 31.2729 22.034 31.6089 23.392H32.9109C32.5749 21.376 30.9369 20.116 28.7669 20.116C25.9249 20.116 24.0909 22.132 24.0909 25.1C24.0909 28.068 25.9809 30.084 28.6969 30.084Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_vk" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M19.8015 30H21.2715L24.7995 20.2H23.5395L20.5575 28.558L17.5615 20.2H16.2735L19.8015 30ZM25.8768 30H27.0948V27.452L29.0408 25.254L32.3448 30H33.8008L29.9368 24.33L33.5208 20.2H32.0368L27.0948 25.758V20.2H25.8768V30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_ok" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M25.2125 25.1C25.2125 22.216 23.2945 20.116 20.5365 20.116C17.7785 20.116 15.8605 22.216 15.8605 25.1C15.8605 27.984 17.7785 30.084 20.5365 30.084C23.2945 30.084 25.2125 27.984 25.2125 25.1ZM17.1065 25.1C17.1065 22.846 18.4925 21.236 20.5365 21.236C22.5805 21.236 23.9665 22.846 23.9665 25.1C23.9665 27.354 22.5805 28.964 20.5365 28.964C18.4925 28.964 17.1065 27.354 17.1065 25.1ZM26.7518 30H27.9698V27.452L29.9158 25.254L33.2198 30H34.6758L30.8118 24.33L34.3958 20.2H32.9118L27.9698 25.758V20.2H26.7518V30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_tw" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M14.4792 21.32H17.6572V30H18.8752V21.32H22.0532V20.2H14.4792V21.32ZM25.332 30H26.788L29.014 22.23L31.254 30H32.71L35.58 20.2H34.32L32.01 28.432L29.686 20.2H28.454L26.046 28.432L23.75 20.2H22.476L25.332 30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg height="64px" id="n1_infinity" preserveaspectratio="xMidYMid" style="display:block;width:0;height:0" viewbox="0 0 100 100" width="64px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <path d="M24.3 30C11.4 30 5 43.3 5 50s6.4 20 19.3 20c19.3 0 32.1-40 51.4-40 C88.6 30 95 43.3 95 50s-6.4 20-19.3 20C56.4 70 43.6 30 24.3 30z" fill="none" stroke="#ffffff" stroke-dasharray="146.25568908691406 110.33323913574219" stroke-linecap="round" stroke-width="5" style="transform:scale(0.8);transform-origin:50px 50px">
# <animate attributename="stroke-dashoffset" dur="1.3157894736842106s" keytimes="0;1" repeatcount="indefinite" values="0;256.58892822265625"></animate>
# </path>
# </svg>
# <svg fill="none" id="n1_cross" style="display:block;width:0;height:0" viewbox="0 0 14 14" xmlns="http://www.w3.org/2000/svg">
# <path d="M1.00146 1L13.0015 13" stroke="#F9F9F9"></path>
# <path d="M13 1L1 13" stroke="#F9F9F9"></path>
# </svg>
# <svg id="n1_link_arrow" style="display:block;width:0;height:0" viewbox="0 0 11 11" xmlns="http://www.w3.org/2000/svg">
# <path d="M10.0738 5.87L5.08775 0.901999L4.15175 1.838L7.51775 5.204H0.19175V6.536H7.51775L4.15175 9.902L5.08775 10.838L10.0738 5.87Z" fill="currentColor"></path>
# </svg>
# <svg id="n1_big_star" style="display:block;width:0;height:0;" viewbox="0 0 61 61" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current
L19.9534 14.5916L14.6734 19.8516L16.0849 21.2685ZM14.0321 20.6272L14.6721 21.2672L16.0863 19.853L15.4463 19.213L14.0321 20.6272ZM18.1721 15.073L14.0321 19.213L15.4463 20.6272L19.5863 16.4872L18.1721 15.073ZM9.65918 16.7801H18.8792V14.7801H9.65918V16.7801ZM8.65918 14.8401V15.7801H10.6592V14.8401H8.65918ZM18.8792 13.8401H9.65918V15.8401H18.8792V13.8401ZM14.0321 11.4072L18.1721 15.5472L19.5863 14.133L15.4463 9.99295L14.0321 11.4072ZM14.6721 9.35295L14.0321 9.99295L15.4463 11.4072L16.0863 10.7672L14.6721 9.35295Z" fill="#fff" mask="url(#path-1-inside-1_2694_77554)"></path>
# </svg>
# <svg fill="none" id="n1_play" style="display:block;width:0;height:0;" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# <path class="stroke-current" d="M18 35V15L36 25L18 35Z"></path>
# </svg>
# <svg fill="none" id="n1_pupa" style="display:block;width:0;height:0;" viewbox="0 0 24 23" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M17 8.80329C17 13.0922 13.4392 16.6066 9 16.6066C4.56077 16.6066 1 13.0922 1 8.80329C1 4.51437 4.56077 1 9 1C13.4392 1 17 4.51437 17 8.80329ZM14.9967 15.3678C13.4049 16.7601 11.3035 17.6066 9 17.6066C4.02944 17.6066 0 13.6652 0 8.80329C0 3.94137 4.02944 0 9 0C13.9706 0 18 3.94137 18 8.80329C18 11.0562 17.1348 13.1114 15.7118 14.6684L23.3531 22.1427C23.5505 22.3358 23.554 22.6524 23.3609 22.8498C23.1678 23.0472 22.8513 23.0507 22.6539 22.8576L14.9967 15.3678Z" fill="#32363A" fill-rule="evenodd"></path>
# </svg>
# <svg fill="none" id="n1_burger" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <line stroke="#32363A" x2="30" y1="6.5" y2="6.5"></line>
# <line stroke="#32363A" x2="30" y1="23.5" y2="23.5"></line>
# <line stroke="#32363A" x2="30" y1="15" y2="15"></line>
# </svg>
# <svg fill="none" id="n1_cross_menu" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <path d="M4 4L26 26" stroke="#32363A"></path>
# <path d="M26 4L4 26" stroke="#32363A"></path>
# </svg>
# <svg id="n1_check" style="display:block;width:0;height:0;fill:currentColor" version="1.1" viewbox="0 0 752 752" xmlns="http://www.w3.org/2000/svg">
# <path d="m183.6 357.87-22.184 22.168v0.003907c-3.2969 3.293-3.2969 8.6367 0 11.934l133.29 133.28v0.003907c3.7305 3.7266 8.7891 5.8242 14.066 5.8242 5.2734 0 10.332-2.0977 14.062-5.8242l267.76-267.76c1.582-1.582 2.4727-3.7305 2.4727-5.9688 0-2.2383-0.89062-4.3867-2.4727-5.9688l-22.156-22.168c-1.582-1.5898-3.7344-2.4805-5.9727-2.4805-2.2422 0-4.3945 0.89062-5.9766 2.4805l-244.31 244.3c-1.8828 1.8789-4.9336 1.8789-6.8164 0l-109.84-109.83c-3.293-3.2852-8.625-3.2852-11.918 0z"></path>
# </svg>
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script src="/front-build/js/app.js?id=0ebe93a4910598709624f15c46949ba6"></script>
# <!-- Yandex.Metrika counter 2-->
# <script type="text/javascript">
# (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
# 	m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
# (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
# ym(88946384, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true
# });
#
#
# ym(29654565, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true,
# 	trackHash:true,
# 	ecommerce:"dataLayer"
# });
# </script>
# <noscript>
# <div>
# <img alt="" src="https://mc.yandex.ru/watch/88946384" style="position:absolute; left:-9999px;"/>
# <img alt="" src="https://mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;"/>
# </div>
# </noscript>
# <!-- /Yandex.Metrika counter -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-61773772-1"></script>
# <script>
# window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'UA-61773772-1');
# </script>
# <script>window.yaContextCb = window.yaContextCb || []</script>
# <script async="" src="https://yandex.ru/ads/system/context.js"></script>
# <script>
# if ('serviceWorker' in navigator) {
# 	window.addEventListener('load', () => {
# 		navigator.serviceWorker.register('/front-service-worker.js').then(reg => {
# 			// sometime later…
# 			reg.update()
# 		})
# 	})
# }
# </script>
# </body>
# </html>

# %% [markdown]
# Для просмотра выглядит не очень удобно.  «Причешем» наш `soup` – воспользуемся методом `.prettify()` в сочетании с функцией `print()`.

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ru" prefix="og: http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    N + 1 — главное издание о науке, технике и технологиях
#   </title>
#   <link as="font" crossorigin="" href="https://staticn1.nplus1.ru/fonts/AeonikPro/AeonikPro-Regular.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="https://staticn1.nplus1.ru/fonts/Spectral/Spectral-Regular.woff" rel="preload" type="font/woff2"/>
#   <link href="/front-build/css/main.css?id=c066269c9e31b8c5719ba747306ba601" rel="stylesheet"/>
#   <link href="/front-build/css/app.css?id=ab07a66910bee48e90bcb5a042d79cad" rel="stylesheet"/>
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/site.webmanifest" rel="manifest"/>
#   <link color="#f26e40" href="/safari-pinned-tab.svg" rel="mask-icon"/>
#   <meta content="#f26e40" name="msapplication-TileColor"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <link href="https://nplus1.ru" rel="canonical"/>
#   <meta content="8c90b02c84ac3b72" name="yandex-verification"/>
#   <meta content="b419949322895fc9106e24ed01be58ac" name="pmail-verification"/>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#
#     })(window,document,'script','dataLayer','GTM-PJWMQBQ');
#   </script>
#   <!-- End Google Tag Manager -->
#   <meta content="N + 1 - это научно-популярное издание, которое познакомит вас с природными явлениями, открытиями и технологиями, расскажет
#  просто о сложном и поможет узнать что-то новое для себя" name="description"/>
#   <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:site_name"/>
#   <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:title"/>
#   <meta content="https://nplus1.ru/images-new/share_snippet.png" property="og:image"/>
#   <meta content="https://nplus1.ru" property="og:url"/>
#   <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:description"/>
#   <meta content="" property="og:type"/>
#   <script type="application/ld+json">
#    {
# 	"@context": "http://schema.org",
# 	"@type": "WebSite",
# 	"url": "https://nplus1.ru/",
# 	"name": "N + 1 — главное издание о науке, технике и технологиях",
# 	"description": "N + 1 — главное издание о науке, технике и технологиях",
# 	"image": "https://staticn1.nplus1.ru/image-new/share_snippet.png",
# 	"publisher": {
# 	"@type": "Organization",
# 		"name": "N+1",
# 		"logo": {
# 			"@type":"ImageObject",
# 			"url": "https://staticn1.nplus1.ru/image-new/logo-alt.png"
# 		},
# 		"sameAs": [
# 			"https://www.facebook.com/nplusone",
# 			"https://twitter.com/nplusodin",
# 			"https://vk.com/nplusone",
# 			"https://ok.ru/nplus1",
# 			"https://soundcloud.com/nplus_1",
# 			"https://t.me/nplusone"
# 		]
# 	},
# 	"potentialAction":{
# 		"@type":"SearchAction",
# 		"target":"https://nplus1.ru/search/{search_term_string}",
# 		"query-input":"required name=search_term_string"
# 	}
# }
#   </script>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@nplusodin" name="twitter:site"/>
#   <meta content="N + 1 — главное издание о науке, технике и технологиях" name="twitter:title"/>
#   <meta content="N + 1 — главное издание о науке, технике и технологиях" name="twitter:description"/>
#   <meta content="https://nplus1.ru/images-new/share_snippet.png" name="twitter:image"/>
#   <link href="https://nplus1.ru/rss" rel="alternate" title="RSS" type="application/rss+xml"/>
#  </head>
#  <body class="antialiased">
#   <!-- Top.Mail.Ru counter -->
#   <script type="text/javascript">
#    var tmr = window.tmr || (window._tmr = []);
#
# _tmr.push({id: "3377932", type: "pageView", start: (new Date()).getTime()});
#
# (function (d, w, id) {
#
#   if (d.getElementById(id)) return;
#
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
#
# })(document, window, "tmr-code");
#   </script>
#   <noscript>
#    <div>
#     <img alt="Top.Mail.Ru" src="https://top-fwz1.mail.ru/counter?id=3377932;js=na" style="position:absolute;left:-9999px;"/>
#    </div>
#   </noscript>
#   <!-- /Top.Mail.Ru counter -->
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PJWMQBQ" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <div class="font-aeonik text-main-black flex flex-col min-h-screen pt-15 bg-light-gray" id="appfront">
#    <header class="bg-light-gray fixed h-15 left-0 top-0 w-full z-50" data-ref-header="" ref="headerRef">
#     <div class="border-b border-main-gray h-full">
#      <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto flex justify-between items-center h-full" data-ref-header-container="" ref="headerContainerRef">
#       <button aria-label="Go" class="w-7.5 h-7.5" data-ref-header-menu-btn="" id="topMenuBtn" ref="headerMenuBtnRef">
#        <template v-if="isOpenDesktopMenu || isOpenMobileMenu">
#         <svg class="w-full h-full">
#          <use xlink:href="#n1_cross_menu">
#          </use>
#         </svg>
#        </template>
#        <template v-else="">
#         <svg class="w-full h-full">
#          <use xlink:href="#n1_burger">
#          </use>
#         </svg>
#        </template>
#       </button>
#       <div>
#        <img alt="as" height="23" loading="lazy" src="https://staticn1.nplus1.ru/image-new/logo.svg" width="57"/>
#       </div>
#       <a class="w-7.5 h-7.5" href="/search">
#        <svg class="w-full h-full">
#         <use xlink:href="#n1_pupa">
#         </use>
#        </svg>
#       </a>
#      </div>
#     </div>
#     <nav :style="stylesNavDesktop" class="relative bg-light-gray max-h-0 n1_top_nav overflow-hidden" id="navMenu" v-if="isOpenDesktopMenu">
#      <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
#       <div class="py-12 mb-12 border-b border-gray-2 text-18 grid grid-cols-flow lg:grid-cols-12 gap-x-5 md:gap-x-9">
#        <!--
#         <a @click.native="menuClose"
#            class="col-span-3 flex gap-x-2 lg:gap-x-5 items-center hover:text-main transition-colors duration-75"
#            href="/lk">
#           <svg class="h-10 lg:h-12 w-10 lg:w-12 shrink-0">
#             <use xlink:href="#n1_person"></use>
#           </svg>
#           <span>Личный кабинет</span>
#         </a>
#         -->
#        <a class="col-span-3 lg:col-span-2 col-start-7 lg:col-start-9 flex items-center hover:text-main transition-colors duration-75" href="https://offline.nplus1.ru/">
#         N + offline
#        </a>
#        <a class="col-span-3 lg:col-span-2 col-start-10 lg:col-start-11 flex items-center hover:text-main transition-colors duration-75" href="https://nplus.pro/">
#         N + production
#        </a>
#       </div>
#       <div class="grid grid-cols-12 gap-x-5 gap-y-5 md:gap-y-9 pb-6">
#        <div class="col-span-6 md:col-span-3 text-20 lg:text-26 xl:text-34 font-spectral flex flex-col gap-y-3">
#         <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">
#          О нас
#         </a>
#         <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#          Сложность
#         </a>
#         <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#          Рекламодателям
#         </a>
#         <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">
#          Авторам
#         </a>
#        </div>
#        <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">
#          Игры
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">
#          Физика
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">
#          Зоология
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">
#          Астрономия
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">
#          Генетика
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">
#          Математика
#         </a>
#        </div>
#        <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">
#          Космонавтика
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">
#          Археология
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">
#          Нейронауки
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">
#          На мышах
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">
#          Звук
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">
#          Красота
#         </a>
#        </div>
#        <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">
#          Научные закрытия
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">
#          ИИ спешит на помощь
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">
#          Когда рассеется дым
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">
#          Книжная полка
#         </a>
#        </div>
#       </div>
#       <div class="py-12 mt-auto border-t border-gray-2 text-18 grid grid-cols-12 gap-x-5 md:gap-x-9">
#        <ul class="flex gap-2.5">
#         <li>
#          <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_tg">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_vk">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_ok">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li class="w-12">
#          <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_tw">
#            </use>
#           </svg>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </nav>
#     <nav :style="stylesNavMobile" class="relative bg-white max-h-0 n1_top_nav overflow-hidden" id="mobNavMenu" v-if="isOpenMobileMenu">
#      <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
#       <div class="text-30 font-spectral flex flex-col gap-y-5 mb-10 mt-10">
#        <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">
#         О нас
#        </a>
#        <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#         Сложность
#        </a>
#        <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#         Рекламодателям
#        </a>
#        <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/news/2015/09/21/editor-thy-name" target="_blank">
#         Вакансии
#        </a>
#       </div>
#       <div class="text-28 text-main flex flex-col gap-y-2.5 mb-10">
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">
#         Игры
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">
#         Физика
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">
#         Зоология
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">
#         Астрономия
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">
#         Генетика
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">
#         Математика
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">
#         Космонавтика
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">
#         Археология
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">
#         Нейронауки
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">
#         На мышах
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">
#         Звук
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">
#         Красота
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">
#         Научные закрытия
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">
#         ИИ спешит на помощь
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">
#         Когда рассеется дым
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">
#         Книжная полка
#        </a>
#       </div>
#       <div class="max-w-full flex py-5 border-t border-gray-2">
#        <div class="flex gap-x-5 overflow-x-auto">
#         <a class="hover:text-main whitespace-nowrap" href="https://offline.nplus1.ru/">
#          N + offline
#         </a>
#         <a class="hover:text-main whitespace-nowrap" href="https://nplus.pro/">
#          N + production
#         </a>
#        </div>
#       </div>
#       <div class="pt-5 pb-10 border-t border-gray-2 text-18">
#        <ul class="flex gap-2.5">
#         <li>
#          <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#           <svg class="w-10 h-10">
#            <use xlink:href="#n1_tg">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#           <svg class="w-10 h-10">
#            <use xlink:href="#n1_vk">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#           <svg class="w-10 h-10">
#            <use xlink:href="#n1_ok">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li class="w-12">
#          <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#           <svg class="w-10 h-10">
#            <use xlink:href="#n1_tw">
#            </use>
#           </svg>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </nav>
#    </header>
#    <section class="mb-10">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto mx-auto">
#      <div class="grid grid-cols-2 col-span-2 gap-0.5 n1_m_full n1_fs_main">
#       <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#        <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
#         <div class="flex flex-wrap gap-2 text-tags">
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=870">
#           Химия
#          </a>
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=879">
#           Материалы
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/5">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">
#            5.7
#           </span>
#          </a>
#         </div>
#        </div>
#        <a class="" href="https://nplus1.ru/material/2023/10/05/qdots-nobel-2023">
#         <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#          <div class="hidden sm:block max-height-[333px]">
#           <div class="-inset-0.5 absolute group">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/841331/25287473fb54662b69f5ff25ecb2daf1.jpg">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/841332/0e9e68ba948158bfb16f691a03bb0e0c.jpg">
#               <img alt="Шрёдингер в телевизоре" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="block sm:hidden">
#           <div class="-inset-0.5 absolute max-height-[333px]">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/841331/25287473fb54662b69f5ff25ecb2daf1.jpg">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/841332/0e9e68ba948158bfb16f691a03bb0e0c.jpg">
#               <img alt="Шрёдингер в телевизоре" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#           <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">
#            Шрёдингер в телевизоре
#           </h3>
#           <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#            Как нобелевские лауреаты по химии материализовали квантовые точки
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#        <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
#         <div class="flex flex-wrap gap-2 text-tags">
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=812">
#           Партнерский материал
#          </a>
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=872">
#           Экология и климат
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/2">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">
#            2.8
#           </span>
#          </a>
#         </div>
#        </div>
#        <a class="" href="https://nplus1.ru/material/2023/10/04/esg-test">
#         <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#          <div class="hidden sm:block max-height-[333px]">
#           <div class="-inset-0.5 absolute group">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/837648/c882a47f573b0288271136029cfcb50d.png">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/837649/b075d68873a88d96da461834ca7e1f34.png">
#               <img alt="Отвечаешь головой" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="block sm:hidden">
#           <div class="-inset-0.5 absolute max-height-[333px]">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/837648/c882a47f573b0288271136029cfcb50d.png">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/837649/b075d68873a88d96da461834ca7e1f34.png">
#               <img alt="Отвечаешь головой" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#           <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">
#            Отвечаешь головой
#           </h3>
#           <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#            Попробуйте справиться с реальными ESG-кейсами
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#        <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
#         <div class="flex flex-wrap gap-2 text-tags">
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=869">
#           Физика
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/4">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">
#            4.9
#           </span>
#          </a>
#         </div>
#        </div>
#        <a class="" href="https://nplus1.ru/material/2023/10/03/nobel-pulses-2023">
#         <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#          <div class="hidden sm:block max-height-[333px]">
#           <div class="-inset-0.5 absolute group">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/840797/00500a7d2ace93ac616788441a953e0f.jpg">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/840798/85fcc9f518e4ab5371f56aec8401a3db.jpg">
#               <img alt="Импульс укорачивать" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="block sm:hidden">
#           <div class="-inset-0.5 absolute max-height-[333px]">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/840797/00500a7d2ace93ac616788441a953e0f.jpg">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/840798/85fcc9f518e4ab5371f56aec8401a3db.jpg">
#               <img alt="Импульс укорачивать" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#           <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">
#            Импульс укорачивать
#           </h3>
#           <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#            Почему нобелевские лауреаты по физике стремились к аттосекундам
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#        <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
#         <div class="flex flex-wrap gap-2 text-tags">
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=870">
#           Химия
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/4">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">
#            4.9
#           </span>
#          </a>
#         </div>
#        </div>
#        <a class="" href="https://nplus1.ru/news/2023/10/04/chem-nobel-2023">
#         <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#          <div class="hidden sm:block max-height-[333px]">
#           <div class="-inset-0.5 absolute group">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/838978/b6a57b60221a4de185ef25eab71044d4.jpg">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/838979/01a0b40604715ad17efdec71160f58aa.jpg">
#               <img alt="Нобелевскую премию по химии присудили за квантовые точки" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="block sm:hidden">
#           <div class="-inset-0.5 absolute max-height-[333px]">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/838978/b6a57b60221a4de185ef25eab71044d4.jpg">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/838979/01a0b40604715ad17efdec71160f58aa.jpg">
#               <img alt="Нобелевскую премию по химии присудили за квантовые точки" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#           <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">
#            Нобелевскую премию по химии присудили за квантовые точки
#           </h3>
#           <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#            Ее получат Мунги Бавенди, Луис Брюс и Алексей Екимов
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#      </div>
#     </div>
#    </section>
#    <section class="mb-0 sm:mb-5">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 sm:grid-cols-12 gap-x-5 md:gap-x-9 relative">
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <div class="inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full">
#           <span class="overflow-hidden text-ellipsis whitespace-nowrap">
#            00:00
#           </span>
#          </div>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/05">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            05.10.23
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
#           <p class="truncate">
#            Медицина
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            2.6
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/05/manganese-accumulation-in-the-brain">
#          <div>
#           Врачи описали хроническое отравление марганцем из-за сварочных работ
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            04.10.23
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=884">
#           <p class="truncate">
#            Геология
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/5">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            5.6
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/sulfur-of-deccan-traps">
#          <div>
#           Извержения Деканских траппов принесли динозаврам серию вулканических зим перед ударом астероида
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            04.10.23
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
#           <p class="truncate">
#            Медицина
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            1.6
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/heartbreaking">
#          <div>
#           Злоупотребление каннабисом связали с повышенным риском болезней сердца и сосудов
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            04.10.23
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=871">
#           <p class="truncate">
#            Космонавтика
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            1.9
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/osiris-rex-deploy-capsule">
#          <div>
#           NASA показало полет возвращаемой капсулы станции OSIRIS-REx к Земле
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            04.10.23
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
#           <p class="truncate">
#            Медицина
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            2.3
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/vehicle-crash-adhd">
#          <div>
#           Пожилые водители с СДВГ отличились повышенным риском ДТП
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            04.10.23
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=874">
#           <p class="truncate">
#            Зоология
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            2.5
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/same-sex-behaviour-mammals">
#          <div>
#           Однополое сексуальное поведение млекопитающих связали с развитием социальности
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            04.10.23
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=880">
#           <p class="truncate">
#            Астрономия
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/4">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            4.9
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/frb-gw-or-no">
#          <div>
#           Астрономы не нашли связи между быстрыми радиовсплесками и гравитационными всплесками
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            04.10.23
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=877">
#           <p class="truncate">
#            Антропология
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            3.1
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/ak-alakha">
#          <div>
#           Знатному пазырыкцу поставили диффузный идиопатический скелетный гиперостоз
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            04.10.23
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
#           <p class="truncate">
#            Медицина
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            2.3
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/second-vaccine-for-malaria">
#          <div>
#           ВОЗ одобрила вторую противомалярийную вакцину для широкого применения
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
# ...
#          <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_vk">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_ok">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li class="w-12">
#          <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_tw">
#            </use>
#           </svg>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </footer>
#   </div>
#   <svg class="stroke-current" fill="none" height="16" id="n1_star" style="display:block;width:0;height:0" viewbox="3 3 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#    <path d="M11 5V17">
#    </path>
#    <path d="M6.75781 6.75781L15.2431 15.2431">
#    </path>
#    <path d="M17 11L5 11">
#    </path>
#    <path d="M15.2422 6.75781L6.75691 15.2431">
#    </path>
#   </svg>
#   <svg class="stroke-current" fill="none" id="n1_person" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <circle cx="25" cy="25" r="24.5">
#    </circle>
#    <path d="M30.1897 30.3212C28.9483 29.9852 27.5345 29.7164 27.5345 28.5067C27.5345 27.8347 27.5 27.0618 28.2931 26.625C31.0172 25.0457 32.5 22.3911 32.1552 18.2581C31.8103 14.0578 29.2586 11 24.9828 11C20.7069 11 18.1552 14.0578 17.8103 18.2581C17.4655 22.3911 18.9138 25.0457 21.6724 26.625C22.4655 27.0618 22.431 27.8347 22.431 28.5067C22.431 29.7164 21.0172 29.9516 19.8103 30.3212C17.3966 30.9933 12.5 31.9005 12.5 36C16.431 36 33.569 36 37.5 36C37.4655 31.9005 32.6034 30.9933 30.1897 30.3212Z" stroke-miterlimit="10">
#    </path>
#   </svg>
#   <svg fill="none" id="n1_tg" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <path class="fill-current" d="M16.3181 21.32H19.4961V30H20.7141V21.32H23.8921V20.2H16.3181V21.32ZM28.6969 30.084C30.3769 30.084 31.4269 29.286 31.8749 28.572L31.9589 30H33.0089V24.694H28.8789V25.814H31.8189V26.15C31.8189 27.886 30.5169 28.964 28.7109 28.964C26.6809 28.964 25.3369 27.368 25.3369 25.1C25.3369 22.832 26.6809 21.236 28.7389 21.236C30.2229 21.236 31.2729 22.034 31.6089 23.392H32.9109C32.5749 21.376 30.9369 20.116 28.7669 20.116C25.9249 20.116 24.0909 22.132 24.0909 25.1C24.0909 28.068 25.9809 30.084 28.6969 30.084Z">
#    </path>
#    <circle class="stroke-current" cx="25" cy="25" r="24.5">
#    </circle>
#   </svg>
#   <svg fill="none" id="n1_vk" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <path class="fill-current" d="M19.8015 30H21.2715L24.7995 20.2H23.5395L20.5575 28.558L17.5615 20.2H16.2735L19.8015 30ZM25.8768 30H27.0948V27.452L29.0408 25.254L32.3448 30H33.8008L29.9368 24.33L33.5208 20.2H32.0368L27.0948 25.758V20.2H25.8768V30Z">
#    </path>
#    <circle class="stroke-current" cx="25" cy="25" r="24.5">
#    </circle>
#   </svg>
#   <svg fill="none" id="n1_ok" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <path class="fill-current" d="M25.2125 25.1C25.2125 22.216 23.2945 20.116 20.5365 20.116C17.7785 20.116 15.8605 22.216 15.8605 25.1C15.8605 27.984 17.7785 30.084 20.5365 30.084C23.2945 30.084 25.2125 27.984 25.2125 25.1ZM17.1065 25.1C17.1065 22.846 18.4925 21.236 20.5365 21.236C22.5805 21.236 23.9665 22.846 23.9665 25.1C23.9665 27.354 22.5805 28.964 20.5365 28.964C18.4925 28.964 17.1065 27.354 17.1065 25.1ZM26.7518 30H27.9698V27.452L29.9158 25.254L33.2198 30H34.6758L30.8118 24.33L34.3958 20.2H32.9118L27.9698 25.758V20.2H26.7518V30Z">
#    </path>
#    <circle class="stroke-current" cx="25" cy="25" r="24.5">
#    </circle>
#   </svg>
#   <svg fill="none" id="n1_tw" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <path class="fill-current" d="M14.4792 21.32H17.6572V30H18.8752V21.32H22.0532V20.2H14.4792V21.32ZM25.332 30H26.788L29.014 22.23L31.254 30H32.71L35.58 20.2H34.32L32.01 28.432L29.686 20.2H28.454L26.046 28.432L23.75 20.2H22.476L25.332 30Z">
#    </path>
#    <circle class="stroke-current" cx="25" cy="25" r="24.5">
#    </circle>
#   </svg>
#   <svg height="64px" id="n1_infinity" preserveaspectratio="xMidYMid" style="display:block;width:0;height:0" viewbox="0 0 100 100" width="64px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#    <path d="M24.3 30C11.4 30 5 43.3 5 50s6.4 20 19.3 20c19.3 0 32.1-40 51.4-40 C88.6 30 95 43.3 95 50s-6.4 20-19.3 20C56.4 70 43.6 30 24.3 30z" fill="none" stroke="#ffffff" stroke-dasharray="146.25568908691406 110.33323913574219" stroke-linecap="round" stroke-width="5" style="transform:scale(0.8);transform-origin:50px 50px">
#     <animate attributename="stroke-dashoffset" dur="1.3157894736842106s" keytimes="0;1" repeatcount="indefinite" values="0;256.58892822265625">
#     </animate>
#    </path>
#   </svg>
#   <svg fill="none" id="n1_cross" style="display:block;width:0;height:0" viewbox="0 0 14 14" xmlns="http://www.w3.org/2000/svg">
#    <path d="M1.00146 1L13.0015 13" stroke="#F9F9F9">
#    </path>
#    <path d="M13 1L1 13" stroke="#F9F9F9">
#    </path>
#   </svg>
#   <svg id="n1_link_arrow" style="display:block;width:0;height:0" viewbox="0 0 11 11" xmlns="http://www.w3.org/2000/svg">
#    <path d="M10.0738 5.87L5.08775 0.901999L4.15175 1.838L7.51775 5.204H0.19175V6.536H7.51775L4.15175 9.902L5.08775 10.838L10.0738 5.87Z" fill="currentColor">
#    </path>
#   </svg>
#   <svg id="n1_big_star" style="display:block;width:0;height:0;" viewbox="0 0 61 61" xmlns="http://www.w3.org/2000/svg">
#    <path class="fill-current" clip-rule="evenodd" d="M3 29.7729H29.0656L10.6345 11.3418L11.3416 10.6347L29.7728 29.0658V3H30.7728V29.0658L49.2039 10.6347L49.911 11.3418L31.4799 29.7729H57.5455V30.7729H31.4799L49.9111 49.2042L49.204 49.9113L30.7728 31.4801V57.5455H29.7728V31.4801L11.3415 49.9113L10.6344 49.2042L29.0656 30.7729H3V29.7729Z" fill-rule="evenodd">
#    </path>
455H29.7728V60.0455ZM27.2728 31.4801V57.5455H32.2728V31.4801H27.2728ZM28.005 29.7123L9.57374 48.1435L13.1093 51.6791L31.5405 33.2478L28.005 29.7123ZM13.1093 48.1435L12.4022 47.4364L8.86664 50.972L9.57374 51.6791L13.1093 48.1435ZM12.4022 50.972L30.8334 32.5407L27.2979 29.0052L8.86664 47.4364L12.4022 50.972ZM3 33.2729H29.0656V28.2729H3V33.2729ZM0.5 29.7729V30.7729H5.5V29.7729H0.5Z">
#    </path>
#   </svg>
#   <svg class="stroke-current" fill="none" id="n1_circle_arrow" style="display:block;width:0;height:0" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
#    <rect height="29" rx="14.5" transform="rotate(-180 29.5 29.5)" width="29" x="29.5" y="29.5">
#    </rect>
#    <path d="M9.33985 14.7014L14.6198 19.9414L15.2598 19.3014L11.1198 15.1614L20.3398 15.1614L20.3398 14.2214L11.1198 14.2214L15.2598 10.0814L14.6198 9.44141L9.33985 14.7014Z">
#    </path>
#   </svg>
#   <svg fill="none" id="n1_circle_arrow_solid" style="display:block;width:0;height:0" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
#    <mask id="path-1-inside-1_2694_77554">
#     <path clip-rule="evenodd" d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z" fill-rule="evenodd">
#     </path>
#    </mask>
#    <path clip-rule="evenodd" d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z" fill="#fff" fill-rule="evenodd">
#    </path>
#    <path d="M20.6592 15.3001L21.3649 16.0085L22.0774 15.2987L21.3636 14.5903L20.6592 15.3001ZM15.3792 10.0601L16.0836 9.35027L15.3765 8.64853L14.6721 9.35295L15.3792 10.0601ZM15.3792 20.5601L14.6721 21.2672L15.3778 21.9729L16.0849 21.2685L15.3792 20.5601ZM14.7392 19.9201L14.0321 19.213L13.325 19.9201L14.0321 20.6272L14.7392 19.9201ZM18.8792 15.7801L19.5863 16.4872L21.2934 14.7801H18.8792V15.7801ZM9.65918 15.7801H8.65918V16.7801H9.65918V15.7801ZM9.65918 14.8401V13.8401H8.65918V14.8401H9.65918ZM18.8792 14.8401V15.8401H21.2934L19.5863 14.133L18.8792 14.8401ZM14.7392 10.7001L14.0321 9.99295L13.325 10.7001L14.0321 11.4072L14.7392 10.7001ZM1 15C1 7.26801 7.26801 1 15 1V-1C6.16344 -1 -1 6.16344 -1 15H1ZM15 29C7.26801 29 1 22.732 1 15H-1C-1 23.8366 6.16344 31 15 31V29ZM29 15C29 22.732 22.732 29 15 29V31C23.8366 31 31 23.8366 31 15H29ZM15 1C22.732 1 29 7.26801 29 15H31C31 6.16344 23.8366 -1 15 -1V1ZM21.3636 14.5903L16.0836 9.35027L14.6748 10.7698L19.9548 16.0098L21.3636 14.5903ZM16.0849 21.2685L21.3649 16.0085L19.9534 14.5916L14.6734 19.8516L16.0849 21.2685ZM14.0321 20.6272L14.6721 21.2672L16.0863 19.853L15.4463 19.213L14.0321 20.6272ZM18.1721 15.073L14.0321 19.213L15.4463 20.6272L19.5863 16.4872L18.1721 15.073ZM9.65918 16.7801H18.8792V14.7801H9.65918V16.7801ZM8.65918 14.8401V15.7801H10.6592V14.8401H8.65918ZM18.8792 13.8401H9.65918V15.8401H18.8792V13.8401ZM14.0321 11.4072L18.1721 15.5472L19.5863 14.133L15.4463 9.99295L14.0321 11.4072ZM14.6721 9.35295L14.0321 9.99295L15.4463 11.4072L16.0863 10.7672L14.6721 9.35295Z" fill="#fff" mask="url(#path-1-inside-1_2694_77554)">
#    </path>
#   </svg>
#   <svg fill="none" id="n1_play" style="display:block;width:0;height:0;" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <circle class="stroke-current" cx="25" cy="25" r="24.5">
#    </circle>
#    <path class="stroke-current" d="M18 35V15L36 25L18 35Z">
#    </path>
#   </svg>
#   <svg fill="none" id="n1_pupa" style="display:block;width:0;height:0;" viewbox="0 0 24 23" xmlns="http://www.w3.org/2000/svg">
#    <path clip-rule="evenodd" d="M17 8.80329C17 13.0922 13.4392 16.6066 9 16.6066C4.56077 16.6066 1 13.0922 1 8.80329C1 4.51437 4.56077 1 9 1C13.4392 1 17 4.51437 17 8.80329ZM14.9967 15.3678C13.4049 16.7601 11.3035 17.6066 9 17.6066C4.02944 17.6066 0 13.6652 0 8.80329C0 3.94137 4.02944 0 9 0C13.9706 0 18 3.94137 18 8.80329C18 11.0562 17.1348 13.1114 15.7118 14.6684L23.3531 22.1427C23.5505 22.3358 23.554 22.6524 23.3609 22.8498C23.1678 23.0472 22.8513 23.0507 22.6539 22.8576L14.9967 15.3678Z" fill="#32363A" fill-rule="evenodd">
#    </path>
#   </svg>
#   <svg fill="none" id="n1_burger" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
#    <line stroke="#32363A" x2="30" y1="6.5" y2="6.5">
#    </line>
#    <line stroke="#32363A" x2="30" y1="23.5" y2="23.5">
#    </line>
#    <line stroke="#32363A" x2="30" y1="15" y2="15">
#    </line>
#   </svg>
#   <svg fill="none" id="n1_cross_menu" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
#    <path d="M4 4L26 26" stroke="#32363A">
#    </path>
#    <path d="M26 4L4 26" stroke="#32363A">
#    </path>
#   </svg>
#   <svg id="n1_check" style="display:block;width:0;height:0;fill:currentColor" version="1.1" viewbox="0 0 752 752" xmlns="http://www.w3.org/2000/svg">
#    <path d="m183.6 357.87-22.184 22.168v0.003907c-3.2969 3.293-3.2969 8.6367 0 11.934l133.29 133.28v0.003907c3.7305 3.7266 8.7891 5.8242 14.066 5.8242 5.2734 0 10.332-2.0977 14.062-5.8242l267.76-267.76c1.582-1.582 2.4727-3.7305 2.4727-5.9688 0-2.2383-0.89062-4.3867-2.4727-5.9688l-22.156-22.168c-1.582-1.5898-3.7344-2.4805-5.9727-2.4805-2.2422 0-4.3945 0.89062-5.9766 2.4805l-244.31 244.3c-1.8828 1.8789-4.9336 1.8789-6.8164 0l-109.84-109.83c-3.293-3.2852-8.625-3.2852-11.918 0z">
#    </path>
#   </svg>
#   <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js">
#   </script>
#   <script src="/front-build/js/app.js?id=0ebe93a4910598709624f15c46949ba6">
#   </script>
#   <!-- Yandex.Metrika counter 2-->
#   <script type="text/javascript">
#    (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
# 	m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
# (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
# ym(88946384, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true
# });
#
#
# ym(29654565, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true,
# 	trackHash:true,
# 	ecommerce:"dataLayer"
# });
#   </script>
#   <noscript>
#    <div>
#     <img alt="" src="https://mc.yandex.ru/watch/88946384" style="position:absolute; left:-9999px;"/>
#     <img alt="" src="https://mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;"/>
#    </div>
#   </noscript>
#   <!-- /Yandex.Metrika counter -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-61773772-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'UA-61773772-1');
#   </script>
#   <script>
#    window.yaContextCb = window.yaContextCb || []
#   </script>
#   <script async="" src="https://yandex.ru/ads/system/context.js">
#   </script>
#   <script>
#    if ('serviceWorker' in navigator) {
# 	window.addEventListener('load', () => {
# 		navigator.serviceWorker.register('/front-service-worker.js').then(reg => {
# 			// sometime later…
# 			reg.update()
# 		})
# 	})
# }
#   </script>
#  </body>
# </html>

# %% [markdown]
# В такой выдаче ориентироваться гораздо удобнее (но при желании, то же можно увидеть в браузере, на большом экране).

# %% [markdown]
# Чтобы сгрузить все новости с главной страницы сайта, нужно собрать все ссылки на страницы с этими новостями. Ссылки в html-файле всегда заключены в тэг `<a></a>` и имеют атрибут `href`.
#
# **Функция `soup.find('a')`** найдет первый в дереве тег \<a>.
# Если нам нужно найти не только первый элемент, а все элементы по определенному признаку, следует использовать функцию **`soup.find_all('a')`**

# %%
soup.find_all('a')
# Out:
# [<a class="w-7.5 h-7.5" href="/search">
#  <svg class="w-full h-full">
#  <use xlink:href="#n1_pupa"></use>
#  </svg>
#  </a>,
#  <a class="col-span-3 lg:col-span-2 col-start-7 lg:col-start-9 flex items-center hover:text-main transition-colors duration-75" href="https://offline.nplus1.ru/">N + offline</a>,
#  <a class="col-span-3 lg:col-span-2 col-start-10 lg:col-start-11 flex items-center hover:text-main transition-colors duration-75" href="https://nplus.pro/">N + production</a>,
#  <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">
#                  О нас
#                </a>,
#  <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#                  Сложность
#                </a>,
#  <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#                  Рекламодателям
#                </a>,
#  <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">
#                  Авторам
#                </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">Игры</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">Физика</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">Зоология</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">Астрономия</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">Генетика</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">Математика</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">Космонавтика</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">Археология</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">Нейронауки</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">На мышах</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">Звук</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">Красота</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">Научные закрытия</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">Когда рассеется дым</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">Книжная полка</a>,
#  <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#  <svg class="w-12 h-12">
#  <use xlink:href="#n1_tg"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#  <svg class="w-12 h-12">
#  <use xlink:href="#n1_vk"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#  <svg class="w-12 h-12">
#  <use xlink:href="#n1_ok"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#  <svg class="w-12 h-12">
#  <use xlink:href="#n1_tw"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">О нас</a>,
#  <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">Сложность</a>,
#  <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">Рекламодателям</a>,
#  <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/news/2015/09/21/editor-thy-name" target="_blank">Вакансии</a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">Игры
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">Физика
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">Зоология
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">Астрономия
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">Генетика
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">Математика
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">Космонавтика
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">Археология
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">Нейронауки
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">На мышах
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">Звук
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">Красота
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">Научные закрытия
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">Когда рассеется дым
#            </a>,
#  <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">Книжная полка
#            </a>,
#  <a class="hover:text-main whitespace-nowrap" href="https://offline.nplus1.ru/">N + offline</a>,
#  <a class="hover:text-main whitespace-nowrap" href="https://nplus.pro/">N + production</a>,
#  <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#  <svg class="w-10 h-10">
#  <use xlink:href="#n1_tg"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#  <svg class="w-10 h-10">
#  <use xlink:href="#n1_vk"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#  <svg class="w-10 h-10">
#  <use xlink:href="#n1_ok"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#  <svg class="w-10 h-10">
#  <use xlink:href="#n1_tw"></use>
#  </svg>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=870">Химия</a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=879">Материалы</a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/5">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">5.7</span>
#  </a>,
#  <a class="" href="https://nplus1.ru/material/2023/10/05/qdots-nobel-2023">
#  <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#  <div class="hidden sm:block max-height-[333px]">
#  <div class="-inset-0.5 absolute group">
#  <picture>
#  <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/841331/25287473fb54662b69f5ff25ecb2daf1.jpg">
#  <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/841332/0e9e68ba948158bfb16f691a03bb0e0c.jpg">
#  <img alt="Шрёдингер в телевизоре" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></picture>
#  </div>
#  </div>
#  <div class="block sm:hidden">
#  <div class="-inset-0.5 absolute max-height-[333px]">
#  <picture>
#  <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/841331/25287473fb54662b69f5ff25ecb2daf1.jpg">
#  <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/841332/0e9e68ba948158bfb16f691a03bb0e0c.jpg">
#  <img alt="Шрёдингер в телевизоре" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></picture>
#  </div>
#  </div>
#  <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#  <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">Шрёдингер в телевизоре</h3>
#  <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#                      Как нобелевские лауреаты по химии материализовали квантовые точки
#                    </div>
#  </div>
#  </div>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=812">Партнерский материал</a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=872">Экология и климат</a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">2.8</span>
#  </a>,
#  <a class="" href="https://nplus1.ru/material/2023/10/04/esg-test">
#  <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#  <div class="hidden sm:block max-height-[333px]">
#  <div class="-inset-0.5 absolute group">
#  <picture>
#  <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/837648/c882a47f573b0288271136029cfcb50d.png">
#  <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/837649/b075d68873a88d96da461834ca7e1f34.png">
#  <img alt="Отвечаешь головой" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></picture>
#  </div>
#  </div>
#  <div class="block sm:hidden">
#  <div class="-inset-0.5 absolute max-height-[333px]">
#  <picture>
#  <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/837648/c882a47f573b0288271136029cfcb50d.png">
#  <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/837649/b075d68873a88d96da461834ca7e1f34.png">
#  <img alt="Отвечаешь головой" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></picture>
#  </div>
#  </div>
#  <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#  <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">Отвечаешь головой</h3>
#  <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#                      Попробуйте справиться с реальными ESG-кейсами
#                    </div>
#  </div>
#  </div>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=869">Физика</a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/4">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">4.9</span>
#  </a>,
#  <a class="" href="https://nplus1.ru/material/2023/10/03/nobel-pulses-2023">
#  <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#  <div class="hidden sm:block max-height-[333px]">
#  <div class="-inset-0.5 absolute group">
#  <picture>
#  <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/840797/00500a7d2ace93ac616788441a953e0f.jpg">
#  <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/840798/85fcc9f518e4ab5371f56aec8401a3db.jpg">
#  <img alt="Импульс укорачивать" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></picture>
#  </div>
#  </div>
#  <div class="block sm:hidden">
#  <div class="-inset-0.5 absolute max-height-[333px]">
#  <picture>
#  <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/840797/00500a7d2ace93ac616788441a953e0f.jpg">
#  <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/840798/85fcc9f518e4ab5371f56aec8401a3db.jpg">
#  <img alt="Импульс укорачивать" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></picture>
#  </div>
#  </div>
#  <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#  <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">Импульс укорачивать</h3>
#  <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#                      Почему нобелевские лауреаты по физике стремились к аттосекундам
#                    </div>
#  </div>
#  </div>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=870">Химия</a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/4">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">4.9</span>
#  </a>,
#  <a class="" href="https://nplus1.ru/news/2023/10/04/chem-nobel-2023">
#  <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#  <div class="hidden sm:block max-height-[333px]">
#  <div class="-inset-0.5 absolute group">
#  <picture>
#  <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/838978/b6a57b60221a4de185ef25eab71044d4.jpg">
#  <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/838979/01a0b40604715ad17efdec71160f58aa.jpg">
#  <img alt="Нобелевскую премию по химии присудили за квантовые точки" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></picture>
#  </div>
#  </div>
#  <div class="block sm:hidden">
#  <div class="-inset-0.5 absolute max-height-[333px]">
#  <picture>
#  <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/838978/b6a57b60221a4de185ef25eab71044d4.jpg">
#  <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/838979/01a0b40604715ad17efdec71160f58aa.jpg">
#  <img alt="Нобелевскую премию по химии присудили за квантовые точки" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></picture>
#  </div>
#  </div>
#  <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#  <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">Нобелевскую премию по химии присудили за квантовые точки</h3>
#  <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#                      Ее получат Мунги Бавенди, Луис Брюс и Алексей Екимов
#                    </div>
#  </div>
#  </div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/05">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">05.10.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
#  <p class="truncate">Медицина</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.6</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/05/manganese-accumulation-in-the-brain">
#  <div>Врачи описали хроническое отравление марганцем из-за сварочных работ</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">04.10.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=884">
#  <p class="truncate">Геология</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/5">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">5.6</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/sulfur-of-deccan-traps">
#  <div>Извержения Деканских траппов принесли динозаврам серию вулканических зим перед ударом астероида</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">04.10.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
#  <p class="truncate">Медицина</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.6</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/heartbreaking">
#  <div>Злоупотребление каннабисом связали с повышенным риском болезней сердца и сосудов</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">04.10.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=871">
#  <p class="truncate">Космонавтика</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.9</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/osiris-rex-deploy-capsule">
#  <div>NASA показало полет возвращаемой капсулы станции OSIRIS-REx к Земле</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">04.10.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
#  <p class="truncate">Медицина</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.3</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/vehicle-crash-adhd">
#  <div>Пожилые водители с СДВГ отличились повышенным риском ДТП</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">04.10.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=874">
#  <p class="truncate">Зоология</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.5</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/same-sex-behaviour-mammals">
#  <div>Однополое сексуальное поведение млекопитающих связали с развитием социальности</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">04.10.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=880">
#  <p class="truncate">Астрономия</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/4">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">4.9</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/frb-gw-or-no">
#  <div>Астрономы не нашли связи между быстрыми радиовсплесками и гравитационными всплесками</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">04.10.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=877">
#  <p class="truncate">Антропология</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">3.1</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/ak-alakha">
#  <div>Знатному пазырыкцу поставили диффузный идиопатический скелетный гиперостоз</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">04.10.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
#  <p class="truncate">Медицина</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.3</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/second-vaccine-for-malaria">
#  <div>ВОЗ одобрила вторую противомалярийную вакцину для широкого применения</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">04.10.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=870">
#  <p class="truncate">Химия</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/4">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">4.9</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/chem-nobel-2023">
#  <div>Нобелевскую премию по химии присудили за квантовые точки</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">04.10.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=877">
#  <p class="truncate">Антропология</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.9</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/neolithic-jericho">
#  <div>Среди 44 жителей Иерихона эпохи докерамического неолита нашли двух неместных</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">04.10.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=887">
#  <p class="truncate">Транспорт</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.7</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/we-drive-solar-sharing-batteries">
#  <div>Каршеринговые электромобили в Нидерландах поделятся энергией с городской электросетью</div>
#  </a>,
#  <a class="shrink-0 h-60 lg:h-72 xl:h-88 relative group" href="https://nplus1.ru/blog/2023/10/04/visual-glue">
#  <picture>
#  <source media="(max-width: 768px)" srcset="https://minio.nplus1.ru/app-images/840625/651c1185e9422_cover_mobile.jpg">
#  <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/840624/651c118586bac_cover_tablet.jpg">
#  <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/840623/651c11852292a_cover.jpg">
#  <img alt="«Визуальный клей»" class="w-full h-full object-cover" loading="lazy" src="https://minio.nplus1.ru/app-images/840623/651c11852292a_cover.jpg"/>
#  </source></source></source></picture>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/blog/2023/10/04">
#  <span class="group-hover:text-main transition-colors duration-75">04.10.23</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=882">
#  <span class="group-hover:text-main transition-colors duration-75">Психология</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">1.1</span>
#  </a>,
#  <a class="group" href="https://nplus1.ru/blog/2023/10/04/visual-glue">
#  <h3 class="text-34 sm:text-22 lg:text-32 mb-1 transition-colors duration-75 group-hover:text-main">
#                  «Визуальный клей»</h3>
#  <p class="font-spectral text-main-gray text-36 sm:text-24 lg:text-34 transition-colors duration-75 group-hover:text-main">
#                  Как направление чтения влияет на восприятие изображений</p>
#  </a>,
#  <a class="shrink-0 h-60 lg:h-72 xl:h-88 relative group" href="https://nplus1.ru/blog/2023/10/03/dangerous-minds">
#  <picture>
#  <source media="(max-width: 768px)" srcset="https://minio.nplus1.ru/app-images/838844/6516bfc9c342d_cover_mobile.jpg">
#  <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/838843/6516bfc965f64_cover_tablet.jpg">
#  <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/838842/6516bfc8f2850_cover.jpg">
#  <img alt="«Преступный разум: Судебный психиатр о маньяках, психопатах, убийцах и природе насилия»" class="w-full h-full object-cover" loading="lazy" src="https://minio.nplus1.ru/app-images/838842/6516bfc8f2850_cover.jpg"/>
#  </source></source></source></picture>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/blog/2023/10/03">
#  <span class="group-hover:text-main transition-colors duration-75">03.10.23</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=873">
#  <span class="group-hover:text-main transition-colors duration-75">Медицина</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">1.1</span>
#  </a>,
#  <a class="group" href="https://nplus1.ru/blog/2023/10/03/dangerous-minds">
#  <h3 class="text-34 sm:text-22 lg:text-32 mb-1 transition-colors duration-75 group-hover:text-main">
#                  «Преступный разум: Судебный психиатр о маньяках, психопатах, убийцах и природе насилия»</h3>
#  <p class="font-spectral text-main-gray text-36 sm:text-24 lg:text-34 transition-colors duration-75 group-hover:text-main">
#                  Как СДВГ может подтолкнуть к правонарушению</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/04">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">04.10.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=874">
#  <p class="truncate">Зоология</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.1</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/04/orca-vs-sea-otters">
#  <div>Косатка проглотила шесть каланов и подавилась седьмым</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/03">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">03.10.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=874">
#  <p class="truncate">Зоология</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.7</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/03/wolves-love-story">
#  <div>Итальянский волк и иберийская волчица образовали гибридную пару</div>
#  </a>,
#  <a class="w-full h-44 group relative" href="https://nplus1.ru/material/2023/09/28/hobbies-of-scientists">
#  <picture>
#  <source media="(max-width: 768px)" srcset="https://minio.nplus1.ru/app-images/831042/64fb0d5b6e16c_list_cover_mobile.png">
#  <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/831042/64fb0d5b6e16c_list_cover_mobile.png">
#  <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/831041/64fb0d5aecf37_list_cover.png">
#  <img alt="Не наукой единой" class="w-full h-full object-cover z-10" loading="lazy" src="https://minio.nplus1.ru/app-images/831041/64fb0d5aecf37_list_cover.png"/>
#  </source></source></source></picture>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/2023/09/28">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">28.09.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=946">
#  <p class="truncate">Игры</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.5</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/material/2023/09/28/hobbies-of-scientists">
#  <div>Не наукой единой</div>
#  <div class="text-main-gray">Тест о хобби великих ученых</div>
#  </a>,
#  <a class="shrink-0 absolute inset-0 group" href="https://nplus1.ru/material/2023/09/27/opensource-philosophy">
#  <picture>
#  <source media="(max-width: 768px)" srcset="https://minio.nplus1.ru/app-images/835740/5b59c1c1006096e67fbd2b6613263cee.png">
#  <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/835739/b5eead54edbe224211afc183137cafb8.png">
#  <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/835739/b5eead54edbe224211afc183137cafb8.png">
#  <img alt="Философия кода" class="w-full h-full object-cover absolute inset-0 brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#  </source></source></source></picture>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=812">
#  <span class="group-hover:text-main transition-colors duration-75">Партнерский материал</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">1.8</span>
#  </a>,
#  <a class="group text-white absolute bottom-5 inset-x-6 md:inset-x-5" href="https://nplus1.ru/material/2023/09/27/opensource-philosophy">
#  <h3 class="text-14 sm:text-22 lg:text-32 mb-1 transition-colors duration-75 group-hover:text-main">
#                          Дмитрий Разумовский
#            </h3>
#  <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#            Философия кода
#          </p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/blog/2023/09/29">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">29.09.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=817">
#  <p class="truncate">История</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.1</span>
#  </a>,
#  <a class="flex flex-col text-14 overflow-hidden" href="/author/alpina-non-fiksn">
#  <div class="mb-0.5 max-w-full whitespace-nowrap overflow-hidden text-ellipsis">
#
#                                  Альпина нон-фикшн
#                </div>
#  <div class="font-spectral max-w-full whitespace-nowrap overflow-hidden text-ellipsis">
#                  Научно-популярное издательство
#                </div>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/blog/2023/09/29/history-of-the-death-penalty">
#  <div>«Право на жизнь. История смертной казни»</div>
#  <div class="text-main-gray">Традиция смертной казни в Японии</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/03">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">03.10.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=874">
#  <p class="truncate">Зоология</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">3.3</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/03/bivalve-cancer">
#  <div>Заразный рак двустворчатых моллюсков оказался генетически нестабилен</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/03">
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">03.10.23</span>
#  </a>,
#  <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=874">
#  <p class="truncate">Зоология</p>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.3</span>
#  </a>,
#  <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2023/10/03/butterflies-plugs">
#  <div>Самцы бабочек с умом подошли к выбору размера копуляционной пробки</div>
#  </a>,
#  <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2023/10/03">
# ...
#  <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#            Сколько воды утекло</p>
#  <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#              Калькулятор ваших литров</p>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/2023/09/04">
#  <span class="group-hover:text-main transition-colors duration-75">04.09.23</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=946">
#  <span class="group-hover:text-main transition-colors duration-75">
#              Игры
#              </span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/4">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">
#            4.1
#          </span>
#  </a>,
#  <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/material/2023/09/04/assemble-the-electrical-network">
#  <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#            Где здесь фаза?</p>
#  <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#              Непростой тест о простом электричестве</p>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/2023/09/27">
#  <span class="group-hover:text-main transition-colors duration-75">27.09.23</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=946">
#  <span class="group-hover:text-main transition-colors duration-75">
#              Игры
#              </span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">
#            2.7
#          </span>
#  </a>,
#  <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/material/2023/09/27/domestication-of-animals">
#  <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#            Когда мы это одомашнили. Часть 1</p>
#  <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#              Игра о приручении братьев наших меньших</p>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/2023/09/22">
#  <span class="group-hover:text-main transition-colors duration-75">22.09.23</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=946">
#  <span class="group-hover:text-main transition-colors duration-75">
#              Игры
#              </span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">
#            2.7
#          </span>
#  </a>,
#  <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/material/2023/09/22/who-died-out-first">
#  <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#            Кто вымер раньше</p>
#  <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#              Игра о тех, кого больше нет с нами</p>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/2023/08/28">
#  <span class="group-hover:text-main transition-colors duration-75">28.08.23</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=946">
#  <span class="group-hover:text-main transition-colors duration-75">
#              Игры
#              </span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/2">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">
#            2.2
#          </span>
#  </a>,
#  <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/material/2023/08/28/what-for">
#  <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#            Для чего это все</p>
#  <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#              Тест о гаджетах прошлого, про которые все забыли</p>
#  </a>,
#  <a class="absolute inset-0 md:static order-2 shrink-0 brightness-50 md:brightness-100" href="https://nplus1.ru/material/2023/10/03/mrna-nobel-2023">
#  <picture>
#  <source media="(max-width: 768px)" srcset="https://minio.nplus1.ru/app-images/840622/38a24697b7a206c83a1f6b102389c6f2.jpg">
#  <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/840622/38a24697b7a206c83a1f6b102389c6f2.jpg">
#  <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/840242/b3e1def00ca24e4d28b601973a150179.jpg">
#  <img alt="Это свои" class="w-full h-full object-cover" loading="lazy" src="https://minio.nplus1.ru/app-images/840242/b3e1def00ca24e4d28b601973a150179.jpg"/>
#  </source></source></source></picture>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/2023/10/03">
#  <span class="group-hover:text-main transition-colors duration-75">03.10.23</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=873">
#  <span class="group-hover:text-main transition-colors duration-75">Медицина</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=885">
#  <span class="group-hover:text-main transition-colors duration-75">Биология</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/5">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">5.6</span>
#  </a>,
#  <a class="group" href="https://nplus1.ru/material/2023/10/03/mrna-nobel-2023">
#  <h3 class="text-34 lg:text-44 mb-1 transition-colors duration-75 group-hover:text-main">
#                  Это свои</h3>
#  <p class="text-white md:text-main-gray font-spectral text-36 lg:text-46 transition-colors duration-75 group-hover:text-main">
#                  Как нобелевские лауреаты по медицине научили клетки не бояться мРНК-вакцин</p>
#  </a>,
#  <a class="absolute inset-0 md:static order-2 md:order-1 shrink-0 brightness-50 md:brightness-100" href="https://nplus1.ru/material/2023/09/29/maverick-unchained">
#  <picture>
#  <source media="(max-width: 768px)" srcset="https://minio.nplus1.ru/app-images/817684/ae60a39143f07cb44b75cf83ce759f15.jpg">
#  <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/817684/ae60a39143f07cb44b75cf83ce759f15.jpg">
#  <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/817681/726c1ebca8ba5ad09c5746b1e861520c.gif">
#  <img alt="Побег из генома" class="w-full h-full object-cover" loading="lazy" src="https://minio.nplus1.ru/app-images/817681/726c1ebca8ba5ad09c5746b1e861520c.gif"/>
#  </source></source></source></picture>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/2023/09/29">
#  <span class="group-hover:text-main transition-colors duration-75">29.09.23</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=885">
#  <span class="group-hover:text-main transition-colors duration-75">Биология</span>
#  </a>,
#  <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/5">
#  <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#  <use xlink:href="#n1_star"></use>
#  </svg>
#  <span class="group-hover:text-main transition-colors duration-75">5.1</span>
#  </a>,
#  <a class="group" href="https://nplus1.ru/material/2023/09/29/maverick-unchained">
#  <h3 class="text-34 lg:text-44 mb-1 transition-colors duration-75 group-hover:text-main">
#                  Побег из генома</h3>
#  <p class="text-white md:text-main-gray font-spectral text-36 lg:text-46 transition-colors duration-75 group-hover:text-main">
#                  Кто помог гену перепрыгнуть от одной нематоды к другой</p>
#  </a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/material/2023/09/14/blanche-par-le-malheur">
#                Побелевшие от горя</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2023/09/15/earth-core-density-deficit">
#                Дефицит плотности ядра Земли в два раза превысил предыдущие оценки</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2023/09/16/erase-and-rewire">
#                Механизм развития синдрома Ангельмана связали с пресинаптическими рецепторами</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2023/09/20/nothing-extra">
#                Человеческая сперма оказалась лишена митохондриальной ДНК</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2023/09/21/put-through">
#                Универсальная нанопора поможет эффективно секвенировать белки</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2023/09/22/topological-phonons-in-graphene">
#                Физики обнаружили топологические фононы в графене</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2023/09/23/jwst-europe-co2">
#                «Джеймс Уэбб» нашел на поверхности Европы углекислый газ из подповерхностного океана</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2023/09/23/be-my-guide">
#                Целенаправленная регенерация аксонов восстановила ходьбу у парализованных мышей</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/material/2023/09/25/astro-impulse">
#                Звездный транспорт</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/material/2023/09/29/maverick-unchained">
#                Побег из генома</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/material/2023/10/03/mrna-nobel-2023">
#                Это свои</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/material/2023/10/03/nobel-pulses-2023">
#                Импульс укорачивать</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2023/10/04/frb-gw-or-no">
#                Астрономы не нашли связи между быстрыми радиовсплесками и гравитационными всплесками</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/news/2023/10/04/sulfur-of-deccan-traps">
#                Извержения Деканских траппов принесли динозаврам серию вулканических зим перед ударом астероида</a>,
#  <a class="font-spectral text-20 sm:text-22 transition-colors duration-75 hover:text-main font-spectral" href="https://nplus1.ru/material/2023/10/05/qdots-nobel-2023">
#                Шрёдингер в телевизоре</a>,
#  <a class="transition-colors duration-75 hover:text-main" href="https://nplus1.ru/about" target="_blank">О нас</a>,
#  <a class="transition-colors duration-75 hover:text-main" href="https://nplus1.ru/difficult" target="_blank">Сложность</a>,
#  <a class="transition-colors duration-75 hover:text-main" href="https://nplus1.ru/adv" target="_blank">Рекламодателям</a>,
#  <a class="transition-colors duration-75 hover:text-main" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">Авторам</a>,
#  <a href="/cdn-cgi/l/email-protection#315f5d715f415d4442001f4344"><span class="__cf_email__" data-cfemail="791715391709150c0a48570b0c">[email protected]</span></a>,
#  <a href="/cdn-cgi/l/email-protection#84edeae2ebc4eaf4e8f1f7b5aaf6f1"><span class="__cf_email__" data-cfemail="9af3f4fcf5daf4eaf6efe9abb4e8ef">[email protected]</span></a>,
#  <a class="underline transition-colors duration-75 hover:text-main inline-block col-span-6 sm:col-span-5 mb-5 font-spectral italic" href="/personal-data-policy">Политика
#            обработки
#            персональных данных пользователей сайта
#          </a>,
#  <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#  <svg class="w-12 h-12">
#  <use xlink:href="#n1_tg"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#  <svg class="w-12 h-12">
#  <use xlink:href="#n1_vk"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#  <svg class="w-12 h-12">
#  <use xlink:href="#n1_ok"></use>
#  </svg>
#  </a>,
#  <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#  <svg class="w-12 h-12">
#  <use xlink:href="#n1_tw"></use>
#  </svg>
#  </a>]

# %%
len(soup.find_all('a'))
# Out:
# 436

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# /search
# https://offline.nplus1.ru/
# https://nplus.pro/
# https://nplus1.ru/about
# https://nplus1.ru/difficult
# https://nplus1.ru/adv
# https://nplus1.ru/blog/2022/04/01/samotek
# https://nplus1.ru/search?tags=946
# https://nplus1.ru/search?tags=869
# https://nplus1.ru/search?tags=874
# https://nplus1.ru/search?tags=880
# https://nplus1.ru/search?tags=768
# https://nplus1.ru/search?tags=890
# https://nplus1.ru/search?tags=871
# https://nplus1.ru/search?tags=876
# https://nplus1.ru/search?tags=775
# https://nplus1.ru/search?tags=767
# https://nplus1.ru/search?tags=771
# https://nplus1.ru/search?tags=946
# /material/difficulty/2
# https://nplus1.ru/material/2023/08/28/what-for
# https://nplus1.ru/material/2023/10/03/mrna-nobel-2023
# /material/2023/10/03
# https://nplus1.ru/search?tags=873
# https://nplus1.ru/search?tags=885
# /material/difficulty/5
# https://nplus1.ru/material/2023/10/03/mrna-nobel-2023
# https://nplus1.ru/material/2023/09/29/maverick-unchained
# /material/2023/09/29
# https://nplus1.ru/search?tags=885
# /material/difficulty/5
# https://nplus1.ru/material/2023/09/29/maverick-unchained
# https://nplus1.ru/material/2023/09/14/blanche-par-le-malheur
# https://nplus1.ru/news/2023/09/15/earth-core-density-deficit
# https://nplus1.ru/news/2023/09/16/erase-and-rewire
# https://nplus1.ru/news/2023/09/20/nothing-extra
# https://nplus1.ru/news/2023/09/21/put-through
# https://nplus1.ru/news/2023/09/22/topological-phonons-in-graphene
# https://nplus1.ru/news/2023/09/23/jwst-europe-co2
# https://nplus1.ru/news/2023/09/23/be-my-guide
# https://nplus1.ru/material/2023/09/25/astro-impulse
# https://nplus1.ru/material/2023/09/29/maverick-unchained
# https://nplus1.ru/material/2023/10/03/mrna-nobel-2023
# https://nplus1.ru/material/2023/10/03/nobel-pulses-2023
# https://nplus1.ru/news/2023/10/04/frb-gw-or-no
# https://nplus1.ru/news/2023/10/04/sulfur-of-deccan-traps
# https://nplus1.ru/material/2023/10/05/qdots-nobel-2023
# https://nplus1.ru/about
# https://nplus1.ru/difficult
# https://nplus1.ru/adv
# https://nplus1.ru/blog/2022/04/01/samotek
# /cdn-cgi/l/email-protection#315f5d715f415d4442001f4344
# /cdn-cgi/l/email-protection#84edeae2ebc4eaf4e8f1f7b5aaf6f1
# /personal-data-policy
# https://t.me/nplusone
# https://vk.com/nplusone
# https://ok.ru/nplus1
# https://twitter.com/nplusodin

# %% [markdown]
# Ссылок много. Но нам нужны только новости – ссылки, которые начинаются со слова `/news`. Добавим условие: будем выбирать только те ссылки, в которых есть `/news`. Создадим пустой список `urls` и будем добавлять в него только ссылки, которые удовлетворяют этому условию.

# %%
urls = []

for link in soup.find_all('a'):
#     print(link)
    if '/news' in link.get('href'):
        if 'https://' in link.get('href'):
            urls.append(link.get('href'))
urls
# Out:
# ['https://nplus1.ru/news/2015/09/21/editor-thy-name',
#  'https://nplus1.ru/news/2023/10/04/chem-nobel-2023',
#  'https://nplus1.ru/news/2023/10/05/manganese-accumulation-in-the-brain',
#  'https://nplus1.ru/news/2023/10/04/sulfur-of-deccan-traps',
#  'https://nplus1.ru/news/2023/10/04/heartbreaking',
#  'https://nplus1.ru/news/2023/10/04/osiris-rex-deploy-capsule',
#  'https://nplus1.ru/news/2023/10/04/vehicle-crash-adhd',
#  'https://nplus1.ru/news/2023/10/04/same-sex-behaviour-mammals',
#  'https://nplus1.ru/news/2023/10/04/frb-gw-or-no',
#  'https://nplus1.ru/news/2023/10/04/ak-alakha',
#  'https://nplus1.ru/news/2023/10/04/second-vaccine-for-malaria',
#  'https://nplus1.ru/news/2023/10/04/chem-nobel-2023',
#  'https://nplus1.ru/news/2023/10/04/neolithic-jericho',
#  'https://nplus1.ru/news/2023/10/04/we-drive-solar-sharing-batteries',
#  'https://nplus1.ru/news/2023/10/04/orca-vs-sea-otters',
#  'https://nplus1.ru/news/2023/10/03/wolves-love-story',
#  'https://nplus1.ru/news/2023/10/03/bivalve-cancer',
#  'https://nplus1.ru/news/2023/10/03/butterflies-plugs',
#  'https://nplus1.ru/news/2023/10/03/gwas-carrot',
#  'https://nplus1.ru/news/2023/10/03/phys-nobel-2023',
#  'https://nplus1.ru/news/2023/10/03/yamnaya-people-and-multiple-sclerosis',
#  'https://nplus1.ru/news/2023/10/03/viking-age-burial-in-garden',
#  'https://nplus1.ru/news/2023/10/03/music-reading-dementia',
#  'https://nplus1.ru/news/2023/10/03/gobekli-tepe',
#  'https://nplus1.ru/news/2023/10/03/loneliness-and-risk-of-pd',
#  'https://nplus1.ru/news/2023/10/03/jwst-m-42',
#  'https://nplus1.ru/news/2023/10/03/baby-beaver',
#  'https://nplus1.ru/news/2023/10/02/nitrogen-fertilisers',
#  'https://nplus1.ru/news/2023/10/02/kelping',
#  'https://nplus1.ru/news/2023/10/02/probiotics-preterm-infants',
#  'https://nplus1.ru/news/2023/10/02/millimobile-battery-free-robot',
#  'https://nplus1.ru/news/2023/10/02/carbene-double-oxidation',
#  'https://nplus1.ru/news/2023/10/02/enlight-short-list-2023',
#  'https://nplus1.ru/news/2023/10/02/lincombian-ranisian-jerzmanowician',
#  'https://nplus1.ru/news/2023/10/02/physmed-nobel-2023',
#  'https://nplus1.ru/news/2023/10/02/september-2023',
#  'https://nplus1.ru/news/2023/10/02/abydos-wine-jars',
#  'https://nplus1.ru/news/2023/10/02/petranola',
#  'https://nplus1.ru/news/2023/10/02/neanderthals-from-altai',
#  'https://nplus1.ru/news/2023/10/03/gobekli-tepe',
#  'https://nplus1.ru/news/2023/09/15/bathory-family',
#  'https://nplus1.ru/news/2023/09/20/earliest-wood-construction',
#  'https://nplus1.ru/news/2023/09/27/pyramid-of-sahure',
#  'https://nplus1.ru/news/2023/09/27/ninth-pangolin',
#  'https://nplus1.ru/news/2023/09/22/new-language',
#  'https://nplus1.ru/news/2023/09/15/earth-core-density-deficit',
#  'https://nplus1.ru/news/2023/09/15/earth-core-density-deficit',
#  'https://nplus1.ru/news/2023/09/16/erase-and-rewire',
#  'https://nplus1.ru/news/2023/09/20/nothing-extra',
#  'https://nplus1.ru/news/2023/09/21/put-through',
#  'https://nplus1.ru/news/2023/09/22/topological-phonons-in-graphene',
#  'https://nplus1.ru/news/2023/09/23/jwst-europe-co2',
#  'https://nplus1.ru/news/2023/09/23/be-my-guide',
#  'https://nplus1.ru/news/2023/10/04/frb-gw-or-no',
#  'https://nplus1.ru/news/2023/10/04/sulfur-of-deccan-traps']

# %%
len(urls)
# Out:
# 55

# %%
urls[1]
# Out:
# 'https://nplus1.ru/news/2023/10/04/chem-nobel-2023'

# %% [markdown]
# Теперь наша задача сводится к следующему: изучить одну страницу с новостью, научиться из нее вытаскивать текст и всю необходимую информацию, а потом применить весь набор действий к каждой ссылке из `full_urls` в цикле. Посмотрим на новость с индексом 1, у вас может быть другая, новости обновляются.

# %%
url0 = urls[1]

page0 = requests.get(url0)
print(page0)

soup0 = BeautifulSoup(page0.text, 'html')
print(soup0)
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <html lang="ru" prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Нобелевскую премию по химии присудили за квантовые точки. Ее получат Мунги Бавенди, Луис Брюс и Алексей Екимов</title>
# <link as="font" crossorigin="" href="https://staticn1.nplus1.ru/fonts/AeonikPro/AeonikPro-Regular.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://staticn1.nplus1.ru/fonts/Spectral/Spectral-Regular.woff" rel="preload" type="font/woff2"/>
# <link href="/front-build/css/main.css?id=c066269c9e31b8c5719ba747306ba601" rel="stylesheet"/>
# <link href="/front-build/css/app.css?id=ab07a66910bee48e90bcb5a042d79cad" rel="stylesheet"/>
# <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/site.webmanifest" rel="manifest"/>
# <link color="#f26e40" href="/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="#f26e40" name="msapplication-TileColor"/>
# <meta content="#ffffff" name="theme-color"/>
# <link href="https://nplus1.ru/news/2023/10/04/chem-nobel-2023" rel="canonical"/>
# <meta content="8c90b02c84ac3b72" name="yandex-verification"/>
# <meta content="b419949322895fc9106e24ed01be58ac" name="pmail-verification"/>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#
#     })(window,document,'script','dataLayer','GTM-PJWMQBQ');</script>
# <!-- End Google Tag Manager -->
# <meta content="N + 1 — главное издание о науке, технике и технологиях" name="description"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:site_name"/>
# <meta content="Нобелевскую премию по химии присудили за квантовые точки" property="og:title"/>
# <meta content="https://minio.nplus1.ru/app-images/838971/6516cd4f91d3b_cover_share.jpg" property="og:image"/>
# <meta content="https://nplus1.ru/news/2023/10/04/chem-nobel-2023" property="og:url"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="2023-10-04" itemprop="datePublished"/>
# <!-- amp page -->
# <link href="https://nplus1.ru/news/2023/10/04/chem-nobel-2023/amp" rel="amphtml"/>
# <meta content="2023-10-04" itemprop="datePublished"/>
# <meta content="Михаил Бойм" name="mediator_author"/>
# <meta content="Михаил Бойм" name="author"/>
# <meta content="" name="copyright"/>
# <script type="application/ld+json">
#     {
#       "@context": "https://schema.org",
#       "@type": "NewsArticle",
#       "mainEntityOfPage": {
#         "@type": "WebPage",
#         "@id": "https://nplus1.ru/news/2023/10/04/chem-nobel-2023"
#       },
#       "headline": "Нобелевскую премию по химии присудили за квантовые точки",
#       "description": "Ее получат Мунги Бавенди, Луис Брюс и Алексей Екимов",
#             "image": "https://minio.nplus1.ru/app-images/838971/6516cd4f91d3b_cover_share.jpg",
#
#
#
#
#           "author": {
#         "@type": "Person",
#         "name": "Михаил Бойм",
#                 "image": "https://staticn1.nplus1.ru/image-new/logo-alt.png",
#               "url": "https://nplus1.ru/author/mixail-boim"
#         },
#
#         "publisher": {
#       "@type": "Organization",
#       "name": "N+1",
#       "logo": {
#         "@type": "ImageObject",
#         "url": "https://minio.nplus1.ru/app-images/838971/6516cd4f91d3b_cover_share.jpg"
#       }
#     },
#     "datePublished": "2023-10-04",
#       "dateModified": "2023-10-04"
#     }
#
#
#
#     </script>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@nplusodin" name="twitter:site"/>
# <meta content="Нобелевскую премию по химии присудили за квантовые точки" name="twitter:title"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" name="twitter:description"/>
# <meta content="https://minio.nplus1.ru/app-images/838971/6516cd4f91d3b_cover_share.jpg" name="twitter:image"/>
# <link href="https://nplus1.ru/rss" rel="alternate" title="RSS" type="application/rss+xml"/>
# </head>
# <body class="antialiased">
# <!-- Top.Mail.Ru counter -->
# <script type="text/javascript">
#
# var tmr = window.tmr || (window._tmr = []);
#
# _tmr.push({id: "3377932", type: "pageView", start: (new Date()).getTime()});
#
# (function (d, w, id) {
#
#   if (d.getElementById(id)) return;
#
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
#
# })(document, window, "tmr-code");
#
# </script>
# <noscript><div><img alt="Top.Mail.Ru" src="https://top-fwz1.mail.ru/counter?id=3377932;js=na" style="position:absolute;left:-9999px;"/></div></noscript>
# <!-- /Top.Mail.Ru counter -->
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PJWMQBQ" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div class="font-aeonik text-main-black flex flex-col min-h-screen pt-15 bg-light-gray" id="appfront">
# <header class="bg-light-gray fixed h-15 left-0 top-0 w-full z-50" data-ref-header="" ref="headerRef">
# <div class="absolute bg-main-gray/5 bottom-0 left-0 top-0" id="progressBar" style="z-index: -1"></div>
# <div class="border-b border-main-gray h-full">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto flex justify-between items-center h-full" data-ref-header-container="" ref="headerContainerRef">
# <button aria-label="Go" class="w-7.5 h-7.5" data-ref-header-menu-btn="" id="topMenuBtn" ref="headerMenuBtnRef">
# <template v-if="isOpenDesktopMenu || isOpenMobileMenu">
# <svg class="w-full h-full">
# <use xlink:href="#n1_cross_menu"></use>
# </svg>
# </template>
# <template v-else="">
# <svg class="w-full h-full">
# <use xlink:href="#n1_burger"></use>
# </svg>
# </template>
# </button>
# <div>
# <a href="/">
# <img alt="as" height="23" loading="lazy" src="https://staticn1.nplus1.ru/image-new/logo.svg" width="57"/>
# </a>
# </div>
# <a class="w-7.5 h-7.5" href="/search">
# <svg class="w-full h-full">
# <use xlink:href="#n1_pupa"></use>
# </svg>
# </a>
# </div>
# </div>
# <nav :style="stylesNavDesktop" class="relative bg-light-gray max-h-0 n1_top_nav overflow-hidden" id="navMenu" v-if="isOpenDesktopMenu">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
# <div class="py-12 mb-12 border-b border-gray-2 text-18 grid grid-cols-flow lg:grid-cols-12 gap-x-5 md:gap-x-9">
# <!--
#         <a @click.native="menuClose"
#            class="col-span-3 flex gap-x-2 lg:gap-x-5 items-center hover:text-main transition-colors duration-75"
#            href="/lk">
#           <svg class="h-10 lg:h-12 w-10 lg:w-12 shrink-0">
#             <use xlink:href="#n1_person"></use>
#           </svg>
#           <span>Личный кабинет</span>
#         </a>
#         -->
# <a class="col-span-3 lg:col-span-2 col-start-7 lg:col-start-9 flex items-center hover:text-main transition-colors duration-75" href="https://offline.nplus1.ru/">N + offline</a>
# <a class="col-span-3 lg:col-span-2 col-start-10 lg:col-start-11 flex items-center hover:text-main transition-colors duration-75" href="https://nplus.pro/">N + production</a>
# </div>
# <div class="grid grid-cols-12 gap-x-5 gap-y-5 md:gap-y-9 pb-6">
# <div class="col-span-6 md:col-span-3 text-20 lg:text-26 xl:text-34 font-spectral flex flex-col gap-y-3">
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">
#                 О нас
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#                 Сложность
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#                 Рекламодателям
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">
#                 Авторам
#               </a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">Игры</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">Физика</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">Зоология</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">Астрономия</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">Генетика</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">Математика</a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">Космонавтика</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">Археология</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">Нейронауки</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">На мышах</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">Звук</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">Красота</a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">Научные закрытия</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">Когда рассеется дым</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">Книжная полка</a>
# </div>
# </div>
# <div class="py-12 mt-auto border-t border-gray-2 text-18 grid grid-cols-12 gap-x-5 md:gap-x-9">
# <ul class="flex gap-2.5">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <nav :style="stylesNavMobile" class="relative bg-white max-h-0 n1_top_nav overflow-hidden" id="mobNavMenu" v-if="isOpenMobileMenu">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
# <div class="text-30 font-spectral flex flex-col gap-y-5 mb-10 mt-10">
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">О нас</a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">Сложность</a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">Рекламодателям</a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/news/2015/09/21/editor-thy-name" target="_blank">Вакансии</a>
# </div>
# <div class="text-28 text-main flex flex-col gap-y-2.5 mb-10">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">Игры
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">Физика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">Зоология
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">Астрономия
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">Генетика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">Математика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">Космонавтика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">Археология
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">Нейронауки
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">На мышах
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">Звук
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">Красота
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">Научные закрытия
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">Когда рассеется дым
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">Книжная полка
#           </a>
# </div>
# <div class="max-w-full flex py-5 border-t border-gray-2">
# <div class="flex gap-x-5 overflow-x-auto">
# <a class="hover:text-main whitespace-nowrap" href="https://offline.nplus1.ru/">N + offline</a>
# <a class="hover:text-main whitespace-nowrap" href="https://nplus.pro/">N + production</a>
# </div>
# </div>
# <div class="pt-5 pb-10 border-t border-gray-2 text-18">
# <ul class="flex gap-2.5">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# </header>
# <app-heading-nav></app-heading-nav>
# <section class="mb-15 md:mb-20">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 md:grid-cols-12 gap-x-5 md:gap-x-9 relative overflow-hidden" data-heading-wrap="">
# <!--tags-->
# <div class="flex-wrap col-span-6 md:col-span-12 lg:col-span-2 mt-5 -mb-2.5 lg:-mb-0 lg:mt-10 content-start mr-9">
# <div class="flex flex-wrap lg:mb-10 gap-2 text-tags xl:pr-9">
# <span class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center">
# <span class="group-hover:text-main transition-colors duration-75">12:54</span>
# </span>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/news/2023/10/04">
# <span class="group-hover:text-main transition-colors duration-75">04.10.23</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/4">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">4.9</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=870">
# <span class="group-hover:text-main transition-colors duration-75">Химия</span>
# </a>
# </div>
# <div class="hidden lg:flex items-center gap-x-2">
# <a class="group" href="https://nplus1.ru/material-print/66282" target="_blank">
# <svg class="group-hover:text-main transition-colors duration-75 stroke-current" fill="none" height="30" viewbox="0 0 22 30" width="22" xmlns="http://www.w3.org/2000/svg">
# <rect height="29" width="21" x="0.5" y="0.5"></rect>
# <line x1="4" x2="18" y1="7.5" y2="7.5"></line>
# <line x1="4" x2="18" y1="21.5" y2="21.5"></line>
# <line x1="4" x2="18" y1="14.5" y2="14.5"></line>
# </svg>
# </a>
# <app-copy-material link="https://nplus1.ru/news/2023/10/04/chem-nobel-2023" type="full-2"></app-copy-material>
# </div>
# <div class="w-full flex flex-col mt-5">
# </div>
# </div>
# <!--dotes menu mobile-->
# <template v-if="isMobile">
# <button class="absolute flex right-5 top-5 z-30 text-main-black">
# <svg class="fill-current" fill="none" height="30" viewbox="0 0 30 30" width="30" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M17 6C17 6.55228 16.5523 7 16 7H15C14.4477 7 14 6.55228 14 6V5C14 4.44772 14.4477 4 15 4H16C16.5523 4 17 4.44772 17 5V6ZM17 23C17 23.5523 16.5523 24 16 24H15C14.4477 24 14 23.5523 14 23V22C14 21.4477 14.4477 21 15 21H16C16.5523 21 17 21.4477 17 22V23ZM14 14.5C14 15.0523 14.4477 15.5 15 15.5H16C16.5523 15.5 17 15.0523 17 14.5V13.5C17 12.9477 16.5523 12.5 16 12.5H15C14.4477 12.5 14 12.9477 14 13.5V14.5Z" fill-rule="evenodd"></path>
# </svg>
# </button>
# <div :class="{
#            'transition-transform flex items-center gap-x-7.5 absolute top-0 right-0 w-full px-6 md:px-8 h-20 bg-white z-30 justify-end bg-light-gray':true,
#            '-translate-x-full': !isOpenMobileDotsMenu,
#            '-translate-x-0': isOpenMobileDotsMenu
#            }" ref="mobileDotsMenuRef">
# <app-copy-material link="https://nplus1.ru/news/2023/10/04/chem-nobel-2023" type="mobile"></app-copy-material>
# <button aria-label="Go" class="group">
# <svg class="group-focus:text-main transition-colors duration-75 stroke-current" fill="none" height="40" viewbox="0 0 30 40" width="30" xmlns="http://www.w3.org/2000/svg">
# <path d="M14.3303 26.2967L0.5 38.8697V0.5H28.8333V38.8697L15.003 26.2967L14.6667 25.9909L14.3303 26.2967Z"></path>
# </svg>
# </button>
# <button aria-label="Go" class="group">
# <svg class="group-focus:text-main transition-colors duration-75 stroke-current" fill="none" height="40" viewbox="0 0 30 40" width="30" xmlns="http://www.w3.org/2000/svg">
# <rect height="39" width="28.3333" x="0.833984" y="0.5"></rect>
# <line x1="5.66732" x2="24.334" y1="10.1665" y2="10.1665"></line>
# <line x1="5.66732" x2="24.334" y1="28.8335" y2="28.8335"></line>
# <line x1="5.66732" x2="24.334" y1="19.5" y2="19.5"></line>
# </svg>
# </button>
# </div>
# </template>
# <!-- main image -->
# <!--main-->
# <div class="col-span-6 md:col-span-8 lg:col-span-7 lg:col-start-3 row-span-2 lg:border-l lg:border-gray-200 xl:-ml-9 lg:pl-9 mt-10">
# <div class="flex flex-col">
# <h1 class="text-34 md:text-42 xl:text-52 break-words">
#             Нобелевскую премию по химии присудили за квантовые точки
#           </h1>
# <p class="text-36 md:text-44 xl:text-54 font-spectral text-main-gray mb-6">Ее получат Мунги Бавенди, Луис Брюс и Алексей Екимов</p>
# <div class="text-14 mb-5 sm:mb-12 flex flex-wrap">
# <span class="whitespace-nowrap">
# <a class="underline" href="/author/mixail-boim">Михаил Бойм</a>
# </span>
# </div>
# <div class="mb-14" data-lmb-0="">
# <basegallerymain :gid="67423"></basegallerymain>
# <div></div>
# <div class="n1_material text-18"><p class="mb-6">Лауреатами Нобелевской премии по химии 2023 года стали Мунги Бавенди (Moungi G. Bawendi), Луис Брюс (Louis E. Brus) и Алексей Екимов (Alexei I. Ekimov) — за открытие и исследование квантовых точек. За церемонией вручения премии можно наблюдать в прямом эфире на <a href="https://www.nobelprize.org/">сайте</a> Нобелевского комитета. Подробнее об исследованиях лауреатов рассказывает <a href="https://www.nobelprize.org/prizes/chemistry/2023/press-release/">пресс-релиз</a>. Вручение премий состоится 10 декабря в Стокгольме.</p></div>
# <basegallerymain :gid="67505"></basegallerymain>
# <div></div>
# <div class="n1_material text-18"><p class="mb-6">Квантовые точки представляют собой кристаллические полупроводниковые частицы размером в несколько нанометров. Из-за своего небольшого размера, их оптические свойства во многом определяются квантовыми эффектами, и поэтому они сильно отличаются от макрокристаллических полупроводников. В частности, разница между энергетическими уровнями валентных электронов и электронов проводимости в квантовых точках отличается от ширины запрещенной зоны в объемном полупроводнике, и сильно зависит от размера частицы. Поэтому свойства квантовых точек можно менять, варьируя их размер.</p></div>
# <div class="n1_material text-18"><p class="mb-6">Первым квантовые точки из хлорида меди <a href="https://web.archive.org/web/20141216142832/http://www.jetpletters.ac.ru/ps/1030/article_15644.pdf">синтезировал</a> в стеклянной матрице Алексей Екимов в 1981 году, работавший тогда в Государственном оптическом институте имени Вавилова в Санкт-Петербурге. Он обнаружил, что в зависимости от размера получившихся частиц, стекло поглощало свет с разной длиной волны. Статью о своих исследованиях Екимов опубликовал в советском журнале на русском языке, поэтому первое время она оставалась непрочитанной. </p></div>
# <div class="n1_material text-18"><p class="mb-6">Через два года Луис Брюс с коллегами из лабораторий Белла, ничего не знавший об открытии Екимова, <a href="https://pubs.aip.org/aip/jcp/article-abstract/79/2/1086/776583/Quantum-size-effects-in-the-redox-potentials?redirectedFrom=fulltext">обнаружил</a>, что коллоидный раствор наночастиц сульфида кадмия меняет свои оптические свойства при стоянии. Он сделал вывод, что частицы в растворе со временем растут, и по своей способности поглощать свет становятся похожими на обычные кристаллы сульфида кадмия. При этом когда частицы были достаточно маленькие, их свойства отличались от свойств макрокристаллических образцов.</p></div>
# <div class="n1_material text-18"><p class="mb-6">А главная заслуга третьего Нобелиата — Мунги Бавенди из Массачусетского технологического института — в том, что он с коллегами <a href="https://pubs.acs.org/doi/pdf/10.1021/ja00072a025">разработал</a> удобный способ синтеза монодисперсных растворов квантовых точек нужного размера. Дело в том, что уже существующие к моменту открытия Бавенди методики синтеза часто приводили к непредсказуемым результатам — в одинаковых экспериментах химики получали разные нанокристаллические образцы. А Бавенди смог разработать воспроизводящуюся методику синтеза, способную на выходе давать нанокристаллы с узким распределением по размеру.</p></div>
# <div class="n1_material text-18"><p class="mb-6">В 2012 году один из лауреатов Луис Брюс <a href="https://www.prnewswire.com/news-releases/thomson-reuters-predicts-2012-nobel-laureates-170285846.html">попал</a> в список вероятных будущих лауреатов Нобеля, когда его составляла еще компания Thomson Reuters. В 2020 году, уже в аналогичный список от компании Clarivate, <a href="https://clarivate.com/news/clarivate-reveals-2020-citation-laureates-annual-list-of-researchers-of-nobel-class/">попал</a> Мунги Бавенди. А в этом году в него вошли три группы химиков. Джеймс Коллинз, Майкл Эловиц и Станислас Лейблер попали в список за свои работы в области искуственных генных схем. Шанкар Баласубраманиан и Дэвид Кленермэн — за новый метод секвенирования ДНК. А Кадзунори Катаока, Владимир Торчилин и Карен Вули — за разработку полимерных оболочек для доставки лекарств к мишени. Подробнее об ученых из списка читайте в нашем материале <a href="https://nplus1.ru/blog/2023/09/20/clarivate-nobel-2023">«Нобелевское предчувствие — 2023»</a>.</p></div>
# <div class="n1_material text-18"><p class="mb-6">Последние годы Нобелевские премии по химии вручали за исследования в области органической химии. В 2022 году премию разделили Каролин Бертоцци, Мортен Мельдаль и Барри Шарплесс — за развитие методов клик-химии и биоортогональной химии, о которых можно прочитать в нашем материале <a href="https://nplus1.ru/material/2022/10/06/chemistry-nobel-2022">«Клик — и готово»</a>. При этом Шарплесс получил премию уже во второй раз. А в 2021 году лауреатами стали Беньямин Лист и Дэвид Макмиллан за развитие асимметрического органокатализа, позволяющего получать органические вещества в оптически чистом виде. Подробнее о лауреатах 2021 года читайте в материале <a href="https://nplus1.ru/material/2021/10/07/nobel-chem-2021">«Химия зазеркалья»</a>.</p></div>
# </div>
# <div class="text-18">
# <app-tags-carousel>
# <template v-slot:default="slotProps">
# <a :class="slotProps.classesTag" href="https://nplus1.ru/search?tags=870">Химия</a>
# <a :class="slotProps.classesTag" href="https://nplus1.ru/search?tags=785">Нобелевская премия</a>
# </template>
# </app-tags-carousel>
# <div class="text-20 font-spectral text-main-gray leading-none" v-if="!isMobile">
#               Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter.
#             </div>
# </div>
# </div>
# </div>
# <!--right sidebar-->
# <div class="hidden md:block md:col-span-4 lg:col-span-3 mt-10">
# <div class="w-full" data-ref-sidebar=""></div>
# <!-- ba2 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: CLICKIO html5-->
# <!--Расположение: <верх страницы>-->
# <div class="bg-gray-100 mt-2 py-4 w-full" id="adfox_153934342663011746"></div>
# <!--
#         <a class="text-14 leading-21 group" href="#">
#           <p>
#             Human mobility at Tell Atchana (Alalakh), Hatay, Turkey during the 2nd millennium BC: Integration of
#             isotopic and genomic evidence
#           </p>
#           <div class="group-hover:text-main inline-flex items-center font-spectral text-main-gray">
#             <p class="mr-1">PLOS ONE, 30.06.2021</p>
#             <svg class="fill-current" width="11" height="11" viewBox="0 0 11 11" xmlns="http://www.w3.org/2000/svg">
#               <path d="M10.0738 5.87L5.08775 0.901999L4.15175 1.838L7.51775 5.204H0.19175V6.536H7.51775L4.15175 9.902L5.08775 10.838L10.0738 5.87Z"
#                     fill="currentColor"></path>
#             </svg>
#           </div>
#         </a>
#         -->
# </div>
# </div>
# </section>
# <section class="mb-15 md:mb-20">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 md:grid-cols-12 gap-x-5 md:gap-x-9">
# <!--tags-->
# <div class="flex-wrap col-span-6 md:col-span-12 lg:col-span-2 -mb-2.5 lg:-mb-0 content-start">
# <div class="flex flex-wrap lg:mb-10 gap-2 text-tags xl:pr-9">
# <span class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center">
# <span class="group-hover:text-main transition-colors duration-75">16:54</span>
# </span>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/news/2023/03/16">
# <span class="group-hover:text-main transition-colors duration-75">16.03.23</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/5">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">5.5</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=870">
# <span class="group-hover:text-main transition-colors duration-75">Химия</span>
# </a>
# </div>
# <div class="hidden lg:flex items-center gap-x-2">
# <a aria-label="Go" class="group" href="https://nplus1.ru/material-print/64608">
# <svg class="group-hover:text-main transition-colors duration-75 stroke-current" fill="none" height="30" viewbox="0 0 22 30" width="22" xmlns="http://www.w3.org/2000/svg">
# <rect height="29" width="21" x="0.5" y="0.5"></rect>
# <line x1="4" x2="18" y1="7.5" y2="7.5"></line>
# <line x1="4" x2="18" y1="21.5" y2="21.5"></line>
# <line x1="4" x2="18" y1="14.5" y2="14.5"></line>
# </svg>
# </a>
# <app-copy-material link="https://nplus1.ru/news/2023/03/16/chiral-oxonium-ions" type="full-2"></app-copy-material>
# </div>
# </div>
# <!--main image  -->
# <!--main-->
# <div class="col-span-6 md:col-span-8 lg:col-span-7 lg:col-start-3 row-span-2 lg:border-l lg:border-gray-200 xl:-ml-9 lg:pl-9 mt-10 lg:mt-0">
# <div class="flex flex-col">
# <div class="text-34 md:text-42 xl:text-52 break-words">
#           Химики разделили энантиомеры с оптическим центром на кислороде
#         </div>
# <p class="text-36 md:text-44 xl:text-54 font-spectral text-main-gray mb-6">Они не рацемизовались за неделю</p>
# <div class="text-14 pt-4 sm:pt-6 mb-10 sm:mb-12 flex flex-wrap">
# <a class="underline whitespace-nowrap" href="/author/mixail-boim">Михаил Бойм</a>
# </div>
# <div class="n1_material text-18" id="read-next-2">
# <p class="mb-6">Английские и американские химики получили хиральный оксониевый катион, который удалось разделить на энантиомеры с помощью кристаллизации его соли с хиральным анионом. Полученные энантиомеры с оптическим центром на атоме кислорода оказались конфигурационно стабильны и устойчивы при хранении на воздухе, пишут ученые в Nature.</p>
# </div>
# <div class="mt-5 md:mt-6">
# <a class="inline-flex justify-center bg-main w-full py-4" href="https://nplus1.ru/news/2023/03/16/chiral-oxonium-ions">
# <span class="text-white text-22 md:text-24">Читать дальше</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="mb-15 md:mb-20">
# <div class="bg-gray-100 w-full" id="adfox_154408219501673625"></div>
# </section>
# <div class="mb-1 w-full overflow-hidden">
# <app-material-slider-carousel :const-container="constContainer" :const-start-container="constStartContainer">
# <template v-slot:default="slotProps">
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                                'padding-left': slotProps.left + 'px'
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/840114/651abe20f2101_hl_cover_v.jpg">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/840115/651abe214571c_hl_cover_h.jpg">
# <img alt="В Карахан-Тепе обнаружили двухметровую статую держащегося за пенис мужчины" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/840115/651abe214571c_hl_cover_h.jpg"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/news/2023/10/03">
# <span class="group-hover:text-main transition-colors duration-75">03.10.23</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=876">
# <span class="group-hover:text-main transition-colors duration-75">
#             Археология
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           1.5
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/news/2023/10/03/gobekli-tepe">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           В Карахан-Тепе обнаружили двухметровую статую держащегося за пенис мужчины</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             А в Гёбекли-Тепе нашли окрашенную статую кабана</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/812014/c2c3df223026f1123590ac7976879f45.jpg">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/812013/7b16f36af94bc63c858e33223a50c626.jpg">
# <img alt="Моя персональная радиация" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/812013/7b16f36af94bc63c858e33223a50c626.jpg"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/2023/08/07">
# <span class="group-hover:text-main transition-colors duration-75">07.08.23</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=869">
# <span class="group-hover:text-main transition-colors duration-75">
#             Физика
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           1.5
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/material/2023/08/07/radiation-calculator">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           Моя персональная радиация</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             Калькулятор личных зивертов</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/831830/7426ca49a270b3afa82918a679e05dad.jpg">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/831829/9e095bd6efa444e777b88cdc5d7c09d3.jpg">
# <img alt="Клуб космической романтики" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/831829/9e095bd6efa444e777b88cdc5d7c09d3.jpg"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/2023/09/11">
# <span class="group-hover:text-main transition-colors duration-75">11.09.23</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=946">
# <span class="group-hover:text-main transition-colors duration-75">
#             Игры
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           2.7
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/material/2023/09/11/space-romance-club">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           Клуб космической романтики</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             Узнайте планеты Солнечной системы поближе</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/833496/650433d367017_hl_cover_v.jpg">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/833497/650433d3b4029_hl_cover_h.jpg">
# <img alt="Палеогенетики идентифицировали останки двух представителей рода Батори" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/833497/650433d3b4029_hl_cover_h.jpg"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/news/2023/09/15">
# <span class="group-hover:text-main transition-colors duration-75">15.09.23</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=877">
# <span class="group-hover:text-main transition-colors duration-75">
#             Антропология
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           3.3
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/news/2023/09/15/bathory-family">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           Палеогенетики идентифицировали останки двух представителей рода Батори</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             Их нашли в Румынии</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/830889/c3ecd4880473d64ab4c9f3760e46c9cc.png">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/830888/324545278a007bf82ed0e9645373f099.png">
# <img alt="Сова или жаворонок" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/830888/324545278a007bf82ed0e9645373f099.png"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/2023/09/20">
# <span class="group-hover:text-main transition-colors duration-75">20.09.23</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=946">
# <span class="group-hover:text-main transition-colors duration-75">
#             Игры
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           1.5
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/material/2023/09/20/owl-or-lark">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           Сова или жаворонок</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             Простой тест о ваших биологических часах</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/835296/650ad679d6325_hl_cover_v.jpeg">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/835297/650ad67a2468c_hl_cover_h.jpeg">
# <img alt="В Замбии обнаружили остатки 476-тысячелетней деревянной постройки" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/835297/650ad67a2468c_hl_cover_h.jpeg"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/news/2023/09/20">
# <span class="group-hover:text-main transition-colors duration-75">20.09.23</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=876">
# <span class="group-hover:text-main transition-colors duration-75">
#             Археология
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           3.5
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/news/2023/09/20/earliest-wood-construction">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           В Замбии обнаружили остатки 476-тысячелетней деревянной постройки</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             Это древнейшее подобное сооружение в мире</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/837963/6513c61f5d7b5_hl_cover_v.jpg">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/837964/6513c61f9aee6_hl_cover_h.jpg">
# <img alt="В пирамиде фараона Сахура нашли восемь кладовых" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/837964/6513c61f9aee6_hl_cover_h.jpg"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/news/2023/09/27">
# <span class="group-hover:text-main transition-colors duration-75">27.09.23</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=876">
# <span class="group-hover:text-main transition-colors duration-75">
#             Археология
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           1.8
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/news/2023/09/27/pyramid-of-sahure">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           В пирамиде фараона Сахура нашли восемь кладовых</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             Археологи раскопали их во время расчистки, реставрации и консервации гробницы</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# ...
# <a class="underline transition-colors duration-75 hover:text-main inline-block col-span-6 sm:col-span-5 mb-5 font-spectral italic" href="/personal-data-policy">Политика
#           обработки
#           персональных данных пользователей сайта
#         </a>
# </div>
# <div class="order-3 sm:col-span-9 lg:col-span-5 sm:order-3 lg:order-6 mt-auto col-span-6 mb-10 lg:mb-0">
# <ul class="flex gap-3 text-gray-2">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </footer>
# </div>
# <svg class="stroke-current" fill="none" height="16" id="n1_star" style="display:block;width:0;height:0" viewbox="3 3 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M11 5V17"></path>
# <path d="M6.75781 6.75781L15.2431 15.2431"></path>
# <path d="M17 11L5 11"></path>
# <path d="M15.2422 6.75781L6.75691 15.2431"></path>
# </svg>
# <svg class="stroke-current" fill="none" id="n1_person" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <circle cx="25" cy="25" r="24.5"></circle>
# <path d="M30.1897 30.3212C28.9483 29.9852 27.5345 29.7164 27.5345 28.5067C27.5345 27.8347 27.5 27.0618 28.2931 26.625C31.0172 25.0457 32.5 22.3911 32.1552 18.2581C31.8103 14.0578 29.2586 11 24.9828 11C20.7069 11 18.1552 14.0578 17.8103 18.2581C17.4655 22.3911 18.9138 25.0457 21.6724 26.625C22.4655 27.0618 22.431 27.8347 22.431 28.5067C22.431 29.7164 21.0172 29.9516 19.8103 30.3212C17.3966 30.9933 12.5 31.9005 12.5 36C16.431 36 33.569 36 37.5 36C37.4655 31.9005 32.6034 30.9933 30.1897 30.3212Z" stroke-miterlimit="10"></path>
# </svg>
# <svg fill="none" id="n1_tg" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M16.3181 21.32H19.4961V30H20.7141V21.32H23.8921V20.2H16.3181V21.32ZM28.6969 30.084C30.3769 30.084 31.4269 29.286 31.8749 28.572L31.9589 30H33.0089V24.694H28.8789V25.814H31.8189V26.15C31.8189 27.886 30.5169 28.964 28.7109 28.964C26.6809 28.964 25.3369 27.368 25.3369 25.1C25.3369 22.832 26.6809 21.236 28.7389 21.236C30.2229 21.236 31.2729 22.034 31.6089 23.392H32.9109C32.5749 21.376 30.9369 20.116 28.7669 20.116C25.9249 20.116 24.0909 22.132 24.0909 25.1C24.0909 28.068 25.9809 30.084 28.6969 30.084Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_vk" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M19.8015 30H21.2715L24.7995 20.2H23.5395L20.5575 28.558L17.5615 20.2H16.2735L19.8015 30ZM25.8768 30H27.0948V27.452L29.0408 25.254L32.3448 30H33.8008L29.9368 24.33L33.5208 20.2H32.0368L27.0948 25.758V20.2H25.8768V30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_ok" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M25.2125 25.1C25.2125 22.216 23.2945 20.116 20.5365 20.116C17.7785 20.116 15.8605 22.216 15.8605 25.1C15.8605 27.984 17.7785 30.084 20.5365 30.084C23.2945 30.084 25.2125 27.984 25.2125 25.1ZM17.1065 25.1C17.1065 22.846 18.4925 21.236 20.5365 21.236C22.5805 21.236 23.9665 22.846 23.9665 25.1C23.9665 27.354 22.5805 28.964 20.5365 28.964C18.4925 28.964 17.1065 27.354 17.1065 25.1ZM26.7518 30H27.9698V27.452L29.9158 25.254L33.2198 30H34.6758L30.8118 24.33L34.3958 20.2H32.9118L27.9698 25.758V20.2H26.7518V30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_tw" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M14.4792 21.32H17.6572V30H18.8752V21.32H22.0532V20.2H14.4792V21.32ZM25.332 30H26.788L29.014 22.23L31.254 30H32.71L35.58 20.2H34.32L32.01 28.432L29.686 20.2H28.454L26.046 28.432L23.75 20.2H22.476L25.332 30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg height="64px" id="n1_infinity" preserveaspectratio="xMidYMid" style="display:block;width:0;height:0" viewbox="0 0 100 100" width="64px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <path d="M24.3 30C11.4 30 5 43.3 5 50s6.4 20 19.3 20c19.3 0 32.1-40 51.4-40 C88.6 30 95 43.3 95 50s-6.4 20-19.3 20C56.4 70 43.6 30 24.3 30z" fill="none" stroke="#ffffff" stroke-dasharray="146.25568908691406 110.33323913574219" stroke-linecap="round" stroke-width="5" style="transform:scale(0.8);transform-origin:50px 50px">
# <animate attributename="stroke-dashoffset" dur="1.3157894736842106s" keytimes="0;1" repeatcount="indefinite" values="0;256.58892822265625"></animate>
# </path>
# </svg>
# <svg fill="none" id="n1_cross" style="display:block;width:0;height:0" viewbox="0 0 14 14" xmlns="http://www.w3.org/2000/svg">
# <path d="M1.00146 1L13.0015 13" stroke="#F9F9F9"></path>
# <path d="M13 1L1 13" stroke="#F9F9F9"></path>
# </svg>
# <svg id="n1_link_arrow" style="display:block;width:0;height:0" viewbox="0 0 11 11" xmlns="http://www.w3.org/2000/svg">
# <path d="M10.0738 5.87L5.08775 0.901999L4.15175 1.838L7.51775 5.204H0.19175V6.536H7.51775L4.15175 9.902L5.08775 10.838L10.0738 5.87Z" fill="currentColor"></path>
# </svg>
# <svg id="n1_big_star" style="display:block;width:0;height:0;" viewbox="0 0 61 61" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" clip-rule="evenodd" d="M3 29.7729H29.0656L10.6345 11.3418L11.3416 10.6347L29.7728 29.0658V3H30.7728V29.0658L49.2039 10.6347L49.911 11.3418L31.4799 29.7729H57.5455V30.7729H31.4799L49.9111 49.2042L49.204 49.9113L30.7728 31.4801V57.5455H29.7728V31.4801L11.3415 49.9113L10.6344 49.2042L29.0656 30.7729H3V29.7729Z" fill-rule="evenodd"></path>
# <path class="fill-current" d="M29.0656 29.7729V32.2729H35.1012L30.8334 28.0052L29.0656 29.7729ZM3 29.7729V27.2729H0.5V29.7729H3ZM10.6345 11.3418L8.86676 9.57407L7.099 11.3418L8.86676 13.1096L10.6345 11.3418ZM11.3416 10.6347L13.1094 8.86696L11.3416 7.09919L9.57387 8.86696L11.3416 10.6347ZM29.7728 29.0658L28.005 30.8336L32.2728 35.1014V29.0658H29.7728ZM29.7728 3V0.5H27.2728V3H29.7728ZM30.7728 3H33.2728V0.5H30.7728V3ZM30.7728 29.0658H28.2728V35.1014L
style="display:block;width:0;height:0" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <rect height="29" rx="14.5" transform="rotate(-180 29.5 29.5)" width="29" x="29.5" y="29.5"></rect>
# <path d="M9.33985 14.7014L14.6198 19.9414L15.2598 19.3014L11.1198 15.1614L20.3398 15.1614L20.3398 14.2214L11.1198 14.2214L15.2598 10.0814L14.6198 9.44141L9.33985 14.7014Z"></path>
# </svg>
# <svg fill="none" id="n1_circle_arrow_solid" style="display:block;width:0;height:0" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <mask id="path-1-inside-1_2694_77554">
# <path clip-rule="evenodd" d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z" fill-rule="evenodd"></path>
# </mask>
# <path clip-rule="evenodd" d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z" fill="#fff" fill-rule="evenodd"></path>
# <path d="M20.6592 15.3001L21.3649 16.0085L22.0774 15.2987L21.3636 14.5903L20.6592 15.3001ZM15.3792 10.0601L16.0836 9.35027L15.3765 8.64853L14.6721 9.35295L15.3792 10.0601ZM15.3792 20.5601L14.6721 21.2672L15.3778 21.9729L16.0849 21.2685L15.3792 20.5601ZM14.7392 19.9201L14.0321 19.213L13.325 19.9201L14.0321 20.6272L14.7392 19.9201ZM18.8792 15.7801L19.5863 16.4872L21.2934 14.7801H18.8792V15.7801ZM9.65918 15.7801H8.65918V16.7801H9.65918V15.7801ZM9.65918 14.8401V13.8401H8.65918V14.8401H9.65918ZM18.8792 14.8401V15.8401H21.2934L19.5863 14.133L18.8792 14.8401ZM14.7392 10.7001L14.0321 9.99295L13.325 10.7001L14.0321 11.4072L14.7392 10.7001ZM1 15C1 7.26801 7.26801 1 15 1V-1C6.16344 -1 -1 6.16344 -1 15H1ZM15 29C7.26801 29 1 22.732 1 15H-1C-1 23.8366 6.16344 31 15 31V29ZM29 15C29 22.732 22.732 29 15 29V31C23.8366 31 31 23.8366 31 15H29ZM15 1C22.732 1 29 7.26801 29 15H31C31 6.16344 23.8366 -1 15 -1V1ZM21.3636 14.5903L16.0836 9.35027L14.6748 10.7698L19.9548 16.0098L21.3636 14.5903ZM16.0849 21.2685L21.3649 16.0085L19.9534 14.5916L14.6734 19.8516L16.0849 21.2685ZM14.0321 20.6272L14.6721 21.2672L16.0863 19.853L15.4463 19.213L14.0321 20.6272ZM18.1721 15.073L14.0321 19.213L15.4463 20.6272L19.5863 16.4872L18.1721 15.073ZM9.65918 16.7801H18.8792V14.7801H9.65918V16.7801ZM8.65918 14.8401V15.7801H10.6592V14.8401H8.65918ZM18.8792 13.8401H9.65918V15.8401H18.8792V13.8401ZM14.0321 11.4072L18.1721 15.5472L19.5863 14.133L15.4463 9.99295L14.0321 11.4072ZM14.6721 9.35295L14.0321 9.99295L15.4463 11.4072L16.0863 10.7672L14.6721 9.35295Z" fill="#fff" mask="url(#path-1-inside-1_2694_77554)"></path>
# </svg>
# <svg fill="none" id="n1_play" style="display:block;width:0;height:0;" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# <path class="stroke-current" d="M18 35V15L36 25L18 35Z"></path>
# </svg>
# <svg fill="none" id="n1_pupa" style="display:block;width:0;height:0;" viewbox="0 0 24 23" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M17 8.80329C17 13.0922 13.4392 16.6066 9 16.6066C4.56077 16.6066 1 13.0922 1 8.80329C1 4.51437 4.56077 1 9 1C13.4392 1 17 4.51437 17 8.80329ZM14.9967 15.3678C13.4049 16.7601 11.3035 17.6066 9 17.6066C4.02944 17.6066 0 13.6652 0 8.80329C0 3.94137 4.02944 0 9 0C13.9706 0 18 3.94137 18 8.80329C18 11.0562 17.1348 13.1114 15.7118 14.6684L23.3531 22.1427C23.5505 22.3358 23.554 22.6524 23.3609 22.8498C23.1678 23.0472 22.8513 23.0507 22.6539 22.8576L14.9967 15.3678Z" fill="#32363A" fill-rule="evenodd"></path>
# </svg>
# <svg fill="none" id="n1_burger" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <line stroke="#32363A" x2="30" y1="6.5" y2="6.5"></line>
# <line stroke="#32363A" x2="30" y1="23.5" y2="23.5"></line>
# <line stroke="#32363A" x2="30" y1="15" y2="15"></line>
# </svg>
# <svg fill="none" id="n1_cross_menu" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <path d="M4 4L26 26" stroke="#32363A"></path>
# <path d="M26 4L4 26" stroke="#32363A"></path>
# </svg>
# <svg id="n1_check" style="display:block;width:0;height:0;fill:currentColor" version="1.1" viewbox="0 0 752 752" xmlns="http://www.w3.org/2000/svg">
# <path d="m183.6 357.87-22.184 22.168v0.003907c-3.2969 3.293-3.2969 8.6367 0 11.934l133.29 133.28v0.003907c3.7305 3.7266 8.7891 5.8242 14.066 5.8242 5.2734 0 10.332-2.0977 14.062-5.8242l267.76-267.76c1.582-1.582 2.4727-3.7305 2.4727-5.9688 0-2.2383-0.89062-4.3867-2.4727-5.9688l-22.156-22.168c-1.582-1.5898-3.7344-2.4805-5.9727-2.4805-2.2422 0-4.3945 0.89062-5.9766 2.4805l-244.31 244.3c-1.8828 1.8789-4.9336 1.8789-6.8164 0l-109.84-109.83c-3.293-3.2852-8.625-3.2852-11.918 0z"></path>
# </svg>
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script src="/front-build/js/app.js?id=0ebe93a4910598709624f15c46949ba6"></script>
# <!-- Yandex.Metrika counter 2-->
# <script type="text/javascript">
# (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
# 	m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
# (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
# ym(88946384, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true
# });
#
#
# ym(29654565, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true,
# 	trackHash:true,
# 	ecommerce:"dataLayer"
# });
# </script>
# <noscript>
# <div>
# <img alt="" src="https://mc.yandex.ru/watch/88946384" style="position:absolute; left:-9999px;"/>
# <img alt="" src="https://mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;"/>
# </div>
# </noscript>
# <!-- /Yandex.Metrika counter -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-61773772-1"></script>
# <script>
# window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'UA-61773772-1');
# </script>
# <script>window.yaContextCb = window.yaContextCb || []</script>
# <script async="" src="https://yandex.ru/ads/system/context.js"></script>
# <script>
# if ('serviceWorker' in navigator) {
# 	window.addEventListener('load', () => {
# 		navigator.serviceWorker.register('/front-service-worker.js').then(reg => {
# 			// sometime later…
# 			reg.update()
# 		})
# 	})
# }
# </script>
# </body>
# </html>

# %% [markdown]
# В коде каждой страницы с новостью есть часть с мета-информацией: датой, именем автора и проч. Такая информация окружена тэгом `<meta></meta>`. Посмотрим:

# %%
soup0.find_all('meta')
# Out:
# [<meta charset="utf-8"/>,
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>,
#  <meta content="#f26e40" name="msapplication-TileColor"/>,
#  <meta content="#ffffff" name="theme-color"/>,
#  <meta content="8c90b02c84ac3b72" name="yandex-verification"/>,
#  <meta content="b419949322895fc9106e24ed01be58ac" name="pmail-verification"/>,
#  <meta content="N + 1 — главное издание о науке, технике и технологиях" name="description"/>,
#  <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:site_name"/>,
#  <meta content="Нобелевскую премию по химии присудили за квантовые точки" property="og:title"/>,
#  <meta content="https://minio.nplus1.ru/app-images/838971/6516cd4f91d3b_cover_share.jpg" property="og:image"/>,
#  <meta content="https://nplus1.ru/news/2023/10/04/chem-nobel-2023" property="og:url"/>,
#  <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:description"/>,
#  <meta content="article" property="og:type"/>,
#  <meta content="2023-10-04" itemprop="datePublished"/>,
#  <meta content="2023-10-04" itemprop="datePublished"/>,
#  <meta content="Михаил Бойм" name="mediator_author"/>,
#  <meta content="Михаил Бойм" name="author"/>,
#  <meta content="" name="copyright"/>,
#  <meta content="summary_large_image" name="twitter:card"/>,
#  <meta content="@nplusodin" name="twitter:site"/>,
#  <meta content="Нобелевскую премию по химии присудили за квантовые точки" name="twitter:title"/>,
#  <meta content="N + 1 — главное издание о науке, технике и технологиях" name="twitter:description"/>,
#  <meta content="https://minio.nplus1.ru/app-images/838971/6516cd4f91d3b_cover_share.jpg" name="twitter:image"/>]

# %%
soup0.find('meta', {'property': 'og:title'}).get('content')
# Out:
# 'Нобелевскую премию по\xa0химии присудили за\xa0квантовые точки'

# %%
soup0.find_all('meta', {'itemprop': 'datePublished'})[0].get('content')
# Out:
# '2023-10-04'

# %% [markdown]
# Из этого списка нам нужны части с именем автора, датой, заголовком и кратким описанием. Воспользуемся поиском по атрибуту `name`. Передадим функции `find_all()` в качестве аргумента словарь с названием и значением атрибута:

# %%
soup0.find_all('meta', {'name' : 'author'}) # например, автор
# Out:
# [<meta content="Михаил Бойм" name="author"/>]

# %% [markdown]
# Теперь выберем единственный элемент полученного списка (с индексом 0):

# %%
soup0.find_all('meta', {'name' : 'author'})[0]
# Out:
# <meta content="Михаил Бойм" name="author"/>

# %% [markdown]
# Нам нужно вытащить из этого объекта `content` – имя автора. Посмотрим на атрибуты:

# %%
soup0.find_all('meta', {'name' : 'author'})[0].attrs
# Out:
# {'name': 'author', 'content': 'Михаил Бойм'}

# %% [markdown]
# Как получить отсюда `content`? Очень просто, ведь это словарь! А доставать из словаря значение по ключу мы умеем.

# %%
author = soup0.find('meta', {'name' : 'author'}).get('content')
author
# Out:
# 'Михаил Бойм'

# %% [markdown]
# Аналогичным образом извлечем дату, заголовок и описание.

# %%
date = soup0.find_all('meta', {'itemprop' : 'datePublished'})[0].get('content')
title = soup0.find_all('meta', {'property' : 'og:title'})[0].get('content')

# %%
title
# Out:
# 'Нобелевскую премию по\xa0химии присудили за\xa0квантовые точки'

# %%
date
# Out:
# '2023-10-04'

# %% [markdown]
# Теперь осталось совсем чуть-чуть. Написать готовую функцию для всех проделанных нами действий и применить ее в цикле для всех ссылок в списке `full_urls`. Напишем! Аргументом функции будет ссылка на новость, а возвращать она будет текст новости и всю необходимую информацию (дата, автор, сложность и проч.). Скопируем все строки кода выше.

# %%
def GetNews(url0):
    """
    Возвращает кортеж с url0, date, author, title.
    Параметры:
    
    url0 - ссылка на новость (строка).
    """
    page0 = requests.get(url0)
    soup0 = BeautifulSoup(page0.text, 'html')
    
    author = soup0.find_all('meta', {'name' : 'author'})[0].get('content')
    date = soup0.find_all('meta', {'itemprop' : 'datePublished'})[0].get('content')
    title = soup0.find_all('meta', {'property' : 'og:title'})[0].get('content')
     
    return url0, date, author, title

# %%
help(GetNews)
# Out:
# Help on function GetNews in module __main__:
#
# GetNews(url0)
#     Возвращает кортеж с url0, date, author, title.
#     Параметры:
#
#     url0 - ссылка на новость (строка).

# %% [markdown]
# Уфф. Осталось применить ее в цикле. Но давайте не будем спешить: импортируем функцию `sleep` для задержки, чтобы на каждой итерации цикла, прежде чем перейти к следующей новости, Python ждал несколько секунд. Во-первых, это нужно, чтобы сайт «не понял», чтобы мы его грабим, да еще автоматически. Во-вторых, с небольшой задержкой всегда есть гарантия, что страница прогрузится (сейчас это пока не очень важно, но особенно актуально будет, когда будем обсуждать встраивание в браузер с Selenium). Приступим.

# %%
from time import sleep

# %%
urls
# Out:
# ['https://nplus1.ru/news/2015/09/21/editor-thy-name',
#  'https://nplus1.ru/news/2023/10/04/chem-nobel-2023',
#  'https://nplus1.ru/news/2023/10/04/vehicle-crash-adhd',
#  'https://nplus1.ru/news/2023/10/04/same-sex-behaviour-mammals',
#  'https://nplus1.ru/news/2023/10/04/frb-gw-or-no',
#  'https://nplus1.ru/news/2023/10/04/ak-alakha',
#  'https://nplus1.ru/news/2023/10/04/second-vaccine-for-malaria',
#  'https://nplus1.ru/news/2023/10/04/chem-nobel-2023',
#  'https://nplus1.ru/news/2023/10/04/neolithic-jericho',
#  'https://nplus1.ru/news/2023/10/04/we-drive-solar-sharing-batteries',
#  'https://nplus1.ru/news/2023/10/04/orca-vs-sea-otters',
#  'https://nplus1.ru/news/2023/10/03/wolves-love-story',
#  'https://nplus1.ru/news/2023/10/03/bivalve-cancer',
#  'https://nplus1.ru/news/2023/10/03/butterflies-plugs',
#  'https://nplus1.ru/news/2023/10/03/gwas-carrot',
#  'https://nplus1.ru/news/2023/10/03/phys-nobel-2023',
#  'https://nplus1.ru/news/2023/10/03/yamnaya-people-and-multiple-sclerosis',
#  'https://nplus1.ru/news/2023/10/03/viking-age-burial-in-garden',
#  'https://nplus1.ru/news/2023/10/03/music-reading-dementia',
#  'https://nplus1.ru/news/2023/10/03/gobekli-tepe',
#  'https://nplus1.ru/news/2023/10/03/loneliness-and-risk-of-pd',
#  'https://nplus1.ru/news/2023/10/03/jwst-m-42',
#  'https://nplus1.ru/news/2023/10/03/baby-beaver',
#  'https://nplus1.ru/news/2023/10/02/nitrogen-fertilisers',
#  'https://nplus1.ru/news/2023/10/02/kelping',
#  'https://nplus1.ru/news/2023/10/02/probiotics-preterm-infants',
#  'https://nplus1.ru/news/2023/10/02/millimobile-battery-free-robot',
#  'https://nplus1.ru/news/2023/10/02/carbene-double-oxidation',
#  'https://nplus1.ru/news/2023/10/02/enlight-short-list-2023',
#  ('https://nplus1.ru/news/2023/10/04/vehicle-crash-adhd',
#   '2023-10-04',
#   'Слава Гоменюк',
#   'Пожилые водители с\xa0СДВГ отличились повышенным риском ДТП'),
#  ('https://nplus1.ru/news/2023/10/04/same-sex-behaviour-mammals',
#   '2023-10-04',
#   'Катерина Петрова',
#   'Однополое сексуальное поведение млекопитающих связали с\xa0развитием социальности'),
#  ('https://nplus1.ru/news/2023/10/04/frb-gw-or-no',
#   '2023-10-04',
#   'Александр Войтюк',
#   'Астрономы не\xa0нашли связи между быстрыми радиовсплесками и\xa0гравитационными всплесками'),
#  ('https://nplus1.ru/news/2023/10/04/ak-alakha',
#   '2023-10-04',
#   'Михаил Подрезов',
#   'Знатному пазырыкцу поставили диффузный идиопатический скелетный гиперостоз'),
#  ('https://nplus1.ru/news/2023/10/04/second-vaccine-for-malaria',
#   '2023-10-04',
#   'Слава Гоменюк',
#   'ВОЗ одобрила вторую противомалярийную вакцину для широкого применения'),
#  ('https://nplus1.ru/news/2023/10/04/chem-nobel-2023',
#   '2023-10-04',
#   'Михаил Бойм',
#   'Нобелевскую премию по\xa0химии присудили за\xa0квантовые точки'),
#  ('https://nplus1.ru/news/2023/10/04/neolithic-jericho',
#   '2023-10-04',
#   'Михаил Подрезов',
#   'Среди 44\xa0жителей Иерихона эпохи докерамического неолита нашли двух неместных'),
#  ('https://nplus1.ru/news/2023/10/04/we-drive-solar-sharing-batteries',
#   '2023-10-04',
#   'Андрей Фокин',
#   'Каршеринговые электромобили в\xa0Нидерландах поделятся энергией с\xa0городской электросетью'),
#  ('https://nplus1.ru/news/2023/10/04/orca-vs-sea-otters',
#   '2023-10-04',
#   'Сергей Коленов',
#   'Косатка проглотила шесть каланов и\xa0подавилась седьмым'),
#  ('https://nplus1.ru/news/2023/10/03/wolves-love-story',
#   '2023-10-03',
#   'Сергей Коленов',
#   'Итальянский волк и\xa0иберийская волчица образовали гибридную пару'),
#  ('https://nplus1.ru/news/2023/10/03/bivalve-cancer',
#   '2023-10-03',
#   'Олег Лищук',
#   'Заразный рак двустворчатых моллюсков оказался генетически нестабилен'),
#  ('https://nplus1.ru/news/2023/10/03/butterflies-plugs',
#   '2023-10-03',
#   'Катерина Петрова',
#   'Самцы бабочек с\xa0умом подошли к\xa0выбору размера копуляционной пробки'),
#  ('https://nplus1.ru/news/2023/10/03/gwas-carrot',
#   '2023-10-03',
#   'Анна Муравьёва',
#   'Генетики объяснили оранжевость моркови'),
#  ('https://nplus1.ru/news/2023/10/03/phys-nobel-2023',
#   '2023-10-03',
#   'Александр Дубов',
#   'Нобелевскую премию по\xa0физике присудили за\xa0аттосекундные импульсы'),
#  ('https://nplus1.ru/news/2023/10/03/yamnaya-people-and-multiple-sclerosis',
#   '2023-10-03',
#   'Михаил Подрезов',
#   'У\xa0ямников выявили генетическую предрасположенность к\xa0рассеянному склерозу'),
#  ('https://nplus1.ru/news/2023/10/03/viking-age-burial-in-garden',
#   '2023-10-03',
#   'Михаил Подрезов',
#   'Норвежская семья искала потерянную серьгу и\xa0наткнулась на\xa0погребение эпохи викингов'),
#  ('https://nplus1.ru/news/2023/10/03/music-reading-dementia',
#   '2023-10-03',
#   'Слава Гоменюк',
#   'Музыка и\xa0чтение не\xa0улучшили исходы деменции'),
#  ('https://nplus1.ru/news/2023/10/03/gobekli-tepe',
#   '2023-10-03',
#   'Михаил Подрезов',
#   'В\xa0Карахан-Тепе обнаружили двухметровую статую держащегося за\xa0пенис мужчины'),
#  ('https://nplus1.ru/news/2023/10/03/loneliness-and-risk-of-pd',
#   '2023-10-03',
#   'Слава Гоменюк',
#   'Одиночество связали с\xa0повышенным риском развития болезни Паркинсона'),
#  ('https://nplus1.ru/news/2023/10/03/jwst-m-42',
#   '2023-10-03',
#   'Александр Войтюк',
#   '«Джеймс Уэбб» показал панораму Большой туманности Ориона'),
#  ('https://nplus1.ru/news/2023/10/03/baby-beaver',
#   '2023-10-03',
#   'Сергей Коленов',
#   'В\xa0Лондоне впервые за\xa0400 лет родился бобренок'),
#  ('https://nplus1.ru/news/2023/10/02/nitrogen-fertilisers',
#   '2023-10-02',
#   'Марина Попова',
#   'Ученые предложили Китаю и\xa0США поделиться азотными удобрениями с\xa0Африкой'),
#  ('https://nplus1.ru/news/2023/10/02/kelping',
#   '2023-10-02',
#   'Сергей Коленов',
#   'Киты оказались любителями водорослевых обертываний'),
#  ('https://nplus1.ru/news/2023/10/02/probiotics-preterm-infants',
#   '2023-10-02',
#   'Слава Гоменюк',
#   'Пробиотики снизили смертность от\xa0всех причин среди недоношенных новорожденных'),
#  ('https://nplus1.ru/news/2023/10/02/millimobile-battery-free-robot',
#   '2023-10-02',
#   'Андрей Фокин',
#   'Автономный микроробот без батареи перевез груз втрое тяжелее себя'),
#  ('https://nplus1.ru/news/2023/10/02/carbene-double-oxidation',
#   '2023-10-02',
#   'Михаил Бойм',
#   'Химики дважды окислили карбен'),
#  ('https://nplus1.ru/news/2023/10/02/enlight-short-list-2023',
#   '2023-10-02',
#   'Дмитрий Левин',
#   'Объявлен шорт-лист премии «Просветитель» 2023 года'),
#  ('https://nplus1.ru/news/2023/10/02/lincombian-ranisian-jerzmanowician',
#   '2023-10-02',
#   'Михаил Подрезов',
#   'На\xa0памятнике с\xa0орудиями линкомбьен-ранис-ежмановице впервые нашли останки сапиенсов'),
#  ('https://nplus1.ru/news/2023/10/02/physmed-nobel-2023',
#   '2023-10-02',
#   'Полина Лосева',
#   'Нобелевскую премию по\xa0медицине присудили за\xa0мРНК-вакцины от\xa0ковида'),
#  ('https://nplus1.ru/news/2023/10/02/september-2023',
#   '2023-10-02',
#   'Марина Попова',
#   'Сентябрь 2023 года в\xa0Москве стал самым теплым за\xa0176 лет'),
#  ('https://nplus1.ru/news/2023/10/02/abydos-wine-jars',
#   '2023-10-02',
#   'Винера Андреева',
#   'В\xa05000-летней гробнице одной из\xa0первых египетских правительниц нашли винный склад'),
#  ('https://nplus1.ru/news/2023/10/02/petranola',
#   '2023-10-02',
#   'Михаил Подрезов',
#   'Антропологи реконструировали внешность человека гейдельбергского'),
#  ('https://nplus1.ru/news/2023/10/02/neanderthals-from-altai',
#   '2023-10-02',
#   'Михаил Подрезов',
#   'Алтайскую пещеру назвали неандертальским наблюдательным пунктом'),
#  ('https://nplus1.ru/news/2023/10/03/gobekli-tepe',
#   '2023-10-03',
#   'Михаил Подрезов',
#   'В\xa0Карахан-Тепе обнаружили двухметровую статую держащегося за\xa0пенис мужчины'),
#  ('https://nplus1.ru/news/2023/09/15/bathory-family',
#   '2023-09-15',
#   'Михаил Подрезов',
#   'Палеогенетики идентифицировали останки двух представителей рода Батори'),
#  ('https://nplus1.ru/news/2023/09/20/earliest-wood-construction',
#   '2023-09-20',
#   'Михаил Подрезов',
#   'В\xa0Замбии обнаружили остатки 476-тысячелетней деревянной постройки'),
#  ('https://nplus1.ru/news/2023/09/27/pyramid-of-sahure',
#   '2023-09-27',
#   'Винера Андреева',
#   'В\xa0пирамиде фараона Сахура нашли восемь кладовых'),
#  ('https://nplus1.ru/news/2023/09/27/ninth-pangolin',
#   '2023-09-27',
#   'Сергей Коленов',
#   'Изъятая у\xa0контрабандистов чешуя указала на\xa0неизвестный вид панголинов'),
#  ('https://nplus1.ru/news/2023/09/22/new-language',
#   '2023-09-22',
#   'Михаил Подрезов',
#   'В\xa0Турции обнаружили ранее неизвестный древний индоевропейский язык'),
#  ('https://nplus1.ru/news/2023/09/15/earth-core-density-deficit',
#   '2023-09-15',
#   'Дмитрий Рудик',
#   'Дефицит плотности ядра Земли в\xa0два раза превысил предыдущие оценки'),
#  ('https://nplus1.ru/news/2023/09/15/earth-core-density-deficit',
#   '2023-09-15',
#   'Дмитрий Рудик',
#   'Дефицит плотности ядра Земли в\xa0два раза превысил предыдущие оценки'),
#  ('https://nplus1.ru/news/2023/09/16/erase-and-rewire',
#   '2023-09-16',
#   'Олег Лищук',
#   'Механизм развития синдрома Ангельмана связали с\xa0пресинаптическими рецепторами'),
#  ('https://nplus1.ru/news/2023/09/20/nothing-extra',
#   '2023-09-20',
#   'Олег Лищук',
#   'Человеческая сперма оказалась лишена митохондриальной ДНК'),
#  ('https://nplus1.ru/news/2023/09/21/put-through',
#   '2023-09-21',
#   'Олег Лищук',
#   'Универсальная нанопора поможет эффективно секвенировать белки'),
#  ('https://nplus1.ru/news/2023/09/22/topological-phonons-in-graphene',
#   '2023-09-22',
#   'Дмитрий Рудик',
#   'Физики обнаружили топологические фононы в\xa0графене'),
#  ('https://nplus1.ru/news/2023/09/23/jwst-europe-co2',
#   '2023-09-23',
#   'Александр Войтюк',
#   '«Джеймс Уэбб» нашел на\xa0поверхности Европы углекислый газ из\xa0подповерхностного океана'),
#  ('https://nplus1.ru/news/2023/09/23/be-my-guide',
#   '2023-09-23',
#   'Олег Лищук',
#   'Целенаправленная регенерация аксонов восстановила ходьбу у\xa0парализованных мышей'),
#  ('https://nplus1.ru/news/2023/10/04/frb-gw-or-no',
#   '2023-10-04',
#   'Александр Войтюк',
#   'Астрономы не\xa0нашли связи между быстрыми радиовсплесками и\xa0гравитационными всплесками'),
#  ('https://nplus1.ru/news/2023/10/04/sulfur-of-deccan-traps',
#   '2023-10-04',
#   'Винера Андреева',
#   'Извержения Деканских траппов принесли динозаврам серию вулканических зим перед ударом астероида')]

# %% [markdown]
# Так теперь выглядит первый элемент списка:

# %% [markdown]
# Импортируем `pandas` и создадим датафрейм из списка кортежей:

# %%
import pandas as pd

# %%
df = pd.DataFrame(news)

# %%
df.head(10)
# Out:
#                                                    0           1  \
# 0  https://nplus1.ru/news/2023/10/04/chem-nobel-2023  2023-10-04
# 1  https://nplus1.ru/news/2023/10/05/manganese-ac...  2023-10-05
# 2  https://nplus1.ru/news/2023/10/04/sulfur-of-de...  2023-10-04
# 3    https://nplus1.ru/news/2023/10/04/heartbreaking  2023-10-04
# 4  https://nplus1.ru/news/2023/10/04/osiris-rex-d...  2023-10-04
# 5  https://nplus1.ru/news/2023/10/04/vehicle-cras...  2023-10-04
# 6  https://nplus1.ru/news/2023/10/04/same-sex-beh...  2023-10-04
# 7     https://nplus1.ru/news/2023/10/04/frb-gw-or-no  2023-10-04
# 8        https://nplus1.ru/news/2023/10/04/ak-alakha  2023-10-04
# 9  https://nplus1.ru/news/2023/10/04/second-vacci...  2023-10-04
#
#                   2                                                  3
# 0       Михаил Бойм  Нобелевскую премию по химии присудили за квант...
# 1     Слава Гоменюк  Врачи описали хроническое отравление марганцем...
# 2   Винера Андреева  Извержения Деканских траппов принесли динозавр...
# 3        Олег Лищук  Злоупотребление каннабисом связали с повышенны...
# 4  Александр Войтюк  NASA показало полет возвращаемой капсулы станц...
# 5     Слава Гоменюк  Пожилые водители с СДВГ отличились повышенным ...
# 6  Катерина Петрова  Однополое сексуальное поведение млекопитающих ...
# 7  Александр Войтюк  Астрономы не нашли связи между быстрыми радиов...
# 8   Михаил Подрезов  Знатному пазырыкцу поставили диффузный идиопат...
# 9     Слава Гоменюк  ВОЗ одобрила вторую противомалярийную вакцину ...

# %% [markdown]
# Переименуем столбцы в базе.

# %%
df.columns = ['link', 'date', 'author', 'title']

# %%
df.head()
# Out:
#                                                 link        date  \
# 0  https://nplus1.ru/news/2023/10/04/chem-nobel-2023  2023-10-04
# 1  https://nplus1.ru/news/2023/10/05/manganese-ac...  2023-10-05
# 2  https://nplus1.ru/news/2023/10/04/sulfur-of-de...  2023-10-04
# 3    https://nplus1.ru/news/2023/10/04/heartbreaking  2023-10-04
# 4  https://nplus1.ru/news/2023/10/04/osiris-rex-d...  2023-10-04
#
#              author                                              title
# 0       Михаил Бойм  Нобелевскую премию по химии присудили за квант...
# 1     Слава Гоменюк  Врачи описали хроническое отравление марганцем...
# 2   Винера Андреева  Извержения Деканских траппов принесли динозавр...
# 3        Олег Лищук  Злоупотребление каннабисом связали с повышенны...
# 4  Александр Войтюк  NASA показало полет возвращаемой капсулы станц...

# %% [markdown]
# Всё! Сохраняем датафрейм в файл. Для разнообразия сохраним в Excel:

# %%
df.to_excel('nplus-news.xlsx', index=False)
